# %%
# install Java8
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# download spark3.2.3
# !wget -q https://downloads.apache.org/spark/spark-3.2.3/spark-3.2.3-bin-hadoop3.2.tgz 
# unzip it
# !tar xf spark-3.2.3-bin-hadoop3.2.tgz
# !pip install -q findspark

# %% [markdown]
#  **Setting Environment Variables**

# %%
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.2.3-bin-hadoop3.2"
import sys

# %% [markdown]
# **Starting a Spark Session**

# %%
# !pip install pyspark==3.2.3
#import findspark
#findspark.init()
from pyspark.sql import SparkSession
from pyspark.conf import SparkConf
from pyspark.sql.functions import *
import pyspark.sql.functions as func
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyspark==3.2.3
#   Downloading pyspark-3.2.3.tar.gz (281.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 281.5/281.5 MB 4.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting py4j==0.10.9.5
#   Downloading py4j-0.10.9.5-py2.py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.7/199.7 KB 22.7 MB/s eta 0:00:00
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.2.3-py2.py3-none-any.whl size=281990673 sha256=50d42e4f3c836fa9543d14fd1dbd1f6e0878454e4ed005edb1520c68e2db8c77
#   Stored in directory: /root/.cache/pip/wheels/9a/99/8c/e2d5ede0e1aefb33c64af344f2cd569354237f0bdd673bd243
# Successfully built pyspark
# Installing collected packages: py4j, pyspark
# Successfully installed py4j-0.10.9.5 pyspark-3.2.3

# %% [markdown]
# **Opening a Session**

# %%
spark = SparkSession.builder.master("local[*]").appName("MyFirstProgram").getOrCreate()
sc=spark.sparkContext

# %% [markdown]
# **Quick Installation Test**

# %%
# Test the spark
df = spark.createDataFrame([{"hello": "world"} for x in
range(1000)])
df.show(3, False)
# Out:
# +-----+
# |hello|
# +-----+
# |world|
# |world|
# |world|
# +-----+
# only showing top 3 rows

# %% [markdown]
# **Checking pyspark version**

# %%
import sys
# Check the pyspark version
import pyspark
print(pyspark.__version__)
# Out:
# 3.2.3

# %% [markdown]
# # Exercise 0 : Download and Prepare your Document Corpus

# %% [markdown]
# **Uploading the text files** **and Reading files**

# %%
import string 

def lower_clean_str(strr):
  return strr.translate(strr.maketrans('', '', string.punctuation)).lower()

# %%
from pyspark import SparkFiles
spark.sparkContext.addFile("https://www.gutenberg.org/files/1112/1112.txt")

wordsRJ = sc.textFile(SparkFiles.get("1112.txt")).flatMap(lambda x: x.split(' ') )\
                        .map(lambda x: lower_clean_str(x))

for i in wordsRJ.collect(): print(i)
# Out:
# Streaming output truncated to the last 5000 lines.
# the
# capulets
#
#
#
#
# raise
# up
# the
# montagues
# some
# others
# search
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# exeunt
# others
# of
# the
# watch
#
#
#
#
# we
# see
# the
# ground
# whereon
# these
# woes
# do
# lie
#
#
#
#
# but
# the
# true
# ground
# of
# all
# these
# piteous
# woes
#
#
#
#
# we
# cannot
# without
# circumstance
# descry
#
#
#
#
#
#
# enter
# some
# of
# the
# watch
# with
# romeos
# man
# balthasar
#
#
#
# 2
# watch
# heres
# romeos
# man
# we
# found
# him
# in
# the
# churchyard
#
#
#
# chief
# watch
# hold
# him
# in
# safety
# till
# the
# prince
# come
# hither
#
#
#
#
#
#
#
#
#
#
#
# enter
# friar
# laurence
# and
# another
# watchman
#
#
#
# 3
# watch
# here
# is
# a
# friar
# that
# trembles
# sighs
# and
# weeps
#
#
#
#
# we
# took
# this
# mattock
# and
# this
# spade
# from
# him
#
#
#
#
# as
# he
# was
# coming
# from
# this
# churchyard
# side
#
#
#
# chief
# watch
# a
# great
# suspicion
# stay
# the
# friar
# too
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# enter
# the
# prince
# and
# attendants
#
#
#
#
# prince
# what
# misadventure
# is
# so
# early
# up
#
#
#
#
# that
# calls
# our
# person
# from
# our
# morning
# rest
#
#
#
#
#
#
#
#
#
#
#
#
#
# enter
# capulet
# and
# his
# wife
# with
# others
#
#
#
#
# cap
# what
# should
# it
# be
# that
# they
# so
# shriek
# abroad
#
#
#
# wife
# the
# people
# in
# the
# street
# cry
# romeo
#
#
#
#
# some
# juliet
# and
# some
# paris
# and
# all
# run
#
#
#
#
# with
# open
# outcry
# toward
# our
# monument
#
#
#
# prince
# what
# fear
# is
# this
# which
# startles
# in
# our
# ears
#
#
#
# chief
# watch
# sovereign
# here
# lies
# the
# county
# paris
# slain
#
#
#
#
# and
# romeo
# dead
# and
# juliet
# dead
# before
#
#
#
#
# warm
# and
# new
# killd
#
#
#
# prince
# search
# seek
# and
# know
# how
# this
# foul
# murder
# comes
#
#
#
# chief
# watch
# here
# is
# a
# friar
# and
# slaughterd
# romeos
# man
#
#
#
#
# with
# instruments
# upon
# them
# fit
# to
# open
#
#
#
#
# these
# dead
# mens
# tombs
#
#
#
# cap
# o
# heavens
# o
# wife
# look
# how
# our
# daughter
# bleeds
#
#
#
#
# this
# dagger
# hath
# mistaen
# for
# lo
# his
# house
#
#
#
#
# is
# empty
# on
# the
# back
# of
# montague
#
#
#
#
# and
# it
# missheathed
# in
# my
# daughters
# bosom
#
#
#
# wife
# o
# me
# this
# sight
# of
# death
# is
# as
# a
# bell
#
#
#
#
# that
# warns
# my
# old
# age
# to
# a
# sepulchre
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# enter
# montague
# and
# others
#
#
#
#
# prince
# come
# montague
# for
# thou
# art
# early
# up
#
#
#
#
# to
# see
# thy
# son
# and
# heir
# more
# early
# down
#
#
#
# mon
# alas
# my
# liege
# my
# wife
# is
# dead
# tonight
#
#
#
#
# grief
# of
# my
# sons
# exile
# hath
# stoppd
# her
# breath
#
#
#
#
# what
# further
# woe
# conspires
# against
# mine
# age
#
#
#
# prince
# look
# and
# thou
# shalt
# see
#
#
#
# mon
# o
# thou
# untaught
# what
# manners
# is
# in
# this
#
#
#
#
# to
# press
# before
# thy
# father
# to
# a
# grave
#
#
#
# prince
# seal
# up
# the
# mouth
# of
# outrage
# for
# a
# while
#
#
#
#
# till
# we
# can
# clear
# these
# ambiguities
#
#
#
#
# and
# know
# their
# spring
# their
# head
# their
# true
# descent
#
#
#
#
# and
# then
# will
# i
# be
# general
# of
# your
# woes
#
#
#
#
# and
# lead
# you
# even
# to
# death
# meantime
# forbear
#
#
#
#
# and
# let
# mischance
# be
# slave
# to
# patience
#
#
#
#
# bring
# forth
# the
# parties
# of
# suspicion
#
#
#
# friar
# i
# am
# the
# greatest
# able
# to
# do
# least
#
#
#
#
# yet
# most
# suspected
# as
# the
# time
# and
# place
#
#
#
#
# doth
# make
# against
# me
# of
# this
# direful
# murther
#
#
#
#
# and
# here
# i
# stand
# both
# to
# impeach
# and
# purge
#
#
#
#
# myself
# condemned
# and
# myself
# excusd
#
#
#
# prince
# then
# say
# it
# once
# what
# thou
# dost
# know
# in
# this
#
#
#
# friar
# i
# will
# be
# brief
# for
# my
# short
# date
# of
# breath
#
#
#
#
# is
# not
# so
# long
# as
# is
# a
# tedious
# tale
#
#
#
#
# romeo
# there
# dead
# was
# husband
# to
# that
# juliet
#
#
#
#
# and
# she
# there
# dead
# that
# romeos
# faithful
# wife
#
#
#
#
# i
# married
# them
# and
# their
# stoln
# marriage
# day
#
#
#
#
# was
# tybalts
# doomsday
# whose
# untimely
# death
#
#
#
#
# banishd
# the
# newmade
# bridegroom
# from
# this
# city
#
#
#
#
# for
# whom
# and
# not
# for
# tybalt
# juliet
# pind
#
#
#
#
# you
# to
# remove
# that
# siege
# of
# grief
# from
# her
#
#
#
#
# betrothd
# and
# would
# have
# married
# her
# perforce
#
#
#
#
# to
# county
# paris
# then
# comes
# she
# to
# me
#
#
#
#
# and
# with
# wild
# looks
# bid
# me
# devise
# some
# mean
#
#
#
#
# to
# rid
# her
# from
# this
# second
# marriage
#
#
#
#
# or
# in
# my
# cell
# there
# would
# she
# kill
# herself
#
#
#
#
# then
# gave
# i
# her
# so
# tutored
# by
# my
# art
#
#
#
#
# a
# sleeping
# potion
# which
# so
# took
# effect
#
#
#
#
# as
# i
# intended
# for
# it
# wrought
# on
# her
#
#
#
#
# the
# form
# of
# death
# meantime
# i
# writ
# to
# romeo
#
#
#
#
# that
# he
# should
# hither
# come
# as
# this
# dire
# night
#
#
#
#
# to
# help
# to
# take
# her
# from
# her
# borrowed
# grave
#
#
#
#
# being
# the
# time
# the
# potions
# force
# should
# cease
#
#
#
#
# but
# he
# which
# bore
# my
# letter
# friar
# john
#
#
#
#
# was
# stayd
# by
# accident
# and
# yesternight
#
#
#
#
# returnd
# my
# letter
# back
# then
# all
# alone
#
#
#
#
# at
# the
# prefixed
# hour
# of
# her
# waking
#
#
#
#
# came
# i
# to
# take
# her
# from
# her
# kindreds
# vault
#
#
#
#
# meaning
# to
# keep
# her
# closely
# at
# my
# cell
#
#
#
#
# till
# i
# conveniently
# could
# send
# to
# romeo
#
#
#
#
# but
# when
# i
# came
# some
# minute
# ere
# the
# time
#
#
#
#
# of
# her
# awaking
# here
# untimely
# lay
#
#
#
#
# the
# noble
# paris
# and
# true
# romeo
# dead
#
#
#
#
# she
# wakes
# and
# i
# entreated
# her
# come
# forth
#
#
#
#
# and
# bear
# this
# work
# of
# heaven
# with
# patience
#
#
#
#
# but
# then
# a
# noise
# did
# scare
# me
# from
# the
# tomb
#
#
#
#
# and
# she
# too
# desperate
# would
# not
# go
# with
# me
#
#
#
#
# but
# as
# it
# seems
# did
# violence
# on
# herself
#
#
#
#
# all
# this
# i
# know
# and
# to
# the
# marriage
#
#
#
#
# her
# nurse
# is
# privy
# and
# if
# aught
# in
# this
#
#
#
#
# miscarried
# by
# my
# fault
# let
# my
# old
# life
#
#
#
#
# be
# sacrificd
# some
# hour
# before
# his
# time
#
#
#
#
# unto
# the
# rigour
# of
# severest
# law
#
#
#
# prince
# we
# still
# have
# known
# thee
# for
# a
# holy
# man
#
#
#
#
# wheres
# romeos
# man
# what
# can
# he
# say
# in
# this
#
#
#
# bal
# i
# brought
# my
# master
# news
# of
# juliets
# death
#
#
#
#
# and
# then
# in
# post
# he
# came
# from
# mantua
#
#
#
#
# to
# this
# same
# place
# to
# this
# same
# monument
#
#
#
#
# this
# letter
# he
# early
# bid
# me
# give
# his
# father
#
#
#
#
# and
# threatned
# me
# with
# death
# going
# in
# the
# vault
#
#
#
#
# if
# i
# departed
# not
# and
# left
# him
# there
#
#
#
# prince
# give
# me
# the
# letter
# i
# will
# look
# on
# it
#
#
#
#
# where
# is
# the
# countys
# page
# that
# raisd
# the
# watch
#
#
#
#
# sirrah
# what
# made
# your
# master
# in
# this
# place
#
#
#
# boy
# he
# came
# with
# flowers
# to
# strew
# his
# ladys
# grave
#
#
#
#
# and
# bid
# me
# stand
# aloof
# and
# so
# i
# did
#
#
#
#
# anon
# comes
# one
# with
# light
# to
# ope
# the
# tomb
#
#
#
#
# and
# byandby
# my
# master
# drew
# on
# him
#
#
#
#
# and
# then
# i
# ran
# away
# to
# call
# the
# watch
#
#
#
# prince
# this
# letter
# doth
# make
# good
# the
# friars
# words
#
#
#
#
# their
# course
# of
# love
# the
# tidings
# of
# her
# death
#
#
#
#
# and
# here
# he
# writes
# that
# he
# did
# buy
# a
# poison
#
#
#
#
# of
# a
# poor
# pothecary
# and
# therewithal
#
#
#
#
# came
# to
# this
# vault
# to
# die
# and
# lie
# with
# juliet
#
#
#
#
# where
# be
# these
# enemies
# capulet
# montage
#
#
#
#
# see
# what
# a
# scourge
# is
# laid
# upon
# your
# hate
#
#
#
#
# that
# heaven
# finds
# means
# to
# kill
# your
# joys
# with
# love
#
#
#
#
# and
# i
# for
# winking
# at
# you
# discords
# too
#
#
#
#
# have
# lost
# a
# brace
# of
# kinsmen
# all
# are
# punishd
#
#
#
# cap
# o
# brother
# montague
# give
# me
# thy
# hand
#
#
#
#
# this
# is
# my
# daughters
# jointure
# for
# no
# more
#
#
#
#
# can
# i
# demand
#
#
#
# mon
# but
# i
# can
# give
# thee
# more
#
#
#
#
# for
# i
# will
# raise
# her
# statue
# in
# pure
# gold
#
#
#
#
# that
# whiles
# verona
# by
# that
# name
# is
# known
#
#
#
#
# there
# shall
# no
# figure
# at
# such
# rate
# be
# set
#
#
#
#
# as
# that
# of
# true
# and
# faithful
# juliet
#
#
#
# cap
# as
# rich
# shall
# romeos
# by
# his
# ladys
# lie
#
#
#
#
# poor
# sacrifices
# of
# our
# enmity
#
#
#
# prince
# a
# glooming
# peace
# this
# morning
# with
# it
# brings
#
#
#
#
# the
# sun
# for
# sorrow
# will
# not
# show
# his
# head
#
#
#
#
# go
# hence
# to
# have
# more
# talk
# of
# these
# sad
# things
#
#
#
#
# some
# shall
# be
# pardond
# and
# some
# punished
#
#
#
#
# for
# never
# was
# a
# story
# of
# more
# woe
#
#
#
#
# than
# this
# of
# juliet
# and
# her
# romeo
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# exeunt
# omnes
#
# the
# end
#
#
#
#
#
#
#
#
# end
# of
# the
# project
# gutenberg
# ebook
# of
# romeo
# and
# juliet
# by
# william
# shakespeare
#
#
# end
# of
# this
# project
# gutenberg
# ebook
# romeo
# and
# juliet
#
#
#
# this
# file
# should
# be
# named
# 1112txt
# or
# 1112zip
#
# this
# and
# all
# associated
# files
# of
# various
# formats
# will
# be
# found
# in
#
#
#
#
#
#
#
#
# httpwwwgutenbergorg1111112
#
#
#
# updated
# editions
# will
# replace
# the
# previous
# onethe
# old
# editions
# will
# be
# renamed
#
# creating
# the
# works
# from
# public
# domain
# print
# editions
# means
# that
# no
# one
# owns
# a
# united
# states
# copyright
# in
# these
# works
# so
# the
# foundation
# and
# you
# can
# copy
# and
# distribute
# it
# in
# the
# united
# states
# without
# permission
# and
# without
# paying
# copyright
# royalties
#
# special
# rules
# set
# forth
# in
# the
# general
# terms
# of
# use
# part
# of
# this
# license
# apply
# to
# copying
# and
# distributing
# project
# gutenbergtm
# electronic
# works
# to
# protect
# the
# project
# gutenbergtm
# concept
# and
# trademark
#
# project
# gutenberg
# is
# a
# registered
# trademark
# and
# may
# not
# be
# used
# if
# you
# charge
# for
# the
# ebooks
# unless
# you
# receive
# specific
# permission
#
# if
# you
# do
# not
# charge
# anything
# for
# copies
# of
# this
# ebook
# complying
# with
# the
# rules
# is
# very
# easy
#
# you
# may
# use
# this
# ebook
# for
# nearly
# any
# purpose
# such
# as
# creation
# of
# derivative
# works
# reports
# performances
# and
# research
#
# they
# may
# be
# modified
# and
# printed
# and
# given
# awayyou
# may
# do
# practically
# anything
# with
# public
# domain
# ebooks
#
# redistribution
# is
# subject
# to
# the
# trademark
# license
# especially
# commercial
# redistribution
#
#
#
#
# start
# full
# license
#
#
# the
# full
# project
# gutenberg
# license
# please
# read
# this
# before
# you
# distribute
# or
# use
# this
# work
#
# to
# protect
# the
# project
# gutenbergtm
# mission
# of
# promoting
# the
# free
# distribution
# of
# electronic
# works
# by
# using
# or
# distributing
# this
# work
# or
# any
# other
# work
# associated
# in
# any
# way
# with
# the
# phrase
# project
# gutenberg
# you
# agree
# to
# comply
# with
# all
# the
# terms
# of
# the
# full
# project
# gutenbergtm
# license
# available
# with
# this
# file
# or
# online
# at
# httpgutenbergorglicense
#
#
# section
# 1
#
# general
# terms
# of
# use
# and
# redistributing
# project
# gutenbergtm
# electronic
# works
#
# 1a
#
# by
# reading
# or
# using
# any
# part
# of
# this
# project
# gutenbergtm
# electronic
# work
# you
# indicate
# that
# you
# have
# read
# understand
# agree
# to
# and
# accept
# all
# the
# terms
# of
# this
# license
# and
# intellectual
# property
# trademarkcopyright
# agreement
#
# if
# you
# do
# not
# agree
# to
# abide
# by
# all
# the
# terms
# of
# this
# agreement
# you
# must
# cease
# using
# and
# return
# or
# destroy
# all
# copies
# of
# project
# gutenbergtm
# electronic
# works
# in
# your
# possession
# if
# you
# paid
# a
# fee
# for
# obtaining
# a
# copy
# of
# or
# access
# to
# a
# project
# gutenbergtm
# electronic
# work
# and
# you
# do
# not
# agree
# to
# be
# bound
# by
# the
# terms
# of
# this
# agreement
# you
# may
# obtain
# a
# refund
# from
# the
# person
# or
# entity
# to
# whom
# you
# paid
# the
# fee
# as
# set
# forth
# in
# paragraph
# 1e8
#
# 1b
#
# project
# gutenberg
# is
# a
# registered
# trademark
#
# it
# may
# only
# be
# used
# on
# or
# associated
# in
# any
# way
# with
# an
# electronic
# work
# by
# people
# who
# agree
# to
# be
# bound
# by
# the
# terms
# of
# this
# agreement
#
# there
# are
# a
# few
# things
# that
# you
# can
# do
# with
# most
# project
# gutenbergtm
# electronic
# works
# even
# without
# complying
# with
# the
# full
# terms
# of
# this
# agreement
#
# see
# paragraph
# 1c
# below
#
# there
# are
# a
# lot
# of
# things
# you
# can
# do
# with
# project
# gutenbergtm
# electronic
# works
# if
# you
# follow
# the
# terms
# of
# this
# agreement
# and
# help
# preserve
# free
# future
# access
# to
# project
# gutenbergtm
# electronic
# works
#
# see
# paragraph
# 1e
# below
#
# 1c
#
# the
# project
# gutenberg
# literary
# archive
# foundation
# the
# foundation
# or
# pglaf
# owns
# a
# compilation
# copyright
# in
# the
# collection
# of
# project
# gutenbergtm
# electronic
# works
#
# nearly
# all
# the
# individual
# works
# in
# the
# collection
# are
# in
# the
# public
# domain
# in
# the
# united
# states
#
# if
# an
# individual
# work
# is
# in
# the
# public
# domain
# in
# the
# united
# states
# and
# you
# are
# located
# in
# the
# united
# states
# we
# do
# not
# claim
# a
# right
# to
# prevent
# you
# from
# copying
# distributing
# performing
# displaying
# or
# creating
# derivative
# works
# based
# on
# the
# work
# as
# long
# as
# all
# references
# to
# project
# gutenberg
# are
# removed
#
# of
# course
# we
# hope
# that
# you
# will
# support
# the
# project
# gutenbergtm
# mission
# of
# promoting
# free
# access
# to
# electronic
# works
# by
# freely
# sharing
# project
# gutenbergtm
# works
# in
# compliance
# with
# the
# terms
# of
# this
# agreement
# for
# keeping
# the
# project
# gutenbergtm
# name
# associated
# with
# the
# work
#
# you
# can
# easily
# comply
# with
# the
# terms
# of
# this
# agreement
# by
# keeping
# this
# work
# in
# the
# same
# format
# with
# its
# attached
# full
# project
# gutenbergtm
# license
# when
# you
# share
# it
# without
# charge
# with
# others
#
# 1d
#
# the
# copyright
# laws
# of
# the
# place
# where
# you
# are
# located
# also
# govern
# what
# you
# can
# do
# with
# this
# work
#
# copyright
# laws
# in
# most
# countries
# are
# in
# a
# constant
# state
# of
# change
#
# if
# you
# are
# outside
# the
# united
# states
# check
# the
# laws
# of
# your
# country
# in
# addition
# to
# the
# terms
# of
# this
# agreement
# before
# downloading
# copying
# displaying
# performing
# distributing
# or
# creating
# derivative
# works
# based
# on
# this
# work
# or
# any
# other
# project
# gutenbergtm
# work
#
# the
# foundation
# makes
# no
# representations
# concerning
# the
# copyright
# status
# of
# any
# work
# in
# any
# country
# outside
# the
# united
# states
#
# 1e
#
# unless
# you
# have
# removed
# all
# references
# to
# project
# gutenberg
#
# 1e1
#
# the
# following
# sentence
# with
# active
# links
# to
# or
# other
# immediate
# access
# to
# the
# full
# project
# gutenbergtm
# license
# must
# appear
# prominently
# whenever
# any
# copy
# of
# a
# project
# gutenbergtm
# work
# any
# work
# on
# which
# the
# phrase
# project
# gutenberg
# appears
# or
# with
# which
# the
# phrase
# project
# gutenberg
# is
# associated
# is
# accessed
# displayed
# performed
# viewed
# copied
# or
# distributed
#
# this
# ebook
# is
# for
# the
# use
# of
# anyone
# anywhere
# at
# no
# cost
# and
# with
# almost
# no
# restrictions
# whatsoever
#
# you
# may
# copy
# it
# give
# it
# away
# or
# reuse
# it
# under
# the
# terms
# of
# the
# project
# gutenberg
# license
# included
# with
# this
# ebook
# or
# online
# at
# wwwgutenbergorglicense
#
# 1e2
#
# if
# an
# individual
# project
# gutenbergtm
# electronic
# work
# is
# derived
# from
# the
# public
# domain
# does
# not
# contain
# a
# notice
# indicating
# that
# it
# is
# posted
# with
# permission
# of
# the
# copyright
# holder
# the
# work
# can
# be
# copied
# and
# distributed
# to
# anyone
# in
# the
# united
# states
# without
# paying
# any
# fees
# or
# charges
#
# if
# you
# are
# redistributing
# or
# providing
# access
# to
# a
# work
# with
# the
# phrase
# project
# gutenberg
# associated
# with
# or
# appearing
# on
# the
# work
# you
# must
# comply
# either
# with
# the
# requirements
# of
# paragraphs
# 1e1
# through
# 1e7
# or
# obtain
# permission
# for
# the
# use
# of
# the
# work
# and
# the
# project
# gutenbergtm
# trademark
# as
# set
# forth
# in
# paragraphs
# 1e8
# or
# 1e9
#
# 1e3
#
# if
# an
# individual
# project
# gutenbergtm
# electronic
# work
# is
# posted
# with
# the
# permission
# of
# the
# copyright
# holder
# your
# use
# and
# distribution
# must
# comply
# with
# both
# paragraphs
# 1e1
# through
# 1e7
# and
# any
# additional
# terms
# imposed
# by
# the
# copyright
# holder
#
# additional
# terms
# will
# be
# linked
# to
# the
# project
# gutenbergtm
# license
# for
# all
# works
# posted
# with
# the
# permission
# of
# the
# copyright
# holder
# found
# at
# the
# beginning
# of
# this
# work
#
# 1e4
#
# do
# not
# unlink
# or
# detach
# or
# remove
# the
# full
# project
# gutenbergtm
# license
# terms
# from
# this
# work
# or
# any
# files
# containing
# a
# part
# of
# this
# work
# or
# any
# other
# work
# associated
# with
# project
# gutenbergtm
#
# 1e5
#
# do
# not
# copy
# display
# perform
# distribute
# or
# redistribute
# this
# electronic
# work
# or
# any
# part
# of
# this
# electronic
# work
# without
# prominently
# displaying
# the
# sentence
# set
# forth
# in
# paragraph
# 1e1
# with
# active
# links
# or
# immediate
# access
# to
# the
# full
# terms
# of
# the
# project
# gutenbergtm
# license
#
# 1e6
#
# you
# may
# convert
# to
# and
# distribute
# this
# work
# in
# any
# binary
# compressed
# marked
# up
# nonproprietary
# or
# proprietary
# form
# including
# any
# word
# processing
# or
# hypertext
# form
#
# however
# if
# you
# provide
# access
# to
# or
# distribute
# copies
# of
# a
# project
# gutenbergtm
# work
# in
# a
# format
# other
# than
# plain
# vanilla
# ascii
# or
# other
# format
# used
# in
# the
# official
# version
# posted
# on
# the
# official
# project
# gutenbergtm
# web
# site
# wwwgutenbergorg
# you
# must
# at
# no
# additional
# cost
# fee
# or
# expense
# to
# the
# user
# provide
# a
# copy
# a
# means
# of
# exporting
# a
# copy
# or
# a
# means
# of
# obtaining
# a
# copy
# upon
# request
# of
# the
# work
# in
# its
# original
# plain
# vanilla
# ascii
# or
# other
# form
#
# any
# alternate
# format
# must
# include
# the
# full
# project
# gutenbergtm
# license
# as
# specified
# in
# paragraph
# 1e1
#
# 1e7
#
# do
# not
# charge
# a
# fee
# for
# access
# to
# viewing
# displaying
# performing
# copying
# or
# distributing
# any
# project
# gutenbergtm
# works
# unless
# you
# comply
# with
# paragraph
# 1e8
# or
# 1e9
#
# 1e8
#
# you
# may
# charge
# a
# reasonable
# fee
# for
# copies
# of
# or
# providing
# access
# to
# or
# distributing
# project
# gutenbergtm
# electronic
# works
# provided
# that
#
#
# you
# pay
# a
# royalty
# fee
# of
# 20
# of
# the
# gross
# profits
# you
# derive
# from
#
#
#
#
#
# the
# use
# of
# project
# gutenbergtm
# works
# calculated
# using
# the
# method
#
#
#
#
#
# you
# already
# use
# to
# calculate
# your
# applicable
# taxes
#
# the
# fee
# is
#
#
#
#
#
# owed
# to
# the
# owner
# of
# the
# project
# gutenbergtm
# trademark
# but
# he
#
#
#
#
#
# has
# agreed
# to
# donate
# royalties
# under
# this
# paragraph
# to
# the
#
#
#
#
#
# project
# gutenberg
# literary
# archive
# foundation
#
# royalty
# payments
#
#
#
#
#
# must
# be
# paid
# within
# 60
# days
# following
# each
# date
# on
# which
# you
#
#
#
#
#
# prepare
# or
# are
# legally
# required
# to
# prepare
# your
# periodic
# tax
#
#
#
#
#
# returns
#
# royalty
# payments
# should
# be
# clearly
# marked
# as
# such
# and
#
#
#
#
#
# sent
# to
# the
# project
# gutenberg
# literary
# archive
# foundation
# at
# the
#
#
#
#
#
# address
# specified
# in
# section
# 4
# information
# about
# donations
# to
#
#
#
#
#
# the
# project
# gutenberg
# literary
# archive
# foundation
#
#
# you
# provide
# a
# full
# refund
# of
# any
# money
# paid
# by
# a
# user
# who
# notifies
#
#
#
#
#
# you
# in
# writing
# or
# by
# email
# within
# 30
# days
# of
# receipt
# that
# she
#
#
#
#
#
# does
# not
# agree
# to
# the
# terms
# of
# the
# full
# project
# gutenbergtm
#
#
#
#
#
# license
#
# you
# must
# require
# such
# a
# user
# to
# return
# or
#
#
#
#
#
# destroy
# all
# copies
# of
# the
# works
# possessed
# in
# a
# physical
# medium
#
#
#
#
#
# and
# discontinue
# all
# use
# of
# and
# all
# access
# to
# other
# copies
# of
#
#
#
#
#
# project
# gutenbergtm
# works
#
#
# you
# provide
# in
# accordance
# with
# paragraph
# 1f3
# a
# full
# refund
# of
# any
#
#
#
#
#
# money
# paid
# for
# a
# work
# or
# a
# replacement
# copy
# if
# a
# defect
# in
# the
#
#
#
#
#
# electronic
# work
# is
# discovered
# and
# reported
# to
# you
# within
# 90
# days
#
#
#
#
#
# of
# receipt
# of
# the
# work
#
#
# you
# comply
# with
# all
# other
# terms
# of
# this
# agreement
# for
# free
#
#
#
#
#
# distribution
# of
# project
# gutenbergtm
# works
#
# 1e9
#
# if
# you
# wish
# to
# charge
# a
# fee
# or
# distribute
# a
# project
# gutenbergtm
# electronic
# work
# or
# group
# of
# works
# on
# different
# terms
# than
# are
# set
# forth
# in
# this
# agreement
# you
# must
# obtain
# permission
# in
# writing
# from
# both
# the
# project
# gutenberg
# literary
# archive
# foundation
# and
# michael
# hart
# the
# owner
# of
# the
# project
# gutenbergtm
# trademark
#
# contact
# the
# foundation
# as
# set
# forth
# in
# section
# 3
# below
#
# 1f
#
# 1f1
#
# project
# gutenberg
# volunteers
# and
# employees
# expend
# considerable
# effort
# to
# identify
# do
# copyright
# research
# on
# transcribe
# and
# proofread
# public
# domain
# works
# in
# creating
# the
# project
# gutenbergtm
# collection
#
# despite
# these
# efforts
# project
# gutenbergtm
# electronic
# works
# and
# the
# medium
# on
# which
# they
# may
# be
# stored
# may
# contain
# defects
# such
# as
# but
# not
# limited
# to
# incomplete
# inaccurate
# or
# corrupt
# data
# transcription
# errors
# a
# copyright
# or
# other
# intellectual
# property
# infringement
# a
# defective
# or
# damaged
# disk
# or
# other
# medium
# a
# computer
# virus
# or
# computer
# codes
# that
# damage
# or
# cannot
# be
# read
# by
# your
# equipment
#
# 1f2
#
# limited
# warranty
# disclaimer
# of
# damages
#
# except
# for
# the
# right
# of
# replacement
# or
# refund
# described
# in
# paragraph
# 1f3
# the
# project
# gutenberg
# literary
# archive
# foundation
# the
# owner
# of
# the
# project
# gutenbergtm
# trademark
# and
# any
# other
# party
# distributing
# a
# project
# gutenbergtm
# electronic
# work
# under
# this
# agreement
# disclaim
# all
# liability
# to
# you
# for
# damages
# costs
# and
# expenses
# including
# legal
# fees
#
# you
# agree
# that
# you
# have
# no
# remedies
# for
# negligence
# strict
# liability
# breach
# of
# warranty
# or
# breach
# of
# contract
# except
# those
# provided
# in
# paragraph
# 1f3
#
# you
# agree
# that
# the
# foundation
# the
# trademark
# owner
# and
# any
# distributor
# under
# this
# agreement
# will
# not
# be
# liable
# to
# you
# for
# actual
# direct
# indirect
# consequential
# punitive
# or
# incidental
# damages
# even
# if
# you
# give
# notice
# of
# the
# possibility
# of
# such
# damage
#
# 1f3
#
# limited
# right
# of
# replacement
# or
# refund
#
# if
# you
# discover
# a
# defect
# in
# this
# electronic
# work
# within
# 90
# days
# of
# receiving
# it
# you
# can
# receive
# a
# refund
# of
# the
# money
# if
# any
# you
# paid
# for
# it
# by
# sending
# a
# written
# explanation
# to
# the
# person
# you
# received
# the
# work
# from
#
# if
# you
# received
# the
# work
# on
# a
# physical
# medium
# you
# must
# return
# the
# medium
# with
# your
# written
# explanation
#
# the
# person
# or
# entity
# that
# provided
# you
# with
# the
# defective
# work
# may
# elect
# to
# provide
# a
# replacement
# copy
# in
# lieu
# of
# a
# refund
#
# if
# you
# received
# the
# work
# electronically
# the
# person
# or
# entity
# providing
# it
# to
# you
# may
# choose
# to
# give
# you
# a
# second
# opportunity
# to
# receive
# the
# work
# electronically
# in
# lieu
# of
# a
# refund
#
# if
# the
# second
# copy
# is
# also
# defective
# you
# may
# demand
# a
# refund
# in
# writing
# without
# further
# opportunities
# to
# fix
# the
# problem
#
# 1f4
#
# except
# for
# the
# limited
# right
# of
# replacement
# or
# refund
# set
# forth
# in
# paragraph
# 1f3
# this
# work
# is
# provided
# to
# you
# asis
# with
# no
# other
# warranties
# of
# any
# kind
# express
# or
# implied
# including
# but
# not
# limited
# to
# warranties
# of
# merchantability
# or
# fitness
# for
# any
# purpose
#
# 1f5
#
# some
# states
# do
# not
# allow
# disclaimers
# of
# certain
# implied
# warranties
# or
# the
# exclusion
# or
# limitation
# of
# certain
# types
# of
# damages
# if
# any
# disclaimer
# or
# limitation
# set
# forth
# in
# this
# agreement
# violates
# the
# law
# of
# the
# state
# applicable
# to
# this
# agreement
# the
# agreement
# shall
# be
# interpreted
# to
# make
# the
# maximum
# disclaimer
# or
# limitation
# permitted
# by
# the
# applicable
# state
# law
#
# the
# invalidity
# or
# unenforceability
# of
# any
# provision
# of
# this
# agreement
# shall
# not
# void
# the
# remaining
# provisions
#
# 1f6
#
# indemnity
#
# you
# agree
# to
# indemnify
# and
# hold
# the
# foundation
# the
# trademark
# owner
# any
# agent
# or
# employee
# of
# the
# foundation
# anyone
# providing
# copies
# of
# project
# gutenbergtm
# electronic
# works
# in
# accordance
# with
# this
# agreement
# and
# any
# volunteers
# associated
# with
# the
# production
# promotion
# and
# distribution
# of
# project
# gutenbergtm
# electronic
# works
# harmless
# from
# all
# liability
# costs
# and
# expenses
# including
# legal
# fees
# that
# arise
# directly
# or
# indirectly
# from
# any
# of
# the
# following
# which
# you
# do
# or
# cause
# to
# occur
# a
# distribution
# of
# this
# or
# any
# project
# gutenbergtm
# work
# b
# alteration
# modification
# or
# additions
# or
# deletions
# to
# any
# project
# gutenbergtm
# work
# and
# c
# any
# defect
# you
# cause
#
#
# section
#
# 2
#
# information
# about
# the
# mission
# of
# project
# gutenbergtm
#
# project
# gutenbergtm
# is
# synonymous
# with
# the
# free
# distribution
# of
# electronic
# works
# in
# formats
# readable
# by
# the
# widest
# variety
# of
# computers
# including
# obsolete
# old
# middleaged
# and
# new
# computers
#
# it
# exists
# because
# of
# the
# efforts
# of
# hundreds
# of
# volunteers
# and
# donations
# from
# people
# in
# all
# walks
# of
# life
#
# volunteers
# and
# financial
# support
# to
# provide
# volunteers
# with
# the
# assistance
# they
# need
# are
# critical
# to
# reaching
# project
# gutenbergtms
# goals
# and
# ensuring
# that
# the
# project
# gutenbergtm
# collection
# will
# remain
# freely
# available
# for
# generations
# to
# come
#
# in
# 2001
# the
# project
# gutenberg
# literary
# archive
# foundation
# was
# created
# to
# provide
# a
# secure
# and
# permanent
# future
# for
# project
# gutenbergtm
# and
# future
# generations
# to
# learn
# more
# about
# the
# project
# gutenberg
# literary
# archive
# foundation
# and
# how
# your
# efforts
# and
# donations
# can
# help
# see
# sections
# 3
# and
# 4
# and
# the
# foundation
# web
# page
# at
# httpwwwpglaforg
#
#
# section
# 3
#
# information
# about
# the
# project
# gutenberg
# literary
# archive
# foundation
#
# the
# project
# gutenberg
# literary
# archive
# foundation
# is
# a
# non
# profit
# 501c3
# educational
# corporation
# organized
# under
# the
# laws
# of
# the
# state
# of
# mississippi
# and
# granted
# tax
# exempt
# status
# by
# the
# internal
# revenue
# service
#
# the
# foundations
# ein
# or
# federal
# tax
# identification
# number
# is
# 646221541
#
# its
# 501c3
# letter
# is
# posted
# at
# httppglaforgfundraising
#
# contributions
# to
# the
# project
# gutenberg
# literary
# archive
# foundation
# are
# tax
# deductible
# to
# the
# full
# extent
# permitted
# by
# us
# federal
# laws
# and
# your
# states
# laws
#
# the
# foundations
# principal
# office
# is
# located
# at
# 4557
# melan
# dr
# s
# fairbanks
# ak
# 99712
# but
# its
# volunteers
# and
# employees
# are
# scattered
# throughout
# numerous
# locations
#
# its
# business
# office
# is
# located
# at
# 809
# north
# 1500
# west
# salt
# lake
# city
# ut
# 84116
# 801
# 5961887
# email
# businesspglaforg
#
# email
# contact
# links
# and
# up
# to
# date
# contact
# information
# can
# be
# found
# at
# the
# foundations
# web
# site
# and
# official
# page
# at
# httppglaforg
#
# for
# additional
# contact
# information
#
#
#
#
#
# dr
# gregory
# b
# newby
#
#
#
#
#
# chief
# executive
# and
# director
#
#
#
#
#
# gbnewbypglaforg
#
#
# section
# 4
#
# information
# about
# donations
# to
# the
# project
# gutenberg
# literary
# archive
# foundation
#
# project
# gutenbergtm
# depends
# upon
# and
# cannot
# survive
# without
# wide
# spread
# public
# support
# and
# donations
# to
# carry
# out
# its
# mission
# of
# increasing
# the
# number
# of
# public
# domain
# and
# licensed
# works
# that
# can
# be
# freely
# distributed
# in
# machine
# readable
# form
# accessible
# by
# the
# widest
# array
# of
# equipment
# including
# outdated
# equipment
#
# many
# small
# donations
# 1
# to
# 5000
# are
# particularly
# important
# to
# maintaining
# tax
# exempt
# status
# with
# the
# irs
#
# the
# foundation
# is
# committed
# to
# complying
# with
# the
# laws
# regulating
# charities
# and
# charitable
# donations
# in
# all
# 50
# states
# of
# the
# united
# states
#
# compliance
# requirements
# are
# not
# uniform
# and
# it
# takes
# a
# considerable
# effort
# much
# paperwork
# and
# many
# fees
# to
# meet
# and
# keep
# up
# with
# these
# requirements
#
# we
# do
# not
# solicit
# donations
# in
# locations
# where
# we
# have
# not
# received
# written
# confirmation
# of
# compliance
#
# to
# send
# donations
# or
# determine
# the
# status
# of
# compliance
# for
# any
# particular
# state
# visit
# httppglaforg
#
# while
# we
# cannot
# and
# do
# not
# solicit
# contributions
# from
# states
# where
# we
# have
# not
# met
# the
# solicitation
# requirements
# we
# know
# of
# no
# prohibition
# against
# accepting
# unsolicited
# donations
# from
# donors
# in
# such
# states
# who
# approach
# us
# with
# offers
# to
# donate
#
# international
# donations
# are
# gratefully
# accepted
# but
# we
# cannot
# make
# any
# statements
# concerning
# tax
# treatment
# of
# donations
# received
# from
# outside
# the
# united
# states
#
# us
# laws
# alone
# swamp
# our
# small
# staff
#
# please
# check
# the
# project
# gutenberg
# web
# pages
# for
# current
# donation
# methods
# and
# addresses
#
# donations
# are
# accepted
# in
# a
# number
# of
# other
# ways
# including
# checks
# online
# payments
# and
# credit
# card
# donations
# to
# donate
# please
# visit
# httppglaforgdonate
#
#
# section
# 5
#
# general
# information
# about
# project
# gutenbergtm
# electronic
# works
#
# professor
# michael
# s
# hart
# is
# the
# originator
# of
# the
# project
# gutenbergtm
# concept
# of
# a
# library
# of
# electronic
# works
# that
# could
# be
# freely
# shared
# with
# anyone
#
# for
# thirty
# years
# he
# produced
# and
# distributed
# project
# gutenbergtm
# ebooks
# with
# only
# a
# loose
# network
# of
# volunteer
# support
#
#
# project
# gutenbergtm
# ebooks
# are
# often
# created
# from
# several
# printed
# editions
# all
# of
# which
# are
# confirmed
# as
# public
# domain
# in
# the
# us
# unless
# a
# copyright
# notice
# is
# included
#
# thus
# we
# do
# not
# necessarily
# keep
# ebooks
# in
# compliance
# with
# any
# particular
# paper
# edition
#
#
# most
# people
# start
# at
# our
# web
# site
# which
# has
# the
# main
# pg
# search
# facility
#
#
#
#
#
#
# httpwwwgutenbergorg
#
# this
# web
# site
# includes
# information
# about
# project
# gutenbergtm
# including
# how
# to
# make
# donations
# to
# the
# project
# gutenberg
# literary
# archive
# foundation
# how
# to
# help
# produce
# our
# new
# ebooks
# and
# how
# to
# subscribe
# to
# our
# email
# newsletter
# to
# hear
# about
# new
# ebooks

# %% [markdown]
# # Exercise 1 : Count Words

# %% [markdown]
# **Count how many times each word occurs**

# %%
import re
precount = wordsRJ.map(lambda word : (word,1))
precount = precount.filter( lambda x : re.match(r"^[a-z]+$",x[0]))
count = precount.reduceByKey(lambda x,y : x+y)
for element in count.collect():
  print(element)

# %% [markdown]
# # Exercise 2: Finding Frequent Terms and Stop Words

# %%
# !pip install -U nltk

# %%
import nltk
nltk.download('stopwords')

from nltk.corpus import stopwords


spark.sparkContext.addFile("https://www.gutenberg.org/files/1524/1524-0.txt")
spark.sparkContext.addFile("https://www.gutenberg.org/cache/epub/1776/pg1776.txt")

wordsRJ = wordsRJ.filter( lambda x : re.match(r"^[a-z]+$",x))
wordsR = sc.textFile(SparkFiles.get("pg1776.txt")).flatMap(lambda x: x.split(' ') )\
                        .map(lambda x: lower_clean_str(x))\
                        .filter( lambda x : re.match(r"^[a-z]+$",x))
wordsH = sc.textFile(SparkFiles.get("1524-0.txt")).flatMap(lambda x: x.split(' ') )\
                        .map(lambda x: lower_clean_str(x))\
                        .filter( lambda x : re.match(r"^[a-z]+$",x))


  
stpW_RJ = wordsRJ.filter(lambda x: x in stopwords.words('english'))
stpW_R = wordsR.filter(lambda x: x in stopwords.words('english'))
stpW_H = wordsH.filter(lambda x: x in stopwords.words('english'))


union = stpW_RJ.union(stpW_R).union(stpW_H)

precountStpW = union.map(lambda word : (word,1))

count = precountStpW.reduceByKey(lambda x,y : x+y)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
result = count.map(lambda word : (word[1],word[0])).sortByKey(ascending=False)
for element in result.collect():
  print(element)
# Out:
# (3004, 'the')
# (2636, 'and')
# (2049, 'to')
# (1961, 'of')
# (1588, 'i')
# (1440, 'a')
# (1342, 'my')
# (1191, 'in')
# (1180, 'you')
# (1067, 'that')
# (1032, 'is')
# (877, 'with')
# (848, 'it')
# (841, 'not')
# (824, 'this')
# (764, 'for')
# (675, 'his')
# (672, 'me')
# (662, 'be')
# (616, 'but')
# (552, 'as')
# (505, 'your')
# (482, 'he')
# (481, 'what')
# (479, 'so')
# (456, 'have')
# (456, 'or')
# (434, 'will')
# (412, 'by')
# (410, 'him')
# (366, 'no')
# (361, 'do')
# (359, 'all')
# (352, 'are')
# (335, 'we')
# (322, 'our')
# (319, 'on')
# (314, 'from')
# (307, 'if')
# (305, 'o')
# (272, 'her')
# (256, 'at')
# (237, 'now')
# (226, 'they')
# (219, 'more')
# (214, 'which')
# (205, 'how')
# (201, 'then')
# (200, 'here')
# (188, 'there')
# (186, 'an')
# (175, 'was')
# (169, 'their')
# (165, 'she')
# (158, 'some')
# (158, 'am')
# (152, 'when')
# (152, 'them')
# (152, 'where')
# (147, 'such')
# (147, 'should')
# (146, 'than')
# (145, 'too')
# (143, 'did')
# (137, 'out')
# (137, 'any')
# (133, 'these')
# (130, 'up')
# (127, 'can')
# (126, 'why')
# (124, 'most')
# (115, 'who')
# (103, 'very')
# (101, 'had')
# (96, 'were')
# (88, 'other')
# (84, 'nor')
# (82, 'own')
# (82, 'again')
# (79, 'both')
# (76, 'down')
# (72, 'against')
# (67, 'before')
# (65, 'been')
# (54, 'into')
# (54, 'those')
# (53, 'being')
# (53, 'off')
# (53, 'about')
# (50, 'myself')
# (47, 'himself')
# (43, 'once')
# (41, 'itself')
# (36, 'under')
# (35, 'through')
# (33, 'only')
# (31, 'does')
# (30, 'while')
# (29, 'same')
# (27, 'after')
# (25, 'each')
# (24, 'further')
# (22, 'whom')
# (21, 'yourself')
# (19, 'because')
# (19, 'has')
# (19, 'between')
# (18, 'above')
# (16, 'ourselves')
# (13, 'herself')
# (13, 'below')
# (12, 'over')
# (11, 'having')
# (11, 'yours')
# (10, 'its')
# (8, 'just')
# (8, 'themselves')
# (8, 'few')
# (7, 'ours')
# (5, 'doing')
# (4, 'hers')
# (4, 'until')
# (4, 'yourselves')
# (4, 'won')
# (3, 'theirs')
# (3, 's')
# (2, 're')
# (2, 'm')
# (1, 't')

# %%
finalResult = spark.createDataFrame(result,["Count","Stop Word"])

finalResult.coalesce(1).write.mode('overwrite').option("header",True) \
            .csv("Count Stop-Word Result")

# %% [markdown]
# # Exercise 3 : Simple Inverted Index

# %%
W_RJ = wordsRJ.filter(lambda x: x not in stopwords.words('english')).filter( lambda x : re.match(r"^[a-z]+$",x))
      
W_R = wordsR.filter(lambda x: x not in stopwords.words('english')).filter( lambda x : re.match(r"^[a-z]+$",x))
W_H = wordsH.filter(lambda x: x not in stopwords.words('english')).filter( lambda x : re.match(r"^[a-z]+$",x))


W_RJ_m = W_RJ.map(lambda x: (x,'RomeoJuliet.txt') )
W_R_m = W_R.map(lambda x: (x,'RichardII.txt') )
W_H_m = W_H.map(lambda x: (x,'Hamlet.txt') )

union_ = W_RJ_m.union(W_R_m).union(W_H_m )

union_ = union_.distinct()


preResult = union_.map(lambda x: (x[0],[x[1]])).reduceByKey(lambda x,y: x+y)
#preResult = union_.groupByKey().map(lambda x: (x[0],list(x[1])))
Result = preResult.zipWithIndex().map(lambda x: (x[1],x[0][0],x[0][1]))

for element in Result.collect():
 print(element)
# Out:
# Streaming output truncated to the last 5000 lines.
# (3197, 'proclaims', ['Hamlet.txt'])
# (3198, 'bounteous', ['Hamlet.txt'])
# (3199, 'dearly', ['Hamlet.txt', 'RomeoJuliet.txt'])
# (3200, 'investments', ['Hamlet.txt'])
# (3201, 'pledge', ['Hamlet.txt', 'RichardII.txt'])
# (3202, 'breach', ['Hamlet.txt', 'RomeoJuliet.txt', 'RichardII.txt'])
# (3203, 'observance', ['Hamlet.txt'])
# (3204, 'origin', ['Hamlet.txt'])
# (3205, 'making', ['Hamlet.txt', 'RomeoJuliet.txt', 'RichardII.txt'])
# (3206, 'horridly', ['Hamlet.txt'])
# (3207, 'nerve', ['Hamlet.txt'])
# (3208, 'unhand', ['Hamlet.txt'])
# (3209, 'render', ['Hamlet.txt', 'RichardII.txt'])
# (3210, 'days', ['Hamlet.txt', 'RomeoJuliet.txt', 'RichardII.txt'])
# (3211, 'fretful', ['Hamlet.txt'])
# (3212, 'rots', ['Hamlet.txt'])
# (3213, 'wharf', ['Hamlet.txt'])
# (3214, 'vial', ['Hamlet.txt', 'RomeoJuliet.txt', 'RichardII.txt'])
# (3215, 'reveal', ['Hamlet.txt'])
# (3216, 'dwelling', ['Hamlet.txt'])
# (3217, 'already', ['Hamlet.txt', 'RomeoJuliet.txt', 'RichardII.txt'])
# (3218, 'wondrous', ['Hamlet.txt', 'RomeoJuliet.txt'])
# (3219, 'dreamt', ['Hamlet.txt', 'RomeoJuliet.txt'])
# (3220, 'rest', ['Hamlet.txt', 'RichardII.txt', 'RomeoJuliet.txt'])
# (3221, 'inquiry', ['Hamlet.txt'])
# (3222, 'fordoes', ['Hamlet.txt'])
# (3223, 'moreover', ['Hamlet.txt', 'RichardII.txt'])
# (3224, 'majesties', ['Hamlet.txt'])
# (3225, 'changed', ['Hamlet.txt'])
# (3226, 'preparation', ['Hamlet.txt'])
# (3227, 'borne', ['Hamlet.txt', 'RomeoJuliet.txt', 'RichardII.txt'])
# (3228, 'employ', ['Hamlet.txt'])
# (3229, 'solicitings', ['Hamlet.txt'])
# (3230, 'thereon', ['Hamlet.txt'])
# (3231, 'godamercy', ['Hamlet.txt'])
# (3232, 'gum', ['Hamlet.txt'])
# (3233, 'honesty', ['Hamlet.txt', 'RomeoJuliet.txt'])
# (3234, 'inclining', ['Hamlet.txt'])
# (3235, 'vapours', ['Hamlet.txt'])
# (3236, 'wearing', ['Hamlet.txt', 'RomeoJuliet.txt'])
# (3237, 'actor', ['Hamlet.txt', 'RichardII.txt'])
# (3238, 'buzz', ['Hamlet.txt'])
# (3239, 'pastoralcomical', ['Hamlet.txt'])
# (3240, 'jephthah', ['Hamlet.txt'])
# (3241, 'matters', ['Hamlet.txt'])
# (3242, 'spoken', ['Hamlet.txt', 'RomeoJuliet.txt', 'RichardII.txt'])
# (3243, 'rage', ['Hamlet.txt', 'RomeoJuliet.txt', 'RichardII.txt'])
# (3244, 'strikes', ['Hamlet.txt', 'RichardII.txt'])
# (3245, 'distraction', ['Hamlet.txt'])
# (3246, 'calls', ['Hamlet.txt', 'RomeoJuliet.txt', 'RichardII.txt'])
# (3247, 'sugar', ['Hamlet.txt', 'RichardII.txt'])
# (3248, 'beautied', ['Hamlet.txt'])
# (3249, 'contumely', ['Hamlet.txt'])
# (3250, 'regard', ['Hamlet.txt', 'RichardII.txt'])
# (3251, 'givers', ['Hamlet.txt'])
# (3252, 'translate', ['Hamlet.txt'])
# (3253, 'believed', ['Hamlet.txt'])
# (3254, 'relish', ['Hamlet.txt'])
# (3255, 'hatch', ['Hamlet.txt'])
# (3256, 'pressure', ['Hamlet.txt'])
# (3257, 'judicious', ['Hamlet.txt'])
# (3258, 'pomp', ['Hamlet.txt', 'RichardII.txt'])
# (3259, 'suffering', ['Hamlet.txt', 'RichardII.txt'])
# (3260, 'wear', ['Hamlet.txt', 'RomeoJuliet.txt', 'RichardII.txt'])
# (3261, 'imaginations', ['Hamlet.txt'])
# (3262, 'lovingly', ['Hamlet.txt'])
# (3263, 'protestation', ['Hamlet.txt'])
# (3264, 'asleep', ['Hamlet.txt', 'RomeoJuliet.txt'])
# (3265, 'woos', ['Hamlet.txt'])
# (3266, 'moons', ['Hamlet.txt', 'RichardII.txt'])
# (3267, 'functions', ['Hamlet.txt'])
# (3268, 'hollow', ['Hamlet.txt', 'RomeoJuliet.txt', 'RichardII.txt'])
# (3269, 'dallying', ['Hamlet.txt'])
# (3270, 'weeds', ['Hamlet.txt', 'RomeoJuliet.txt', 'RichardII.txt'])
# (3271, 'trade', ['Hamlet.txt', 'RichardII.txt'])
# (3272, 'bar', ['Hamlet.txt'])
# (3273, 'harmony', ['Hamlet.txt', 'RichardII.txt'])
# (3274, 'weasel', ['Hamlet.txt'])
# (3275, 'single', ['Hamlet.txt', 'RomeoJuliet.txt'])
# (3276, 'sickly', ['Hamlet.txt'])
# (3277, 'intruding', ['Hamlet.txt'])
# (3278, 'blister', ['Hamlet.txt'])
# (3279, 'contraction', ['Hamlet.txt'])
# (3280, 'compound', ['Hamlet.txt'])
# (3281, 'hoodmanblind', ['Hamlet.txt'])
# (3282, 'spots', ['Hamlet.txt', 'RichardII.txt'])
# (3283, 'cutpurse', ['Hamlet.txt'])
# (3284, 'flame', ['Hamlet.txt'])
# (3285, 'curb', ['Hamlet.txt'])
# (3286, 'scourge', ['Hamlet.txt', 'RomeoJuliet.txt'])
# (3287, 'birds', ['Hamlet.txt', 'RomeoJuliet.txt', 'RichardII.txt'])
# (3288, 'schoolfellows', ['Hamlet.txt'])
# (3289, 'guts', ['Hamlet.txt'])
# (3290, 'mightier', ['Hamlet.txt'])
# (3291, 'mouthed', ['Hamlet.txt'])
# (3292, 'multitude', ['Hamlet.txt'])
# (3293, 'dishes', ['Hamlet.txt'])
# (3294, 'fish', ['Hamlet.txt', 'RomeoJuliet.txt'])
# (3295, 'purposes', ['Hamlet.txt'])
# (3296, 'thereof', ['Hamlet.txt', 'RomeoJuliet.txt'])
# (3297, 'marching', ['Hamlet.txt'])
# (3298, 'event', ['Hamlet.txt'])
# (3299, 'continent', ['Hamlet.txt'])
# (3300, 'unhappily', ['Hamlet.txt'])
# (3301, 'bewept', ['Hamlet.txt'])
# (3302, 'buzzers', ['Hamlet.txt'])
# (3303, 'following', ['Hamlet.txt', 'RichardII.txt', 'RomeoJuliet.txt'])
# (3304, 'satisfaction', ['Hamlet.txt', 'RomeoJuliet.txt'])
# (3305, 'greeted', ['Hamlet.txt'])
# (3306, 'moves', ['Hamlet.txt', 'RomeoJuliet.txt'])
# (3307, 'public', ['Hamlet.txt', 'RomeoJuliet.txt', 'RichardII.txt'])
# (3308, 'turneth', ['Hamlet.txt'])
# (3309, 'blaze', ['Hamlet.txt', 'RomeoJuliet.txt', 'RichardII.txt'])
# (3310, 'digs', ['Hamlet.txt'])
# (3311, 'daintier', ['Hamlet.txt'])
# (3312, 'politician', ['Hamlet.txt'])
# (3313, 'ache', ['Hamlet.txt', 'RomeoJuliet.txt'])
# (3314, 'cases', ['Hamlet.txt'])
# (3315, 'shovel', ['Hamlet.txt'])
# (3316, 'battery', ['Hamlet.txt'])
# (3317, 'breadth', ['Hamlet.txt'])
# (3318, 'losing', ['Hamlet.txt'])
# (3319, 'consider', ['Hamlet.txt'])
# (3320, 'shards', ['Hamlet.txt'])
# (3321, 'bringing', ['Hamlet.txt', 'RomeoJuliet.txt'])
# (3322, 'profane', ['Hamlet.txt', 'RomeoJuliet.txt', 'RichardII.txt'])
# (3323, 'sage', ['Hamlet.txt'])
# (3324, 'mutinies', ['Hamlet.txt'])
# (3325, 'bilboes', ['Hamlet.txt'])
# (3326, 'rashness', ['Hamlet.txt'])
# (3327, 'plots', ['Hamlet.txt'])
# (3328, 'ordinant', ['Hamlet.txt'])
# (3329, 'incensed', ['Hamlet.txt'])
# (3330, 'interim', ['Hamlet.txt'])
# (3331, 'perdition', ['Hamlet.txt'])
# (3332, 'really', ['Hamlet.txt'])
# (3333, 'assigns', ['Hamlet.txt'])
# (3334, 'exceed', ['Hamlet.txt'])
# (3335, 'arrow', ['Hamlet.txt', 'RomeoJuliet.txt'])
# (3336, 'search', ['Hamlet.txt', 'RomeoJuliet.txt'])
# (3337, 'happen', ['Hamlet.txt', 'RichardII.txt'])
# (3338, 'requirements', ['Hamlet.txt', 'RomeoJuliet.txt'])
# (3339, 'disk', ['Hamlet.txt', 'RomeoJuliet.txt', 'RichardII.txt'])
# (3340, 'punitive', ['Hamlet.txt', 'RichardII.txt', 'RomeoJuliet.txt'])
# (3341, 'agent', ['Hamlet.txt', 'RomeoJuliet.txt'])
# (3342, 'internal', ['Hamlet.txt', 'RomeoJuliet.txt'])
# (3343, 'project', ['RomeoJuliet.txt', 'RichardII.txt', 'Hamlet.txt'])
# (3344, 'anyone', ['RomeoJuliet.txt', 'Hamlet.txt', 'RichardII.txt'])
# (3345, 'version', ['RomeoJuliet.txt', 'Hamlet.txt', 'RichardII.txt'])
# (3346, 'long', ['RomeoJuliet.txt', 'RichardII.txt', 'Hamlet.txt'])
# (3347, 'commercial', ['RomeoJuliet.txt', 'RichardII.txt', 'Hamlet.txt'])
# (3348, 'kinsman', ['RomeoJuliet.txt', 'RichardII.txt'])
# (3349, 'gregory', ['RomeoJuliet.txt'])
# (3350, 'unclean', ['RomeoJuliet.txt'])
# (3351, 'continuance', ['RomeoJuliet.txt'])
# (3352, 'house', ['RomeoJuliet.txt', 'RichardII.txt', 'Hamlet.txt'])
# (3353, 'push', ['RomeoJuliet.txt'])
# (3354, 'thy', ['RomeoJuliet.txt', 'Hamlet.txt', 'RichardII.txt'])
# (3355, 'abr', ['RomeoJuliet.txt'])
# (3356, 'upon', ['RomeoJuliet.txt', 'RichardII.txt', 'Hamlet.txt'])
# (3357, 'go', ['RomeoJuliet.txt', 'RichardII.txt', 'Hamlet.txt'])
# (3358, 'thrusts', ['RomeoJuliet.txt'])
# (3359, 'furthest', ['RomeoJuliet.txt', 'RichardII.txt'])
# (3360, 'pens', ['RomeoJuliet.txt'])
# (3361, 'sweet', ['RomeoJuliet.txt', 'Hamlet.txt', 'RichardII.txt'])
# (3362, 'grievance', ['RomeoJuliet.txt'])
# (3363, 'tell', ['RomeoJuliet.txt', 'RichardII.txt', 'Hamlet.txt'])
# (3364, 'sea', ['RomeoJuliet.txt', 'RichardII.txt', 'Hamlet.txt'])
# (3365, 'siege', ['RomeoJuliet.txt', 'RichardII.txt', 'Hamlet.txt'])
# (3366, 'chaste', ['RomeoJuliet.txt', 'Hamlet.txt'])
# (3367, 'wisely', ['RomeoJuliet.txt', 'Hamlet.txt'])
# (3368, 'think', ['RomeoJuliet.txt', 'RichardII.txt', 'Hamlet.txt'])
# (3369, 'penalty', ['RomeoJuliet.txt'])
# (3370, 'never', ['RomeoJuliet.txt', 'Hamlet.txt', 'RichardII.txt'])
# (3371, 'gi', ['RomeoJuliet.txt'])
# (3372, 'martino', ['RomeoJuliet.txt'])
# (3373, 'scales', ['RomeoJuliet.txt'])
# (3374, 'husband', ['RomeoJuliet.txt', 'Hamlet.txt', 'RichardII.txt'])
# (3375, 'perilous', ['RomeoJuliet.txt', 'Hamlet.txt'])
# (3376, 'prettiest', ['RomeoJuliet.txt'])
# (3377, 'thus', ['RomeoJuliet.txt', 'RichardII.txt', 'Hamlet.txt'])
# (3378, 'fly', ['RomeoJuliet.txt', 'Hamlet.txt', 'RichardII.txt'])
# (3379, 'beetle', ['RomeoJuliet.txt'])
# (3380, 'senseless', ['RomeoJuliet.txt', 'Hamlet.txt', 'RichardII.txt'])
# (3381, 'midwife', ['RomeoJuliet.txt', 'RichardII.txt'])
# (3382, 'crickets', ['RomeoJuliet.txt'])
# (3383, 'kisses', ['RomeoJuliet.txt', 'Hamlet.txt'])
# (3384, 'healths', ['RomeoJuliet.txt'])
# (3385, 'nell', ['RomeoJuliet.txt'])
# (3386, 'girls', ['RomeoJuliet.txt'])
# (3387, 'fiveandtwenty', ['RomeoJuliet.txt'])
# (3388, 'antic', ['RomeoJuliet.txt', 'Hamlet.txt', 'RichardII.txt'])
# (3389, 'fleer', ['RomeoJuliet.txt'])
# (3390, 'wherefore', ['RomeoJuliet.txt', 'RichardII.txt', 'Hamlet.txt'])
# (3391, 'storm', ['RomeoJuliet.txt', 'RichardII.txt', 'Hamlet.txt'])
# (3392, 'chance', ['RomeoJuliet.txt', 'RichardII.txt', 'Hamlet.txt'])
# (3393, 'different', ['RomeoJuliet.txt', 'Hamlet.txt'])
# (3394, 'intrusion', ['RomeoJuliet.txt'])
# (3395, 'prayers', ['RomeoJuliet.txt', 'RichardII.txt', 'Hamlet.txt'])
# (3396, 'chinks', ['RomeoJuliet.txt'])
# (3397, 'enemy', ['RomeoJuliet.txt', 'RichardII.txt', 'Hamlet.txt'])
# (3398, 'trim', ['RomeoJuliet.txt'])
# (3399, 'rosalines', ['RomeoJuliet.txt'])
# (3400, 'circle', ['RomeoJuliet.txt'])
# (3401, 'conjurd', ['RomeoJuliet.txt'])
# (3402, 'invocation', ['RomeoJuliet.txt'])
# (3403, 'tree', ['RomeoJuliet.txt', 'Hamlet.txt'])
# (3404, 'trucklebed', ['RomeoJuliet.txt'])
# (3405, 'spheres', ['RomeoJuliet.txt', 'Hamlet.txt'])
# (3406, 'sing', ['RomeoJuliet.txt', 'RichardII.txt', 'Hamlet.txt'])
# (3407, 'leans', ['RomeoJuliet.txt', 'Hamlet.txt'])
# (3408, 'murther', ['RomeoJuliet.txt'])
# (3409, 'peril', ['RomeoJuliet.txt'])
# (3410, 'fain', ['RomeoJuliet.txt', 'Hamlet.txt'])
# (3411, 'perverse', ['RomeoJuliet.txt'])
# (3412, 'confess', ['RomeoJuliet.txt', 'Hamlet.txt', 'RichardII.txt'])
# (3413, 'remembring', ['RomeoJuliet.txt', 'RichardII.txt'])
# (3414, 'lovingjealous', ['RomeoJuliet.txt'])
# (3415, 'eastern', ['RomeoJuliet.txt', 'RichardII.txt'])
# (3416, 'titans', ['RomeoJuliet.txt'])
# (3417, 'uprousd', ['RomeoJuliet.txt'])
# (3418, 'changd', ['RomeoJuliet.txt', 'RichardII.txt'])
# (3419, 'waverer', ['RomeoJuliet.txt'])
# (3420, 'letter', ['RomeoJuliet.txt', 'Hamlet.txt'])
# (3421, 'punto', ['RomeoJuliet.txt'])
# (3422, 'added', ['RomeoJuliet.txt', 'RichardII.txt'])
# (3423, 'drivelling', ['RomeoJuliet.txt'])
# (3424, 'noon', ['RomeoJuliet.txt'])
# (3425, 'pie', ['RomeoJuliet.txt'])
# (3426, 'knave', ['RomeoJuliet.txt', 'RichardII.txt', 'Hamlet.txt'])
# (3427, 'offred', ['RomeoJuliet.txt', 'RichardII.txt'])
# (3428, 'putting', ['RomeoJuliet.txt'])
# (3429, 'apace', ['RomeoJuliet.txt'])
# (3430, 'suns', ['RomeoJuliet.txt'])
# (3431, 'poultice', ['RomeoJuliet.txt'])
# (3432, 'messages', ['RomeoJuliet.txt'])
# (3433, 'lovedevouring', ['RomeoJuliet.txt'])
# (3434, 'musics', ['RomeoJuliet.txt'])
# (3435, 'claps', ['RomeoJuliet.txt'])
# (3436, 'quarrels', ['RomeoJuliet.txt', 'RichardII.txt'])
# (3437, 'addle', ['RomeoJuliet.txt'])
# (3438, 'quarter', ['RomeoJuliet.txt'])
# (3439, 'outrage', ['RomeoJuliet.txt', 'RichardII.txt'])
# (3440, 'page', ['RomeoJuliet.txt', 'RichardII.txt', 'Hamlet.txt'])
# (3441, 'gallant', ['RomeoJuliet.txt', 'RichardII.txt', 'Hamlet.txt'])
# (3442, 'uttered', ['RomeoJuliet.txt'])
# (3443, 'points', ['RomeoJuliet.txt', 'RichardII.txt', 'Hamlet.txt'])
# (3444, 'deathdarting', ['RomeoJuliet.txt'])
# (3445, 'dearlovd', ['RomeoJuliet.txt'])
# (3446, 'trumpet', ['RomeoJuliet.txt', 'Hamlet.txt', 'RichardII.txt'])
# (3447, 'bower', ['RomeoJuliet.txt'])
# (3448, 'perjurd', ['RomeoJuliet.txt'])
# (3449, 'tributary', ['RomeoJuliet.txt', 'Hamlet.txt'])
# (3450, 'murdred', ['RomeoJuliet.txt'])
# (3451, 'lamentation', ['RomeoJuliet.txt'])
# (3452, 'wailing', ['RomeoJuliet.txt'])
# (3453, 'exild', ['RomeoJuliet.txt', 'RichardII.txt'])
# (3454, 'courtship', ['RomeoJuliet.txt', 'RichardII.txt'])
# (3455, 'temperd', ['RomeoJuliet.txt'])
# (3456, 'skilless', ['RomeoJuliet.txt'])
# (3457, 'earl', ['RomeoJuliet.txt', 'RichardII.txt'])
# (3458, 'severing', ['RomeoJuliet.txt'])
# (3459, 'grey', ['RomeoJuliet.txt', 'Hamlet.txt'])
# (3460, 'omit', ['RomeoJuliet.txt'])
# (3461, 'miles', ['RomeoJuliet.txt', 'RichardII.txt'])
# (3462, 'hurdle', ['RomeoJuliet.txt'])
# (3463, 'gossips', ['RomeoJuliet.txt'])
# (3464, 'graze', ['RomeoJuliet.txt'])
# (3465, 'starve', ['RomeoJuliet.txt'])
# (3466, 'acknowledge', ['RomeoJuliet.txt'])
# (3467, 'eagle', ['RomeoJuliet.txt'])
# (3468, 'praisd', ['RomeoJuliet.txt'])
# (3469, 'shield', ['RomeoJuliet.txt'])
# (3470, 'compass', ['RomeoJuliet.txt', 'Hamlet.txt', 'RichardII.txt'])
# (3471, 'unstaind', ['RomeoJuliet.txt'])
# (3472, 'abate', ['RomeoJuliet.txt', 'Hamlet.txt'])
# (3473, 'hire', ['RomeoJuliet.txt', 'Hamlet.txt'])
# (3474, 'begone', ['RomeoJuliet.txt'])
# (3475, 'selfwilld', ['RomeoJuliet.txt'])
# (3476, 'knot', ['RomeoJuliet.txt'])
# (3477, 'kinsmans', ['RomeoJuliet.txt'])
# (3478, 'cotquean', ['RomeoJuliet.txt'])
# (3479, 'soninlaw', ['RomeoJuliet.txt'])
# (3480, 'dump', ['RomeoJuliet.txt'])
# (3481, 'james', ['RomeoJuliet.txt'])
# (3482, 'soundpost', ['RomeoJuliet.txt'])
# (3483, 'singer', ['RomeoJuliet.txt'])
# (3484, 'bosoms', ['RomeoJuliet.txt'])
# (3485, 'thinly', ['RomeoJuliet.txt'])
# (3486, 'fearest', ['RomeoJuliet.txt'])
# (3487, 'unfirm', ['RomeoJuliet.txt'])
# (3488, 'graves', ['RomeoJuliet.txt', 'RichardII.txt', 'Hamlet.txt'])
# (3489, 'wanders', ['RomeoJuliet.txt'])
# (3490, 'morsel', ['RomeoJuliet.txt'])
# (3491, 'apprehend', ['RomeoJuliet.txt'])
# (3492, 'conjuration', ['RomeoJuliet.txt', 'RichardII.txt', 'Hamlet.txt'])
# (3493, 'triumphant', ['RomeoJuliet.txt', 'RichardII.txt'])
# (3494, 'seal', ['RomeoJuliet.txt', 'RichardII.txt', 'Hamlet.txt'])
# (3495, 'engrossing', ['RomeoJuliet.txt'])
# (3496, 'guide', ['RomeoJuliet.txt'])
# (3497, 'returnd', ['RomeoJuliet.txt', 'RichardII.txt'])
# (3498, 'severest', ['RomeoJuliet.txt'])
# (3499, 'renamed', ['RomeoJuliet.txt', 'Hamlet.txt'])
# (3500, 'paying', ['RomeoJuliet.txt', 'Hamlet.txt'])
# (3501, 'modified', ['RomeoJuliet.txt', 'Hamlet.txt'])
# (3502, 'agreement', ['RomeoJuliet.txt', 'Hamlet.txt'])
# (3503, 'paragraph', ['RomeoJuliet.txt', 'Hamlet.txt'])
# (3504, 'check', ['RomeoJuliet.txt', 'RichardII.txt', 'Hamlet.txt'])
# (3505, 'accessed', ['RomeoJuliet.txt', 'Hamlet.txt'])
# (3506, 'site', ['RomeoJuliet.txt', 'RichardII.txt'])
# (3507, 'derive', ['RomeoJuliet.txt', 'Hamlet.txt'])
# (3508, 'reported', ['RomeoJuliet.txt', 'Hamlet.txt'])
# (3509, 'efforts', ['RomeoJuliet.txt', 'Hamlet.txt'])
# (3510, 'expenses', ['RomeoJuliet.txt', 'RichardII.txt', 'Hamlet.txt'])
# (3511, 'particular', ['RomeoJuliet.txt', 'RichardII.txt', 'Hamlet.txt'])
# (3512, 'produce', ['RomeoJuliet.txt', 'RichardII.txt', 'Hamlet.txt'])
# (3513, 'presented', ['RichardII.txt'])
# (3514, 'give', ['RichardII.txt', 'RomeoJuliet.txt', 'Hamlet.txt'])
# (3515, 'bility', ['RichardII.txt'])
# (3516, 'accepts', ['RichardII.txt', 'Hamlet.txt'])
# (3517, 'bolingbroke', ['RichardII.txt'])
# (3518, 'wales', ['RichardII.txt'])
# (3519, 'timehonoured', ['RichardII.txt'])
# (3520, 'thou', ['RichardII.txt', 'RomeoJuliet.txt', 'Hamlet.txt'])
# (3521, 'appeal', ['RichardII.txt'])
# (3522, 'malice', ['RichardII.txt'])
# (3523, 'aimd', ['RichardII.txt', 'RomeoJuliet.txt'])
# (3524, 'accused', ['RichardII.txt'])
# (3525, 'speak', ['RichardII.txt', 'RomeoJuliet.txt', 'Hamlet.txt'])
# (3526, 'tendring', ['RichardII.txt'])
# (3527, 'curbs', ['RichardII.txt'])
# (3528, 'doubled', ['RichardII.txt'])
# (3529, 'tied', ['RichardII.txt'])
# (3530, 'loyalty', ['RichardII.txt'])
# (3531, 'employments', ['RichardII.txt'])
# (3532, 'innocent', ['RichardII.txt', 'Hamlet.txt'])
# (3533, 'cries', ['RichardII.txt', 'RomeoJuliet.txt', 'Hamlet.txt'])
# (3534, 'glorious', ['RichardII.txt', 'RomeoJuliet.txt'])
# (3535, 'bid', ['RichardII.txt', 'Hamlet.txt', 'RomeoJuliet.txt'])
# (3536, 'slew', ['RichardII.txt', 'RomeoJuliet.txt'])
# (3537, 'shalt', ['RichardII.txt', 'RomeoJuliet.txt', 'Hamlet.txt'])
# (3538, 'despite', ['RichardII.txt', 'RomeoJuliet.txt', 'Hamlet.txt'])
# (3539, 'barrdup', ['RichardII.txt'])
# (3540, 'swelling', ['RichardII.txt'])
# (3541, 'model', ['RichardII.txt', 'Hamlet.txt'])
# (3542, 'appelants', ['RichardII.txt'])
# (3543, 'truly', ['RichardII.txt', 'RomeoJuliet.txt', 'Hamlet.txt'])
# (3544, 'standeth', ['RichardII.txt'])
# (3545, 'consults', ['RichardII.txt'])
# (3546, 'unstringed', ['RichardII.txt'])
# (3547, 'viol', ['RichardII.txt'])
# (3548, 'gaoler', ['RichardII.txt'])
# (3549, 'robs', ['RichardII.txt'])
# (3550, 'complot', ['RichardII.txt'])
# (3551, 'wandred', ['RichardII.txt'])
# (3552, 'rue', ['RichardII.txt', 'Hamlet.txt'])
# (3553, 'springs', ['RichardII.txt', 'Hamlet.txt'])
# (3554, 'seemst', ['RichardII.txt', 'RomeoJuliet.txt'])
# (3555, 'enforced', ['RichardII.txt'])
# (3556, 'jewels', ['RichardII.txt'])
# (3557, 'devouring', ['RichardII.txt'])
# (3558, 'edge', ['RichardII.txt', 'Hamlet.txt'])
# (3559, 'craft', ['RichardII.txt', 'Hamlet.txt'])
# (3560, 'dive', ['RichardII.txt'])
# (3561, 'goes', ['RichardII.txt', 'Hamlet.txt', 'RomeoJuliet.txt'])
# (3562, 'draymen', ['RichardII.txt'])
# (3563, 'reversion', ['RichardII.txt'])
# (3564, 'ireland', ['RichardII.txt'])
# (3565, 'enforcd', ['RichardII.txt'])
# (3566, 'enforce', ['RichardII.txt', 'RomeoJuliet.txt'])
# (3567, 'insatiate', ['RichardII.txt'])
# (3568, 'parchment', ['RichardII.txt', 'Hamlet.txt'])
# (3569, 'leanness', ['RichardII.txt'])
# (3570, 'sicker', ['RichardII.txt'])
# (3571, 'flatterers', ['RichardII.txt'])
# (3572, 'grandsire', ['RichardII.txt', 'Hamlet.txt', 'RomeoJuliet.txt'])
# (3573, 'regent', ['RichardII.txt'])
# (3574, 'shoulders', ['RichardII.txt'])
# (3575, 'assistance', ['RichardII.txt', 'Hamlet.txt', 'RomeoJuliet.txt'])
# (3576, 'pleasd', ['RichardII.txt'])
# (3577, 'barely', ['RichardII.txt'])
# (3578, 'blemishd', ['RichardII.txt'])
# (3579, 'gazd', ['RichardII.txt'])
# (3580, 'something', ['RichardII.txt', 'Hamlet.txt', 'RomeoJuliet.txt'])
# (3581, 'parasite', ['RichardII.txt'])
# (3582, 'tide', ['RichardII.txt'])
# (3583, 'saypray', ['RichardII.txt'])
# (3584, 'forces', ['RichardII.txt', 'Hamlet.txt'])
# (3585, 'upstart', ['RichardII.txt'])
# (3586, 'country', ['RichardII.txt', 'RomeoJuliet.txt', 'Hamlet.txt'])
# (3587, 'fed', ['RichardII.txt', 'Hamlet.txt'])
# (3588, 'parks', ['RichardII.txt'])
# (3589, 'toads', ['RichardII.txt'])
# (3590, 'succour', ['RichardII.txt'])
# (3591, 'pines', ['RichardII.txt'])
# (3592, 'wandring', ['RichardII.txt'])
# (3593, 'worldly', ['RichardII.txt'])
# (3594, 'shrewd', ['RichardII.txt'])
# (3595, 'clouded', ['RichardII.txt'])
# (3596, 'swells', ['RichardII.txt'])
# (3597, 'rusty', ['RichardII.txt', 'Hamlet.txt'])
# (3598, 'deposed', ['RichardII.txt'])
# (3599, 'infusing', ['RichardII.txt'])
# (3600, 'torturer', ['RichardII.txt'])
# (3601, 'hide', ['RichardII.txt', 'RomeoJuliet.txt', 'Hamlet.txt'])
# (3602, 'ribs', ['RichardII.txt'])
# (3603, 'waterson', ['RichardII.txt'])
# (3604, 'stood', ['RichardII.txt', 'Hamlet.txt'])
# (3605, 'vassal', ['RichardII.txt'])
# (3606, 'currents', ['RichardII.txt', 'Hamlet.txt'])
# (3607, 'comprising', ['RichardII.txt'])
# (3608, 'swellst', ['RichardII.txt'])
# (3609, 'wantons', ['RichardII.txt', 'RomeoJuliet.txt'])
# (3610, 'laugh', ['RichardII.txt', 'RomeoJuliet.txt', 'Hamlet.txt'])
# (3611, 'jades', ['RichardII.txt'])
# (3612, 'repeat', ['RichardII.txt'])
# (3613, 'wretchedness', ['RichardII.txt', 'RomeoJuliet.txt'])
# (3614, 'dangling', ['RichardII.txt'])
# (3615, 'herbs', ['RichardII.txt', 'RomeoJuliet.txt'])
# (3616, 'skull', ['RichardII.txt', 'Hamlet.txt'])
# (3617, 'saracens', ['RichardII.txt'])
# (3618, 'adopts', ['RichardII.txt'])
# (3619, 'argued', ['RichardII.txt'])
# (3620, 'reenter', ['RichardII.txt', 'Hamlet.txt'])
# (3621, 'sunshine', ['RichardII.txt'])
# (3622, 'deem', ['RichardII.txt'])
# (3623, 'tundeck', ['RichardII.txt'])
# (3624, 'deeper', ['RichardII.txt'])
# (3625, 'wink', ['RichardII.txt', 'RomeoJuliet.txt'])
# (3626, 'boon', ['RichardII.txt'])
# (3627, 'julius', ['RichardII.txt', 'Hamlet.txt'])
# (3628, 'caesars', ['RichardII.txt'])
# (3629, 'lodgd', ['RichardII.txt'])
# (3630, 'grim', ['RichardII.txt'])
# (3631, 'humility', ['RichardII.txt'])
# (3632, 'converts', ['RichardII.txt'])
# (3633, 'crieth', ['RichardII.txt'])
# (3634, 'hypocrisy', ['RichardII.txt'])
# (3635, 'integrity', ['RichardII.txt'])
# (3636, 'wishtly', ['RichardII.txt'])
# (3637, 'scruples', ['RichardII.txt'])
# (3638, 'wonders', ['RichardII.txt'])
# (3639, 'dials', ['RichardII.txt'])
# (3640, 'clamorous', ['RichardII.txt'])
# (3641, 'strange', ['RichardII.txt', 'Hamlet.txt', 'RomeoJuliet.txt'])
# (3642, 'brooch', ['RichardII.txt', 'Hamlet.txt'])
# (3643, 'stable', ['RichardII.txt'])
# (3644, 'groats', ['RichardII.txt'])
# (3645, 'travelling', ['RichardII.txt'])
# (3646, 'commands', ['RichardII.txt', 'Hamlet.txt'])
# (3647, 'brocas', ['RichardII.txt'])
# (3648, 'may', ['Hamlet.txt', 'RomeoJuliet.txt', 'RichardII.txt'])
# (3649, 'reynaldo', ['Hamlet.txt'])
# (3650, 'opinion', ['Hamlet.txt'])
# (3651, 'image', ['Hamlet.txt'])
# (3652, 'armed', ['Hamlet.txt', 'RichardII.txt'])
# (3653, 'invulnerable', ['Hamlet.txt'])
# (3654, 'crew', ['Hamlet.txt', 'RichardII.txt'])
# (3655, 'hies', ['Hamlet.txt'])
# (3656, 'walks', ['Hamlet.txt', 'RomeoJuliet.txt'])
# (3657, 'dropping', ['Hamlet.txt'])
# (3658, 'equal', ['Hamlet.txt', 'RichardII.txt'])
# (3659, 'news', ['Hamlet.txt', 'RomeoJuliet.txt', 'RichardII.txt'])
# (3660, 'laboursome', ['Hamlet.txt'])
# (3661, 'duties', ['Hamlet.txt'])
# (3662, 'incorrect', ['Hamlet.txt'])
# (3663, 'accord', ['Hamlet.txt'])
# (3664, 'respeaking', ['Hamlet.txt'])
# (3665, 'unweeded', ['Hamlet.txt'])
# (3666, 'unrighteous', ['Hamlet.txt'])
# (3667, 'motion', ['Hamlet.txt', 'RomeoJuliet.txt'])
# (3668, 'beaver', ['Hamlet.txt'])
# (3669, 'tried', ['Hamlet.txt', 'RomeoJuliet.txt'])
# (3670, 'humbly', ['Hamlet.txt', 'RomeoJuliet.txt', 'RichardII.txt'])
# (3671, 'parley', ['Hamlet.txt', 'RichardII.txt'])
# (3672, 'tether', ['Hamlet.txt'])
# (3673, 'drains', ['Hamlet.txt'])
# (3674, 'nations', ['Hamlet.txt'])
# (3675, 'vicious', ['Hamlet.txt'])
# (3676, 'blasts', ['Hamlet.txt'])
# (3677, 'charitable', ['Hamlet.txt', 'RomeoJuliet.txt'])
# (3678, 'deprive', ['Hamlet.txt'])
# (3679, 'artery', ['Hamlet.txt'])
# (3680, 'gifts', ['Hamlet.txt'])
# (3681, 'lust', ['Hamlet.txt'])
# (3682, 'patrick', ['Hamlet.txt'])
# (3683, 'help', ['Hamlet.txt', 'RomeoJuliet.txt', 'RichardII.txt'])
# (3684, 'headshake', ['Hamlet.txt'])
# (3685, 'behaviour', ['Hamlet.txt', 'RomeoJuliet.txt'])
# (3686, 'working', ['Hamlet.txt'])
# (3687, 'indirections', ['Hamlet.txt'])
# (3688, 'quoted', ['Hamlet.txt'])
# (3689, 'trifle', ['Hamlet.txt'])
# (3690, 'jealousy', ['Hamlet.txt'])
# (3691, 'resembles', ['Hamlet.txt'])
# (3692, 'pleasures', ['Hamlet.txt'])
# (3693, 'joyfully', ['Hamlet.txt'])
# (3694, 'feast', ['Hamlet.txt', 'RomeoJuliet.txt', 'RichardII.txt'])
# (3695, 'falsely', ['Hamlet.txt', 'RichardII.txt'])
# (3696, 'likes', ['Hamlet.txt'])
# (3697, 'obedience', ['Hamlet.txt', 'RichardII.txt'])
# (3698, 'lock', ['Hamlet.txt'])
# (3699, 'declension', ['Hamlet.txt'])
# (3700, 'try', ['Hamlet.txt', 'RomeoJuliet.txt', 'RichardII.txt'])
# (3701, 'picked', ['Hamlet.txt'])
# (3702, 'quality', ['Hamlet.txt'])
# (3703, 'appurtenance', ['Hamlet.txt'])
# (3704, 'passionate', ['Hamlet.txt'])
# (3705, 'ominous', ['Hamlet.txt'])
# (3706, 'fellies', ['Hamlet.txt'])
# (3707, 'bawdry', ['Hamlet.txt'])
# (3708, 'amaze', ['Hamlet.txt'])
# (3709, 'tweaks', ['Hamlet.txt'])
# (3710, 'damn', ['Hamlet.txt'])
# (3711, 'lawful', ['Hamlet.txt', 'RichardII.txt'])
# (3712, 'nobler', ['Hamlet.txt'])
# (3713, 'heartache', ['Hamlet.txt'])
# (3714, 'fardels', ['Hamlet.txt'])
# (3715, 'grunt', ['Hamlet.txt'])
# (3716, 'puzzles', ['Hamlet.txt'])
# (3717, 'sicklied', ['Hamlet.txt'])
# (3718, 'paradox', ['Hamlet.txt'])
# (3719, 'feature', ['Hamlet.txt'])
# (3720, 'gently', ['Hamlet.txt', 'RichardII.txt'])
# (3721, 'conversation', ['Hamlet.txt'])
# (3722, 'buffets', ['Hamlet.txt'])
# (3723, 'mallicho', ['Hamlet.txt'])
# (3724, 'retirement', ['Hamlet.txt'])
# (3725, 'cloud', ['Hamlet.txt'])
# (3726, 'thoughtsick', ['Hamlet.txt'])
# (3727, 'assurance', ['Hamlet.txt'])
# (3728, 'moor', ['Hamlet.txt'])
# (3729, 'shreds', ['Hamlet.txt'])
# (3730, 'reword', ['Hamlet.txt'])
# (3731, 'skin', ['Hamlet.txt', 'RichardII.txt'])
# (3732, 'ranker', ['Hamlet.txt'])
# (3733, 'fatness', ['Hamlet.txt'])
# (3734, 'reechy', ['Hamlet.txt'])
# (3735, 'enginer', ['Hamlet.txt'])
# (3736, 'heaves', ['Hamlet.txt'])
# (3737, 'ore', ['Hamlet.txt'])
# (3738, 'swallowed', ['Hamlet.txt', 'RomeoJuliet.txt'])
# (3739, 'haps', ['Hamlet.txt'])
# (3740, 'rendezvous', ['Hamlet.txt'])
# (3741, 'examples', ['Hamlet.txt'])
# (3742, 'nods', ['Hamlet.txt'])
# (3743, 'conjectures', ['Hamlet.txt'])
# (3744, 'infect', ['Hamlet.txt'])
# (3745, 'flats', ['Hamlet.txt'])
# (3746, 'seven', ['Hamlet.txt', 'RichardII.txt'])
# (3747, 'fitted', ['Hamlet.txt'])
# (3748, 'poll', ['Hamlet.txt'])
# (3749, 'repair', ['Hamlet.txt', 'RichardII.txt'])
# (3750, 'speedier', ['Hamlet.txt'])
# (3751, 'postscript', ['Hamlet.txt'])
# (3752, 'sum', ['Hamlet.txt', 'RomeoJuliet.txt'])
# (3753, 'envenom', ['Hamlet.txt'])
# (3754, 'stuck', ['Hamlet.txt'])
# (3755, 'willow', ['Hamlet.txt'])
# (3756, 'garlands', ['Hamlet.txt'])
# (3757, 'purples', ['Hamlet.txt'])
# (3758, 'spades', ['Hamlet.txt'])
# (3759, 'sat', ['Hamlet.txt'])
# (3760, 'goodman', ['Hamlet.txt', 'RomeoJuliet.txt'])
# (3761, 'ditchers', ['Hamlet.txt'])
# (3762, 'carpenter', ['Hamlet.txt'])
# (3763, 'gallowsmaker', ['Hamlet.txt'])
# (3764, 'throws', ['Hamlet.txt', 'RomeoJuliet.txt'])
# (3765, 'recognizances', ['Hamlet.txt'])
# (3766, 'jot', ['Hamlet.txt'])
# (3767, 'jester', ['Hamlet.txt'])
# (3768, 'pah', ['Hamlet.txt'])
# (3769, 'bunghole', ['Hamlet.txt'])
# (3770, 'fordo', ['Hamlet.txt'])
# (3771, 'splenative', ['Hamlet.txt'])
# (3772, 'comma', ['Hamlet.txt'])
# (3773, 'suchlike', ['Hamlet.txt'])
# (3774, 'unfellowed', ['Hamlet.txt'])
# (3775, 'lapwing', ['Hamlet.txt'])
# (3776, 'winnowed', ['Hamlet.txt'])
# (3777, 'sparrow', ['Hamlet.txt'])
# (3778, 'betimes', ['Hamlet.txt', 'RichardII.txt'])
# (3779, 'exception', ['Hamlet.txt'])
# (3780, 'hurt', ['Hamlet.txt', 'RomeoJuliet.txt'])
# (3781, 'dally', ['Hamlet.txt'])
# (3782, 'mission', ['Hamlet.txt', 'RomeoJuliet.txt'])
# (3783, 'archive', ['Hamlet.txt', 'RomeoJuliet.txt'])
# (3784, 'prominently', ['Hamlet.txt', 'RomeoJuliet.txt'])
# (3785, 'providing', ['Hamlet.txt', 'RomeoJuliet.txt'])
# (3786, 'website', ['Hamlet.txt'])
# (3787, 'stored', ['Hamlet.txt', 'RomeoJuliet.txt'])
# (3788, 'interpreted', ['Hamlet.txt', 'RomeoJuliet.txt'])
# (3789, 'exists', ['Hamlet.txt', 'RomeoJuliet.txt'])
# (3790, 'solicit', ['Hamlet.txt', 'RomeoJuliet.txt', 'RichardII.txt'])
# (3791, 'montague', ['RomeoJuliet.txt'])
# (3792, 'john', ['RomeoJuliet.txt', 'RichardII.txt'])
# (3793, 'enter', ['RomeoJuliet.txt', 'RichardII.txt', 'Hamlet.txt'])
# (3794, 'loins', ['RomeoJuliet.txt', 'Hamlet.txt'])
# (3795, 'runnst', ['RomeoJuliet.txt'])
# (3796, 'maid', ['RomeoJuliet.txt', 'Hamlet.txt'])
# (3797, 'able', ['RomeoJuliet.txt', 'RichardII.txt', 'Hamlet.txt'])
# (3798, 'frown', ['RomeoJuliet.txt'])
# (3799, 'beat', ['RomeoJuliet.txt', 'RichardII.txt'])
# (3800, 'disturbd', ['RomeoJuliet.txt'])
# (3801, 'shuts', ['RomeoJuliet.txt'])
# (3802, 'secret', ['RomeoJuliet.txt', 'RichardII.txt', 'Hamlet.txt'])
# (3803, 'shrift', ['RomeoJuliet.txt'])
# (3804, 'chaos', ['RomeoJuliet.txt'])
# (3805, 'wellseeming', ['RomeoJuliet.txt'])
# (3806, 'childish', ['RomeoJuliet.txt'])
# (3807, 'lovely', ['RomeoJuliet.txt'])
# (3808, 'swan', ['RomeoJuliet.txt'])
# (3809, 'jul', ['RomeoJuliet.txt'])
# (3810, 'theme', ['RomeoJuliet.txt', 'Hamlet.txt'])
# (3811, 'guests', ['RomeoJuliet.txt'])
# (3812, 'cursd', ['RomeoJuliet.txt'])
# (3813, 'pantry', ['RomeoJuliet.txt'])
# (3814, 'lath', ['RomeoJuliet.txt'])
# (3815, 'enpierced', ['RomeoJuliet.txt'])
# (3816, 'shaft', ['RomeoJuliet.txt'])
# (3817, 'betake', ['RomeoJuliet.txt'])
# (3818, 'cursies', ['RomeoJuliet.txt'])
# (3819, 'fees', ['RomeoJuliet.txt', 'RichardII.txt', 'Hamlet.txt'])
# (3820, 'cutting', ['RomeoJuliet.txt'])
# (3821, 'untangled', ['RomeoJuliet.txt'])
# (3822, 'substance', ['RomeoJuliet.txt', 'RichardII.txt', 'Hamlet.txt'])
# (3823, 'misgives', ['RomeoJuliet.txt'])
# (3824, 'expire', ['RomeoJuliet.txt'])
# (3825, 'lookd', ['RomeoJuliet.txt', 'RichardII.txt'])
# (3826, 'toes', ['RomeoJuliet.txt'])
# (3827, 'mask', ['RomeoJuliet.txt'])
# (3828, 'nuptial', ['RomeoJuliet.txt'])
# (3829, 'enrich', ['RomeoJuliet.txt'])
# (3830, 'wilful', ['RomeoJuliet.txt'])
# (3831, 'shrine', ['RomeoJuliet.txt'])
# (3832, 'effect', ['RomeoJuliet.txt', 'RichardII.txt', 'Hamlet.txt'])
# (3833, 'twould', ['RomeoJuliet.txt'])
# (3834, 'fieldbed', ['RomeoJuliet.txt'])
# (3835, 'winged', ['RomeoJuliet.txt'])
# (3836, 'baptizd', ['RomeoJuliet.txt'])
# (3837, 'bescreend', ['RomeoJuliet.txt'])
# (3838, 'stony', ['RomeoJuliet.txt'])
# (3839, 'farthest', ['RomeoJuliet.txt'])
# (3840, 'twisted', ['RomeoJuliet.txt'])
# (3841, 'cheers', ['RomeoJuliet.txt'])
# (3842, 'lodges', ['RomeoJuliet.txt'])
# (3843, 'duellist', ['RomeoJuliet.txt'])
# (3844, 'fashionmongers', ['RomeoJuliet.txt'])
# (3845, 'fishified', ['RomeoJuliet.txt'])
# (3846, 'salutation', ['RomeoJuliet.txt'])
# (3847, 'ell', ['RomeoJuliet.txt'])
# (3848, 'proves', ['RomeoJuliet.txt'])
# (3849, 'depth', ['RomeoJuliet.txt'])
# (3850, 'scurvy', ['RomeoJuliet.txt'])
# (3851, 'feign', ['RomeoJuliet.txt'])
# (3852, 'repliest', ['RomeoJuliet.txt'])
# (3853, 'deliciousness', ['RomeoJuliet.txt'])
# (3854, 'riband', ['RomeoJuliet.txt', 'Hamlet.txt'])
# (3855, 'consort', ['RomeoJuliet.txt'])
# (3856, 'worship', ['RomeoJuliet.txt'])
# (3857, 'alla', ['RomeoJuliet.txt'])
# (3858, 'sped', ['RomeoJuliet.txt'])
# (3859, 'aspird', ['RomeoJuliet.txt'])
# (3860, 'killd', ['RomeoJuliet.txt', 'RichardII.txt'])
# (3861, 'agile', ['RomeoJuliet.txt'])
# (3862, 'newly', ['RomeoJuliet.txt', 'Hamlet.txt'])
# (3863, 'interest', ['RomeoJuliet.txt'])
# (3864, 'phoebus', ['RomeoJuliet.txt'])
# (3865, 'bating', ['RomeoJuliet.txt'])
# (3866, 'flowring', ['RomeoJuliet.txt'])
# (3867, 'universal', ['RomeoJuliet.txt'])
# (3868, 'sharpground', ['RomeoJuliet.txt'])
# (3869, 'anatomy', ['RomeoJuliet.txt'])
# (3870, 'falln', ['RomeoJuliet.txt'])
# (3871, 'aloft', ['RomeoJuliet.txt'])
# (3872, 'exhales', ['RomeoJuliet.txt'])
# (3873, 'descend', ['RomeoJuliet.txt', 'RichardII.txt'])
# (3874, 'gravity', ['RomeoJuliet.txt'])
# (3875, 'extremes', ['RomeoJuliet.txt'])
# (3876, 'yellow', ['RomeoJuliet.txt'])
# (3877, 'becomed', ['RomeoJuliet.txt'])
# (3878, 'stepping', ['RomeoJuliet.txt'])
# (3879, 'provision', ['RomeoJuliet.txt', 'Hamlet.txt'])
# (3880, 'thrills', ['RomeoJuliet.txt'])
# (3881, 'ministred', ['RomeoJuliet.txt'])
# (3882, 'ancestors', ['RomeoJuliet.txt', 'RichardII.txt'])
# (3883, 'packd', ['RomeoJuliet.txt'])
# (3884, 'resort', ['RomeoJuliet.txt', 'Hamlet.txt'])
# (3885, 'waken', ['RomeoJuliet.txt'])
# (3886, 'settled', ['RomeoJuliet.txt', 'RichardII.txt', 'Hamlet.txt'])
# (3887, 'money', ['RomeoJuliet.txt', 'RichardII.txt', 'Hamlet.txt'])
# (3888, 'simon', ['RomeoJuliet.txt'])
# (3889, 'rebeck', ['RomeoJuliet.txt'])
# (3890, 'pots', ['RomeoJuliet.txt'])
# (3891, 'cakes', ['RomeoJuliet.txt'])
# (3892, 'taker', ['RomeoJuliet.txt'])
# (3893, 'danger', ['RomeoJuliet.txt', 'RichardII.txt', 'Hamlet.txt'])
# (3894, 'wrenching', ['RomeoJuliet.txt'])
# (3895, 'hereabout', ['RomeoJuliet.txt'])
# (3896, 'cram', ['RomeoJuliet.txt'])
# (3897, 'unhallowed', ['RomeoJuliet.txt'])
# (3898, 'liest', ['RomeoJuliet.txt', 'RichardII.txt', 'Hamlet.txt'])
# (3899, 'chambermaids', ['RomeoJuliet.txt'])
# (3900, 'dashing', ['RomeoJuliet.txt'])
# (3901, 'thwarted', ['RomeoJuliet.txt'])
# (3902, 'descry', ['RomeoJuliet.txt'])
# (3903, 'registered', ['RomeoJuliet.txt', 'Hamlet.txt'])
# (3904, 'comply', ['RomeoJuliet.txt', 'Hamlet.txt'])
# (3905, 'copied', ['RomeoJuliet.txt', 'Hamlet.txt'])
# (3906, 'corrupt', ['RomeoJuliet.txt', 'RichardII.txt', 'Hamlet.txt'])
# (3907, 'asis', ['RomeoJuliet.txt', 'RichardII.txt', 'Hamlet.txt'])
# (3908, 'occur', ['RomeoJuliet.txt', 'Hamlet.txt'])
# (3909, 'addresses', ['RomeoJuliet.txt', 'Hamlet.txt'])
# (3910, 'network', ['RomeoJuliet.txt', 'Hamlet.txt'])
# (3911, 'central', ['RichardII.txt'])
# (3912, 'suggestion', ['RichardII.txt'])
# (3913, 'nominally', ['RichardII.txt'])
# (3914, 'p', ['RichardII.txt'])
# (3915, 'honor', ['RichardII.txt'])
# (3916, 'ebcdic', ['RichardII.txt'])
# (3917, 'dedicated', ['RichardII.txt'])
# (3918, 'womans', ['RichardII.txt'])
# (3919, 'ridges', ['RichardII.txt'])
# (3920, 'design', ['RichardII.txt'])
# (3921, 'lendings', ['RichardII.txt'])
# (3922, 'vex', ['RichardII.txt'])
# (3923, 'hurl', ['RichardII.txt'])
# (3924, 'spear', ['RichardII.txt'])
# (3925, 'withstood', ['RichardII.txt'])
# (3926, 'purest', ['RichardII.txt'])
# (3927, 'atone', ['RichardII.txt'])
# (3928, 'envys', ['RichardII.txt'])
# (3929, 'deputy', ['RichardII.txt'])
# (3930, 'wrongfully', ['RichardII.txt'])
# (3931, 'succeeding', ['RichardII.txt'])
# (3932, 'doubly', ['RichardII.txt'])
# (3933, 'combatants', ['RichardII.txt'])
# (3934, 'necessity', ['RichardII.txt', 'Hamlet.txt'])
# (3935, 'tooth', ['RichardII.txt'])
# (3936, 'whereer', ['RichardII.txt'])
# (3937, 'seemd', ['RichardII.txt'])
# (3938, 'somewhat', ['RichardII.txt'])
# (3939, 'charters', ['RichardII.txt'])
# (3940, 'ely', ['RichardII.txt'])
# (3941, 'sweets', ['RichardII.txt', 'Hamlet.txt'])
# (3942, 'limps', ['RichardII.txt'])
# (3943, 'prophet', ['RichardII.txt'])
# (3944, 'preys', ['RichardII.txt'])
# (3945, 'neptune', ['RichardII.txt'])
# (3946, 'ensuing', ['RichardII.txt'])
# (3947, 'aged', ['RichardII.txt'])
# (3948, 'fasting', ['RichardII.txt'])
# (3949, 'diest', ['RichardII.txt', 'Hamlet.txt'])
# (3950, 'wellmeaning', ['RichardII.txt'])
# (3951, 'witness', ['RichardII.txt', 'Hamlet.txt'])
# (3952, 'commends', ['RichardII.txt'])
# (3953, 'goods', ['RichardII.txt'])
# (3954, 'understood', ['RichardII.txt'])
# (3955, 'tends', ['RichardII.txt'])
# (3956, 'kinsmanmost', ['RichardII.txt'])
# (3957, 'le', ['RichardII.txt'])
# (3958, 'ships', ['RichardII.txt'])
# (3959, 'shapes', ['RichardII.txt', 'Hamlet.txt'])
# (3960, 'footing', ['RichardII.txt'])
# (3961, 'underprop', ['RichardII.txt'])
# (3962, 'presages', ['RichardII.txt'])
# (3963, 'oncefor', ['RichardII.txt'])
# (3964, 'sweetned', ['RichardII.txt'])
# (3965, 'confirm', ['RichardII.txt'])
# (3966, 'treasury', ['RichardII.txt'])
# (3967, 'selfborne', ['RichardII.txt'])
# (3968, 'vagabond', ['RichardII.txt'])
# (3969, 'trod', ['RichardII.txt'])
# (3970, 'caterpillars', ['RichardII.txt'])
# (3971, 'tossing', ['RichardII.txt'])
# (3972, 'knowst', ['RichardII.txt'])
# (3973, 'pressd', ['RichardII.txt'])
# (3974, 'hairless', ['RichardII.txt'])
# (3975, 'terrible', ['RichardII.txt'])
# (3976, 'bores', ['RichardII.txt'])
# (3977, 'ague', ['RichardII.txt'])
# (3978, 'flatteries', ['RichardII.txt'])
# (3979, 'occident', ['RichardII.txt'])
# (3980, 'testament', ['RichardII.txt'])
# (3981, 'uncivil', ['RichardII.txt'])
# (3982, 'almsmans', ['RichardII.txt'])
# (3983, 'shadow', ['RichardII.txt', 'Hamlet.txt'])
# (3984, 'chokd', ['RichardII.txt'])
# (3985, 'balance', ['RichardII.txt'])
# (3986, 'standst', ['RichardII.txt'])
# (3987, 'execute', ['RichardII.txt'])
# (3988, 'streaming', ['RichardII.txt'])
# (3989, 'appellants', ['RichardII.txt'])
# (3990, 'buckets', ['RichardII.txt'])
# (3991, 'emptier', ['RichardII.txt'])
# (3992, 'offences', ['RichardII.txt', 'Hamlet.txt'])
# (3993, 'pityyet', ['RichardII.txt'])
# (3994, 'insulting', ['RichardII.txt'])
# (3995, 'usurpd', ['RichardII.txt'])
# (3996, 'shivers', ['RichardII.txt'])
# (3997, 'forthwith', ['RichardII.txt', 'Hamlet.txt'])
# (3998, 'darted', ['RichardII.txt'])
# (3999, 'wellgracd', ['RichardII.txt'])
# (4000, 'aye', ['RichardII.txt', 'Hamlet.txt'])
# (4001, 'triumphday', ['RichardII.txt'])
# (4002, 'readst', ['RichardII.txt'])
# (4003, 'pleads', ['RichardII.txt'])
# (4004, 'nails', ['RichardII.txt'])
# (4005, 'crushing', ['RichardII.txt'])
# (4006, 'rush', ['RichardII.txt'])
# (4007, 'gains', ['RichardII.txt'])
# (4008, 'soldier', ['Hamlet.txt'])
# (4009, 'holla', ['Hamlet.txt'])
# (4010, 'sensible', ['Hamlet.txt'])
# (4011, 'trains', ['Hamlet.txt'])
# (4012, 'wisdoms', ['Hamlet.txt'])
# (4013, 'disjoint', ['Hamlet.txt'])
# (4014, 'oh', ['Hamlet.txt'])
# (4015, 'hyperion', ['Hamlet.txt'])
# (4016, 'fearsurprised', ['Hamlet.txt'])
# (4017, 'importunity', ['Hamlet.txt'])
# (4018, 'chariest', ['Hamlet.txt'])
# (4019, 'strokes', ['Hamlet.txt'])
# (4020, 'pastors', ['Hamlet.txt'])
# (4021, 'libertine', ['Hamlet.txt'])
# (4022, 'station', ['Hamlet.txt'])
# (4023, 'husbandry', ['Hamlet.txt'])
# (4024, 'roaming', ['Hamlet.txt'])
# (4025, 'swaggering', ['Hamlet.txt'])
# (4026, 'kettledrum', ['Hamlet.txt'])
# (4027, 'marrow', ['Hamlet.txt'])
# (4028, 'burst', ['Hamlet.txt'])
# (4029, 'marble', ['Hamlet.txt'])
# (4030, 'hardy', ['Hamlet.txt'])
# (4031, 'secrets', ['Hamlet.txt'])
# (4032, 'stung', ['Hamlet.txt'])
# (4033, 'distant', ['Hamlet.txt'])
# (4034, 'savageness', ['Hamlet.txt'])
# (4035, 'assays', ['Hamlet.txt'])
# (4036, 'wrist', ['Hamlet.txt'])
# (4037, 'practices', ['Hamlet.txt'])
# (4038, 'polack', ['Hamlet.txt'])
# (4039, 'admit', ['Hamlet.txt'])
# (4040, 'thick', ['Hamlet.txt'])
# (4041, 'waist', ['Hamlet.txt'])
# (4042, 'halfpenny', ['Hamlet.txt'])
# (4043, 'verse', ['Hamlet.txt'])
# (4044, 'tragedians', ['Hamlet.txt'])
# (4045, 'poet', ['Hamlet.txt'])
# (4046, 'historicalpastoral', ['Hamlet.txt'])
# (4047, 'digested', ['Hamlet.txt'])
# (4048, 'indite', ['Hamlet.txt'])
# (4049, 'priam', ['Hamlet.txt'])
# (4050, 'caught', ['Hamlet.txt'])
# (4051, 'sixteen', ['Hamlet.txt'])
# (4052, 'defeat', ['Hamlet.txt'])
# (4053, 'malefactions', ['Hamlet.txt'])
# (4054, 'bodkin', ['Hamlet.txt'])
# (4055, 'dowry', ['Hamlet.txt'])
# (4056, 'monsters', ['Hamlet.txt'])
# (4057, 'brood', ['Hamlet.txt'])
# (4058, 'disclose', ['Hamlet.txt'])
# (4059, 'journeymen', ['Hamlet.txt'])
# (4060, 'reform', ['Hamlet.txt'])
# (4061, 'considered', ['Hamlet.txt'])
# (4062, 'hinges', ['Hamlet.txt'])
# (4063, 'stithy', ['Hamlet.txt'])
# (4064, 'detecting', ['Hamlet.txt'])
# (4065, 'unite', ['Hamlet.txt'])
# (4066, 'infected', ['Hamlet.txt'])
# (4067, 'dismantled', ['Hamlet.txt'])
# (4068, 'unmannerly', ['Hamlet.txt'])
# (4069, 'fetters', ['Hamlet.txt'])
# (4070, 'defeats', ['Hamlet.txt'])
# (4071, 'shuffling', ['Hamlet.txt'])
# (4072, 'pranks', ['Hamlet.txt'])
# (4073, 'seated', ['Hamlet.txt'])
# (4074, 'test', ['Hamlet.txt'])
# (4075, 'aptly', ['Hamlet.txt'])
# (4076, 'refrain', ['Hamlet.txt'])
# (4077, 'essentially', ['Hamlet.txt'])
# (4078, 'adders', ['Hamlet.txt'])
# (4079, 'delve', ['Hamlet.txt'])
# (4080, 'discord', ['Hamlet.txt'])
# (4081, 'quickness', ['Hamlet.txt'])
# (4082, 'exposing', ['Hamlet.txt'])
# (4083, 'battalions', ['Hamlet.txt'])
# (4084, 'muddied', ['Hamlet.txt'])
# (4085, 'divinity', ['Hamlet.txt'])
# (4086, 'hedge', ['Hamlet.txt'])
# (4087, 'collateral', ['Hamlet.txt'])
# (4088, 'overlooked', ['Hamlet.txt'])
# (4089, 'lamond', ['Hamlet.txt'])
# (4090, 'rare', ['Hamlet.txt'])
# (4091, 'convenience', ['Hamlet.txt'])
# (4092, 'hoary', ['Hamlet.txt'])
# (4093, 'profession', ['Hamlet.txt'])
# (4094, 'gallows', ['Hamlet.txt'])
# (4095, 'purchases', ['Hamlet.txt'])
# (4096, 'sheep', ['Hamlet.txt'])
# (4097, 'equivocation', ['Hamlet.txt'])
# (4098, 'stopping', ['Hamlet.txt'])
# (4099, 'conjures', ['Hamlet.txt'])
# (4100, 'whine', ['Hamlet.txt'])
# (4101, 'zone', ['Hamlet.txt'])
# (4102, 'sorts', ['Hamlet.txt'])
# (4103, 'changeling', ['Hamlet.txt'])
# (4104, 'waterfly', ['Hamlet.txt'])
# (4105, 'rareness', ['Hamlet.txt'])
# (4106, 'semblable', ['Hamlet.txt'])
# (4107, 'readiness', ['Hamlet.txt'])
# (4108, 'villany', ['Hamlet.txt'])
# (4109, 'afar', ['Hamlet.txt'])
# (4110, 'unknowing', ['Hamlet.txt'])
# (4111, 'noblest', ['Hamlet.txt'])
# (4112, 'loudly', ['Hamlet.txt'])
# (4113, 'widespread', ['Hamlet.txt'])
# (4114, 'file', ['RichardII.txt', 'Hamlet.txt', 'RomeoJuliet.txt'])
# (4115, 'permission', ['RichardII.txt', 'RomeoJuliet.txt', 'Hamlet.txt'])
# (4116, 'membership', ['RichardII.txt', 'RomeoJuliet.txt'])
# (4117, 'reading', ['RichardII.txt', 'Hamlet.txt', 'RomeoJuliet.txt'])
# (4118, 'trademark', ['RichardII.txt', 'Hamlet.txt', 'RomeoJuliet.txt'])
# (4119, 'posted', ['RichardII.txt', 'RomeoJuliet.txt', 'Hamlet.txt'])
# (4120, 'audience', ['RichardII.txt', 'Hamlet.txt'])
# (4121, 'productivity', ['RichardII.txt'])
# (4122, 'provisions', ['RichardII.txt', 'RomeoJuliet.txt', 'Hamlet.txt'])
# (4123, 'case', ['RichardII.txt', 'RomeoJuliet.txt', 'Hamlet.txt'])
# (4124, 'instance', ['RichardII.txt', 'Hamlet.txt'])
# (4125, 'costs', ['RichardII.txt', 'Hamlet.txt', 'RomeoJuliet.txt'])
# (4126, 'fitness', ['RichardII.txt', 'RomeoJuliet.txt', 'Hamlet.txt'])
# (4127, 'directly', ['RichardII.txt', 'Hamlet.txt', 'RomeoJuliet.txt'])
# (4128, 'association', ['RichardII.txt'])
# (4129, 'captain', ['RichardII.txt', 'RomeoJuliet.txt', 'Hamlet.txt'])
# (4130, 'according', ['RichardII.txt', 'Hamlet.txt', 'RomeoJuliet.txt'])
# (4131, 'gracious', ['RichardII.txt', 'Hamlet.txt', 'RomeoJuliet.txt'])
# (4132, 'well', ['RichardII.txt', 'Hamlet.txt', 'RomeoJuliet.txt'])
# (4133, 'foul', ['RichardII.txt', 'RomeoJuliet.txt', 'Hamlet.txt'])
# (4134, 'sword', ['RichardII.txt', 'RomeoJuliet.txt', 'Hamlet.txt'])
# (4135, 'blood', ['RichardII.txt', 'RomeoJuliet.txt', 'Hamlet.txt'])
# (4136, 'patience', ['RichardII.txt', 'RomeoJuliet.txt', 'Hamlet.txt'])
# (4137, 'nought', ['RichardII.txt'])
# (4138, 'kindred', ['RichardII.txt', 'RomeoJuliet.txt'])
# (4139, 'treasons', ['RichardII.txt'])
# (4140, 'chastisement', ['RichardII.txt'])
# (4141, 'liar', ['RichardII.txt', 'Hamlet.txt'])
# (4142, 'upright', ['RichardII.txt'])
# (4143, 'interchangeably', ['RichardII.txt'])
# (4144, 'physician', ['RichardII.txt'])
# (4145, 'deep', ['RichardII.txt', 'Hamlet.txt', 'RomeoJuliet.txt'])
# (4146, 'forget', ['RichardII.txt', 'RomeoJuliet.txt', 'Hamlet.txt'])
# (4147, 'shame', ['RichardII.txt', 'Hamlet.txt', 'RomeoJuliet.txt'])
# (4148, 'beggarfear', ['RichardII.txt'])
# (4149, 'dastard', ['RichardII.txt'])
# (4150, 'difference', ['RichardII.txt', 'Hamlet.txt'])
# (4151, 'hands', ['RichardII.txt', 'RomeoJuliet.txt', 'Hamlet.txt'])
# (4152, 'heads', ['RichardII.txt', 'Hamlet.txt', 'RomeoJuliet.txt'])
# (4153, 'edwards', ['RichardII.txt'])
# (4154, 'spilt', ['RichardII.txt', 'Hamlet.txt'])
# (4155, 'hand', ['RichardII.txt', 'Hamlet.txt', 'RomeoJuliet.txt'])
# (4156, 'showest', ['RichardII.txt'])
# (4157, 'substitute', ['RichardII.txt'])
# (4158, 'causd', ['RichardII.txt'])
# (4159, 'miss', ['RichardII.txt', 'RomeoJuliet.txt', 'Hamlet.txt'])
# (4160, 'sins', ['RichardII.txt', 'Hamlet.txt'])
# (4161, 'wife', ['RichardII.txt', 'RomeoJuliet.txt', 'Hamlet.txt'])
# (4162, 'stay', ['RichardII.txt', 'RomeoJuliet.txt', 'Hamlet.txt'])
# (4163, 'sorrow', ['RichardII.txt', 'RomeoJuliet.txt', 'Hamlet.txt'])
# (4164, 'unfurnishd', ['RichardII.txt', 'RomeoJuliet.txt'])
# (4165, 'champions', ['RichardII.txt'])
# (4166, 'defendant', ['RichardII.txt'])
# (4167, 'truth', ['RichardII.txt', 'Hamlet.txt', 'RomeoJuliet.txt'])
# (4168, 'armour', ['RichardII.txt', 'Hamlet.txt', 'RomeoJuliet.txt'])
# (4169, 'confident', ['RichardII.txt'])
# (4170, 'casque', ['RichardII.txt'])
# (4171, 'lot', ['RichardII.txt', 'RomeoJuliet.txt', 'Hamlet.txt'])
# (4172, 'council', ['RichardII.txt'])
# (4173, 'wounds', ['RichardII.txt', 'RomeoJuliet.txt', 'Hamlet.txt'])
# (4174, 'eaglewinged', ['RichardII.txt'])
# (4175, 'ambitious', ['RichardII.txt', 'Hamlet.txt'])
# (4176, 'wade', ['RichardII.txt'])
# (4177, 'twice', ['RichardII.txt', 'Hamlet.txt'])
# (4178, 'heavier', ['RichardII.txt'])
# (4179, 'forth', ['RichardII.txt', 'Hamlet.txt', 'RomeoJuliet.txt'])
# (4180, 'ignorance', ['RichardII.txt', 'Hamlet.txt', 'RomeoJuliet.txt'])
# (4181, 'vantage', ['RichardII.txt', 'Hamlet.txt'])
# (4182, 'spend', ['RichardII.txt', 'Hamlet.txt'])
# (4183, 'buy', ['RichardII.txt', 'Hamlet.txt', 'RomeoJuliet.txt'])
# (4184, 'sour', ['RichardII.txt', 'RomeoJuliet.txt'])
# (4185, 'judge', ['RichardII.txt', 'Hamlet.txt'])
# (4186, 'mild', ['RichardII.txt'])
# (4187, 'train', ['RichardII.txt', 'RomeoJuliet.txt'])
# (4188, 'sigh', ['RichardII.txt', 'Hamlet.txt', 'RomeoJuliet.txt'])
# (4189, 'places', ['RichardII.txt', 'Hamlet.txt'])
# (4190, 'whence', ['RichardII.txt', 'Hamlet.txt', 'RomeoJuliet.txt'])
# (4191, 'gnarling', ['RichardII.txt'])
# (4192, 'less', ['RichardII.txt', 'RomeoJuliet.txt', 'Hamlet.txt'])
# (4193, 'bare', ['RichardII.txt', 'RomeoJuliet.txt', 'Hamlet.txt'])
# (4194, 'snow', ['RichardII.txt', 'RomeoJuliet.txt', 'Hamlet.txt'])
# (4195, 'sorrows', ['RichardII.txt', 'Hamlet.txt', 'RomeoJuliet.txt'])
# (4196, 'another', ['RichardII.txt', 'Hamlet.txt', 'RomeoJuliet.txt'])
# (4197, 'taught', ['RichardII.txt'])
# (4198, 'hearts', ['RichardII.txt', 'Hamlet.txt', 'RomeoJuliet.txt'])
# (4199, 'humble', ['RichardII.txt', 'Hamlet.txt'])
# (4200, 'supple', ['RichardII.txt', 'RomeoJuliet.txt'])
# (4201, 'liberal', ['RichardII.txt', 'Hamlet.txt'])
# (4202, 'furnish', ['RichardII.txt', 'Hamlet.txt', 'RomeoJuliet.txt'])
# (4203, 'rich', ['RichardII.txt', 'RomeoJuliet.txt', 'Hamlet.txt'])
# (4204, 'ease', ['RichardII.txt', 'RomeoJuliet.txt', 'Hamlet.txt'])
# (4205, 'manners', ['RichardII.txt', 'Hamlet.txt', 'RomeoJuliet.txt'])
# (4206, 'vile', ['RichardII.txt', 'Hamlet.txt', 'RomeoJuliet.txt'])
# (4207, 'showers', ['RichardII.txt', 'Hamlet.txt'])
# (4208, 'seat', ['RichardII.txt', 'Hamlet.txt'])
# (4209, 'birth', ['RichardII.txt', 'RomeoJuliet.txt', 'Hamlet.txt'])
# (4210, 'tenement', ['RichardII.txt'])
# (4211, 'ragd', ['RichardII.txt'])
# (4212, 'breeds', ['RichardII.txt'])
# (4213, 'prophets', ['RichardII.txt'])
# (4214, 'possessd', ['RichardII.txt', 'RomeoJuliet.txt'])
# (4215, 'leanwitted', ['RichardII.txt'])
# (4216, 'coin', ['RichardII.txt'])
# (4217, 'godgod', ['RichardII.txt'])
# (4218, 'unless', ['RichardII.txt', 'RomeoJuliet.txt', 'Hamlet.txt'])
# (4219, 'children', ['RichardII.txt', 'Hamlet.txt', 'RomeoJuliet.txt'])
# (4220, 'blanks', ['RichardII.txt', 'Hamlet.txt'])
# (4221, 'benevolences', ['RichardII.txt'])
# (4222, 'compromise', ['RichardII.txt'])
# (4223, 'brittany', ['RichardII.txt'])
# (4224, 'quoint', ['RichardII.txt'])
# (4225, 'unborn', ['RichardII.txt'])
# (4226, 'weeps', ['RichardII.txt', 'Hamlet.txt', 'RomeoJuliet.txt'])
# (4227, 'nameless', ['RichardII.txt'])
# (4228, 'crave', ['RichardII.txt', 'RomeoJuliet.txt'])
# (4229, 'powerful', ['RichardII.txt', 'RomeoJuliet.txt'])
# (4230, 'revolted', ['RichardII.txt'])
# (4231, 'faction', ['RichardII.txt', 'Hamlet.txt'])
# (4232, 'servants', ['RichardII.txt', 'RomeoJuliet.txt', 'Hamlet.txt'])
# (4233, 'whilst', ['RichardII.txt', 'Hamlet.txt'])
# (4234, 'sirrah', ['RichardII.txt', 'RomeoJuliet.txt'])
# (4235, 'sistercousin', ['RichardII.txt'])
# (4236, 'purses', ['RichardII.txt'])
# (4237, 'empties', ['RichardII.txt'])
# (4238, 'sands', ['RichardII.txt'])
# (4239, 'ways', ['RichardII.txt', 'Hamlet.txt', 'RomeoJuliet.txt'])
# (4240, 'tediousness', ['RichardII.txt', 'Hamlet.txt'])
# (4241, 'learnd', ['RichardII.txt'])
# (4242, 'seals', ['RichardII.txt', 'Hamlet.txt'])
# (4243, 'reply', ['RichardII.txt', 'Hamlet.txt', 'RomeoJuliet.txt'])
# (4244, 'comewhat', ['RichardII.txt'])
# (4245, 'indifferent', ['RichardII.txt', 'Hamlet.txt'])
# (4246, 'wandering', ['RichardII.txt'])
# (4247, 'cherish', ['RichardII.txt', 'RomeoJuliet.txt'])
# (4248, 'neuter', ['RichardII.txt'])
# (4249, 'held', ['RichardII.txt', 'Hamlet.txt', 'RomeoJuliet.txt'])
# (4250, 'camp', ['RichardII.txt'])
# (4251, 'stayd', ['RichardII.txt', 'RomeoJuliet.txt'])
# (4252, 'moon', ['RichardII.txt', 'Hamlet.txt', 'RomeoJuliet.txt'])
# (4253, 'leap', ['RichardII.txt', 'RomeoJuliet.txt'])
# (4254, 'witnessing', ['RichardII.txt'])
# (4255, 'wash', ['RichardII.txt', 'Hamlet.txt', 'RomeoJuliet.txt'])
# (4256, 'disfigured', ['RichardII.txt'])
# (4257, 'myselfa', ['RichardII.txt'])
# (4258, 'windows', ['RichardII.txt', 'RomeoJuliet.txt'])
# (4259, 'greet', ['RichardII.txt', 'Hamlet.txt'])
# (4260, 'heavygaited', ['RichardII.txt'])
# (4261, 'double', ['RichardII.txt', 'RomeoJuliet.txt', 'Hamlet.txt'])
# (4262, 'enough', ['RichardII.txt', 'Hamlet.txt', 'RomeoJuliet.txt'])
# (4263, 'limits', ['RichardII.txt', 'RomeoJuliet.txt'])
# (4264, 'thin', ['RichardII.txt', 'Hamlet.txt', 'RomeoJuliet.txt'])
# (4265, 'distaffwomen', ['RichardII.txt'])
# (4266, 'rainy', ['RichardII.txt'])
# (4267, 'grinning', ['RichardII.txt', 'Hamlet.txt'])
# (4268, 'subjected', ['RichardII.txt'])
# (4269, 'oppresseth', ['RichardII.txt'])
# (4270, 'easy', ['RichardII.txt', 'Hamlet.txt', 'RomeoJuliet.txt'])
# (4271, 'lengthen', ['RichardII.txt'])
# (4272, 'followers', ['RichardII.txt', 'RomeoJuliet.txt'])
# (4273, 'royally', ['RichardII.txt', 'Hamlet.txt'])
# (4274, 'discontented', ['RichardII.txt'])
# (4275, 'knowmy', ['RichardII.txt'])
# (4276, 'contradiction', ['RichardII.txt'])
# (4277, 'contented', ['RichardII.txt'])
# (4278, 'obscure', ['RichardII.txt', 'Hamlet.txt'])
# (4279, 'drive', ['RichardII.txt', 'Hamlet.txt'])
# (4280, 'gardener', ['RichardII.txt'])
# (4281, 'supportance', ['RichardII.txt'])
# (4282, 'likeness', ['RichardII.txt', 'Hamlet.txt', 'RomeoJuliet.txt'])
# (4283, 'camst', ['RichardII.txt', 'RomeoJuliet.txt'])
# (4284, 'eat', ['RichardII.txt', 'Hamlet.txt'])
# ...
# (7795, 'earthtreading', ['RomeoJuliet.txt'])
# (7796, 'paper', ['RomeoJuliet.txt', 'RichardII.txt', 'Hamlet.txt'])
# (7797, 'anselmo', ['RomeoJuliet.txt'])
# (7798, 'trow', ['RomeoJuliet.txt', 'RichardII.txt'])
# (7799, 'lineament', ['RomeoJuliet.txt'])
# (7800, 'liking', ['RomeoJuliet.txt'])
# (7801, 'faintly', ['RomeoJuliet.txt', 'RichardII.txt'])
# (7802, 'pricking', ['RomeoJuliet.txt'])
# (7803, 'film', ['RomeoJuliet.txt', 'Hamlet.txt'])
# (7804, 'spanish', ['RomeoJuliet.txt'])
# (7805, 'manes', ['RomeoJuliet.txt'])
# (7806, 'presses', ['RomeoJuliet.txt'])
# (7807, 'napkins', ['RomeoJuliet.txt'])
# (7808, 'potpan', ['RomeoJuliet.txt'])
# (7809, 'snowy', ['RomeoJuliet.txt'])
# (7810, 'youll', ['RomeoJuliet.txt'])
# (7811, 'saucy', ['RomeoJuliet.txt'])
# (7812, 'whats', ['RomeoJuliet.txt', 'RichardII.txt'])
# (7813, 'venus', ['RomeoJuliet.txt'])
# (7814, 'adjacent', ['RomeoJuliet.txt'])
# (7815, 'pilot', ['RomeoJuliet.txt'])
# (7816, 'vast', ['RomeoJuliet.txt'])
# (7817, 'impute', ['RomeoJuliet.txt', 'RichardII.txt'])
# (7818, 'attending', ['RomeoJuliet.txt', 'RichardII.txt'])
# (7819, 'natural', ['RomeoJuliet.txt', 'Hamlet.txt'])
# (7820, 'opposed', ['RomeoJuliet.txt'])
# (7821, 'worser', ['RomeoJuliet.txt', 'Hamlet.txt'])
# (7822, 'saluteth', ['RomeoJuliet.txt'])
# (7823, 'earliness', ['RomeoJuliet.txt'])
# (7824, 'distemprature', ['RomeoJuliet.txt'])
# (7825, 'maria', ['RomeoJuliet.txt'])
# (7826, 'minim', ['RomeoJuliet.txt'])
# (7827, 'afflicted', ['RomeoJuliet.txt'])
# (7828, 'herring', ['RomeoJuliet.txt'])
# (7829, 'flowed', ['RomeoJuliet.txt'])
# (7830, 'berhyme', ['RomeoJuliet.txt'])
# (7831, 'cursy', ['RomeoJuliet.txt'])
# (7832, 'exposition', ['RomeoJuliet.txt'])
# (7833, 'pink', ['RomeoJuliet.txt'])
# (7834, 'argument', ['RomeoJuliet.txt', 'RichardII.txt', 'Hamlet.txt'])
# (7835, 'dealing', ['RomeoJuliet.txt'])
# (7836, 'tackled', ['RomeoJuliet.txt'])
# (7837, 'powder', ['RomeoJuliet.txt'])
# (7838, 'spy', ['RomeoJuliet.txt', 'RichardII.txt'])
# (7839, 'quarrelld', ['RomeoJuliet.txt'])
# (7840, 'wakened', ['RomeoJuliet.txt'])
# (7841, 'grievances', ['RomeoJuliet.txt'])
# (7842, 'drybeat', ['RomeoJuliet.txt'])
# (7843, 'bowd', ['RomeoJuliet.txt'])
# (7844, 'stout', ['RomeoJuliet.txt'])
# (7845, 'exile', ['RomeoJuliet.txt', 'RichardII.txt'])
# (7846, 'phaeton', ['RomeoJuliet.txt'])
# (7847, 'loveperforming', ['RomeoJuliet.txt'])
# (7848, 'sobersuited', ['RomeoJuliet.txt'])
# (7849, 'winning', ['RomeoJuliet.txt'])
# (7850, 'needly', ['RomeoJuliet.txt'])
# (7851, 'mistlike', ['RomeoJuliet.txt'])
# (7852, 'courts', ['RomeoJuliet.txt'])
# (7853, 'lark', ['RomeoJuliet.txt'])
# (7854, 'unpleasing', ['RomeoJuliet.txt', 'RichardII.txt'])
# (7855, 'counterfeitst', ['RomeoJuliet.txt'])
# (7856, 'blest', ['RomeoJuliet.txt', 'RichardII.txt'])
# (7857, 'dispraise', ['RomeoJuliet.txt'])
# (7858, 'minded', ['RomeoJuliet.txt'])
# (7859, 'strains', ['RomeoJuliet.txt'])
# (7860, 'fade', ['RomeoJuliet.txt'])
# (7861, 'stiff', ['RomeoJuliet.txt', 'RichardII.txt'])
# (7862, 'invite', ['RomeoJuliet.txt', 'Hamlet.txt'])
# (7863, 'prostrate', ['RomeoJuliet.txt'])
# (7864, 'city', ['RomeoJuliet.txt', 'Hamlet.txt'])
# (7865, 'healthsome', ['RomeoJuliet.txt'])
# (7866, 'bakd', ['RomeoJuliet.txt'])
# (7867, 'mousehunt', ['RomeoJuliet.txt'])
# (7868, 'whoreson', ['RomeoJuliet.txt', 'Hamlet.txt'])
# (7869, 'instruments', ['RomeoJuliet.txt'])
# (7870, 'servingcreature', ['RomeoJuliet.txt'])
# (7871, 'fa', ['RomeoJuliet.txt'])
# (7872, 'emperor', ['RomeoJuliet.txt', 'Hamlet.txt'])
# (7873, 'capels', ['RomeoJuliet.txt'])
# (7874, 'meagre', ['RomeoJuliet.txt'])
# (7875, 'inauspicious', ['RomeoJuliet.txt'])
# (7876, 'pariss', ['RomeoJuliet.txt'])
# (7877, 'bleeds', ['RomeoJuliet.txt'])
# (7878, 'descent', ['RomeoJuliet.txt', 'RichardII.txt'])
# (7879, 'pind', ['RomeoJuliet.txt'])
# (7880, 'betrothd', ['RomeoJuliet.txt'])
# (7881, 'scare', ['RomeoJuliet.txt'])
# (7882, 'rigour', ['RomeoJuliet.txt'])
# (7883, 'gbnewbypglaforg', ['RomeoJuliet.txt'])
# (7884, 'solicitation', ['RomeoJuliet.txt', 'Hamlet.txt'])
# (7885, 'per', ['RichardII.txt'])
# (7886, 'dollar', ['RichardII.txt'])
# (7887, 'exact', ['RichardII.txt', 'Hamlet.txt'])
# (7888, 'clearly', ['RichardII.txt', 'Hamlet.txt', 'RomeoJuliet.txt'])
# (7889, 'damaged', ['RichardII.txt', 'Hamlet.txt', 'RomeoJuliet.txt'])
# (7890, 'ing', ['RichardII.txt'])
# (7891, 'lia', ['RichardII.txt'])
# (7892, 'dont', ['RichardII.txt'])
# (7893, 'mowbray', ['RichardII.txt'])
# (7894, 'surrey', ['RichardII.txt'])
# (7895, 'ross', ['RichardII.txt'])
# (7896, 'woodstock', ['RichardII.txt'])
# (7897, 'highnessno', ['RichardII.txt'])
# (7898, 'add', ['RichardII.txt', 'RomeoJuliet.txt'])
# (7899, 'greeting', ['RichardII.txt', 'Hamlet.txt', 'RomeoJuliet.txt'])
# (7900, 'eager', ['RichardII.txt', 'Hamlet.txt'])
# (7901, 'soars', ['RichardII.txt'])
# (7902, 'recreant', ['RichardII.txt'])
# (7903, 'norfolks', ['RichardII.txt'])
# (7904, 'chest', ['RichardII.txt'])
# (7905, 'sue', ['RichardII.txt'])
# (7906, 'coventry', ['RichardII.txt'])
# (7907, 'chivalry', ['RichardII.txt'])
# (7908, 'correction', ['RichardII.txt'])
# (7909, 'branch', ['RichardII.txt'])
# (7910, 'widows', ['RichardII.txt'])
# (7911, 'remember', ['RichardII.txt', 'Hamlet.txt', 'RomeoJuliet.txt'])
# (7912, 'appointed', ['RichardII.txt'])
# (7913, 'regreet', ['RichardII.txt'])
# (7914, 'furbish', ['RichardII.txt'])
# (7915, 'chains', ['RichardII.txt'])
# (7916, 'spears', ['RichardII.txt'])
# (7917, 'civil', ['RichardII.txt', 'RomeoJuliet.txt'])
# (7918, 'hopeless', ['RichardII.txt'])
# (7919, 'glasses', ['RichardII.txt'])
# (7920, 'wrinkle', ['RichardII.txt'])
# (7921, 'visits', ['RichardII.txt'])
# (7922, 'youtli', ['RichardII.txt'])
# (7923, 'oysterwench', ['RichardII.txt'])
# (7924, 'seldom', ['RichardII.txt'])
# (7925, 'vanity', ['RichardII.txt', 'RomeoJuliet.txt'])
# (7926, 'riot', ['RichardII.txt'])
# (7927, 'marys', ['RichardII.txt'])
# (7928, 'wont', ['RichardII.txt', 'Hamlet.txt'])
# (7929, 'nicely', ['RichardII.txt'])
# (7930, 'darest', ['RichardII.txt'])
# (7931, 'chasing', ['RichardII.txt'])
# (7932, 'homage', ['RichardII.txt', 'Hamlet.txt'])
# (7933, 'hereof', ['RichardII.txt'])
# (7934, 'exactions', ['RichardII.txt'])
# (7935, 'warrd', ['RichardII.txt'])
# (7936, 'worcester', ['RichardII.txt'])
# (7937, 'dissolve', ['RichardII.txt'])
# (7938, 'surfeit', ['RichardII.txt'])
# (7939, 'lordship', ['RichardII.txt', 'Hamlet.txt'])
# (7940, 'called', ['RichardII.txt', 'Hamlet.txt'])
# (7941, 'condemnd', ['RichardII.txt'])
# (7942, 'wearisome', ['RichardII.txt'])
# (7943, 'bethink', ['RichardII.txt', 'RomeoJuliet.txt'])
# (7944, 'proclaimed', ['RichardII.txt'])
# (7945, 'unfelt', ['RichardII.txt'])
# (7946, 'labours', ['RichardII.txt'])
# (7947, 'forbidden', ['RichardII.txt'])
# (7948, 'denied', ['RichardII.txt', 'Hamlet.txt', 'RomeoJuliet.txt'])
# (7949, 'abused', ['RichardII.txt'])
# (7950, 'meteors', ['RichardII.txt'])
# (7951, 'enjoy', ['RichardII.txt'])
# (7952, 'injustice', ['RichardII.txt'])
# (7953, 'stinging', ['RichardII.txt'])
# (7954, 'searching', ['RichardII.txt'])
# (7955, 'tellst', ['RichardII.txt'])
# (7956, 'sting', ['RichardII.txt', 'Hamlet.txt'])
# (7957, 'servile', ['RichardII.txt'])
# (7958, 'alter', ['RichardII.txt'])
# (7959, 'omnipotent', ['RichardII.txt'])
# (7960, 'warlike', ['RichardII.txt', 'Hamlet.txt'])
# (7961, 'debase', ['RichardII.txt'])
# (7962, 'figurd', ['RichardII.txt'])
# (7963, 'nightowls', ['RichardII.txt'])
# (7964, 'kissing', ['RichardII.txt', 'Hamlet.txt'])
# (7965, 'adds', ['RichardII.txt'])
# (7966, 'shouldst', ['RichardII.txt', 'Hamlet.txt'])
# (7967, 'sire', ['RichardII.txt'])
# (7968, 'executioner', ['RichardII.txt'])
# (7969, 'overproud', ['RichardII.txt'])
# (7970, 'daring', ['RichardII.txt'])
# (7971, 'unjust', ['RichardII.txt'])
# (7972, 'brandish', ['RichardII.txt'])
# (7973, 'bond', ['RichardII.txt'])
# (7974, 'tie', ['RichardII.txt'])
# (7975, 'regalia', ['RichardII.txt'])
# (7976, 'tutor', ['RichardII.txt', 'Hamlet.txt', 'RomeoJuliet.txt'])
# (7977, 'ravel', ['RichardII.txt', 'Hamlet.txt'])
# (7978, 'font', ['RichardII.txt'])
# (7979, 'silent', ['RichardII.txt'])
# (7980, 'givst', ['RichardII.txt'])
# (7981, 'conveyers', ['RichardII.txt'])
# (7982, 'paw', ['RichardII.txt'])
# (7983, 'knowest', ['RichardII.txt', 'Hamlet.txt', 'RomeoJuliet.txt'])
# (7984, 'theatre', ['RichardII.txt', 'Hamlet.txt'])
# (7985, 'troth', ['RichardII.txt', 'RomeoJuliet.txt'])
# (7986, 'conspiracy', ['RichardII.txt'])
# (7987, 'suspect', ['RichardII.txt'])
# (7988, 'begs', ['RichardII.txt'])
# (7989, 'dugs', ['RichardII.txt'])
# (7990, 'prayer', ['RichardII.txt', 'Hamlet.txt', 'RomeoJuliet.txt'])
# (7991, 'rehearse', ['RichardII.txt'])
# (7992, 'rail', ['RichardII.txt'])
# (7993, 'tird', ['RichardII.txt'])
# (7994, 'staggers', ['RichardII.txt'])
# (7995, 'cain', ['RichardII.txt'])
# (7996, 'fortinbras', ['Hamlet.txt'])
# (7997, 'francisco', ['Hamlet.txt'])
# (7998, 'heraldry', ['Hamlet.txt'])
# (7999, 'gaged', ['Hamlet.txt'])
# (8000, 'lawless', ['Hamlet.txt'])
# (8001, 'foresaid', ['Hamlet.txt'])
# (8002, 'main', ['Hamlet.txt', 'RomeoJuliet.txt'])
# (8003, 'preparations', ['Hamlet.txt'])
# (8004, 'gibber', ['Hamlet.txt'])
# (8005, 'empire', ['Hamlet.txt', 'RomeoJuliet.txt'])
# (8006, 'dirge', ['Hamlet.txt'])
# (8007, 'obstinate', ['Hamlet.txt'])
# (8008, 'hercules', ['Hamlet.txt'])
# (8009, 'attent', ['Hamlet.txt'])
# (8010, 'secrecy', ['Hamlet.txt'])
# (8011, 'hitherto', ['Hamlet.txt'])
# (8012, 'lesson', ['Hamlet.txt'])
# (8013, 'springes', ['Hamlet.txt'])
# (8014, 'mere', ['Hamlet.txt'])
# (8015, 'bawds', ['Hamlet.txt'])
# (8016, 'nipping', ['Hamlet.txt'])
# (8017, 'stamp', ['Hamlet.txt'])
# (8018, 'hearsed', ['Hamlet.txt'])
# (8019, 'impartment', ['Hamlet.txt'])
# (8020, 'porches', ['Hamlet.txt'])
# (8021, 'smile', ['Hamlet.txt', 'RomeoJuliet.txt'])
# (8022, 'truepenny', ['Hamlet.txt'])
# (8023, 'fencing', ['Hamlet.txt'])
# (8024, 'obeys', ['Hamlet.txt'])
# (8025, 'regards', ['Hamlet.txt'])
# (8026, 'hits', ['Hamlet.txt'])
# (8027, 'quintessence', ['Hamlet.txt'])
# (8028, 'gratis', ['Hamlet.txt'])
# (8029, 'escoted', ['Hamlet.txt'])
# (8030, 'clouts', ['Hamlet.txt'])
# (8031, 'roscius', ['Hamlet.txt'])
# (8032, 'seneca', ['Hamlet.txt'])
# (8033, 'handsome', ['Hamlet.txt', 'RomeoJuliet.txt'])
# (8034, 'pyrrhus', ['Hamlet.txt'])
# (8035, 'roasted', ['Hamlet.txt'])
# (8036, 'repugnant', ['Hamlet.txt'])
# (8037, 'stoops', ['Hamlet.txt'])
# (8038, 'remorse', ['Hamlet.txt'])
# (8039, 'whipping', ['Hamlet.txt'])
# (8040, 'rascal', ['Hamlet.txt'])
# (8041, 'foh', ['Hamlet.txt'])
# (8042, 'blench', ['Hamlet.txt'])
# (8043, 'forcing', ['Hamlet.txt'])
# (8044, 'espials', ['Hamlet.txt'])
# (8045, 'consummation', ['Hamlet.txt'])
# (8046, 'insolence', ['Hamlet.txt'])
# (8047, 'nymph', ['Hamlet.txt'])
# (8048, 'nowhere', ['Hamlet.txt'])
# (8049, 'paintings', ['Hamlet.txt'])
# (8050, 'blown', ['Hamlet.txt'])
# (8051, 'periwigpated', ['Hamlet.txt'])
# (8052, 'profanely', ['Hamlet.txt'])
# (8053, 'bellowed', ['Hamlet.txt'])
# (8054, 'danish', ['Hamlet.txt'])
# (8055, 'enact', ['Hamlet.txt'])
# (8056, 'lying', ['Hamlet.txt'])
# (8057, 'rock', ['Hamlet.txt'])
# (8058, 'tropically', ['Hamlet.txt'])
# (8059, 'withers', ['Hamlet.txt'])
# (8060, 'interpret', ['Hamlet.txt'])
# (8061, 'damnable', ['Hamlet.txt'])
# (8062, 'bellow', ['Hamlet.txt'])
# (8063, 'strucken', ['Hamlet.txt', 'RomeoJuliet.txt'])
# (8064, 'razed', ['Hamlet.txt'])
# (8065, 'diseased', ['Hamlet.txt'])
# (8066, 'fret', ['Hamlet.txt'])
# (8067, 'quake', ['Hamlet.txt'])
# (8068, 'gulf', ['Hamlet.txt'])
# (8069, 'highest', ['Hamlet.txt'])
# (8070, 'forestalled', ['Hamlet.txt'])
# (8071, 'struggling', ['Hamlet.txt'])
# (8072, 'rat', ['Hamlet.txt', 'RomeoJuliet.txt'])
# (8073, 'blasting', ['Hamlet.txt'])
# (8074, 'hover', ['Hamlet.txt'])
# (8075, 'purer', ['Hamlet.txt'])
# (8076, 'threats', ['Hamlet.txt'])
# (8077, 'disease', ['Hamlet.txt'])
# (8078, 'demanded', ['Hamlet.txt'])
# (8079, 'rages', ['Hamlet.txt'])
# (8080, 'market', ['Hamlet.txt'])
# (8081, 'army', ['Hamlet.txt'])
# (8082, 'cockle', ['Hamlet.txt'])
# (8083, 'sandal', ['Hamlet.txt'])
# (8084, 'gis', ['Hamlet.txt'])
# (8085, 'impetuous', ['Hamlet.txt'])
# (8086, 'fennel', ['Hamlet.txt'])
# (8087, 'hatchment', ['Hamlet.txt'])
# (8088, 'rite', ['Hamlet.txt', 'RomeoJuliet.txt'])
# (8089, 'graveness', ['Hamlet.txt'])
# (8090, 'spark', ['Hamlet.txt'])
# (8091, 'snuff', ['Hamlet.txt'])
# (8092, 'knife', ['Hamlet.txt', 'RomeoJuliet.txt'])
# (8093, 'cataplasm', ['Hamlet.txt'])
# (8094, 'nonce', ['Hamlet.txt'])
# (8095, 'brook', ['Hamlet.txt'])
# (8096, 'element', ['Hamlet.txt'])
# (8097, 'offendendo', ['Hamlet.txt'])
# (8098, 'outlives', ['Hamlet.txt'])
# (8099, 'yaughan', ['Hamlet.txt'])
# (8100, 'quillets', ['Hamlet.txt'])
# (8101, 'buyer', ['Hamlet.txt'])
# (8102, 'likelihood', ['Hamlet.txt'])
# (8103, 'maimed', ['Hamlet.txt'])
# (8104, 'retiring', ['Hamlet.txt'])
# (8105, 'unsanctified', ['Hamlet.txt'])
# (8106, 'leaping', ['Hamlet.txt'])
# (8107, 'rant', ['Hamlet.txt'])
# (8108, 'unseal', ['Hamlet.txt'])
# (8109, 'goblins', ['Hamlet.txt'])
# (8110, 'angle', ['Hamlet.txt'])
# (8111, 'feelingly', ['Hamlet.txt'])
# (8112, 'passes', ['Hamlet.txt'])
# (8113, 'bevy', ['Hamlet.txt'])
# (8114, 'commended', ['Hamlet.txt'])
# (8115, 'foolery', ['Hamlet.txt'])
# (8116, 'cannons', ['Hamlet.txt', 'RomeoJuliet.txt'])
# (8117, 'aright', ['Hamlet.txt'])
# (8118, 'printed', ['Hamlet.txt', 'RomeoJuliet.txt'])
# (8119, 'wwwgutenbergorglicense', ['Hamlet.txt', 'RomeoJuliet.txt'])
# (8120, 'intellectual', ['Hamlet.txt', 'RomeoJuliet.txt'])
# (8121, 'unprotected', ['Hamlet.txt'])
# (8122, 'displaying', ['Hamlet.txt', 'RomeoJuliet.txt'])
# (8123, 'viewed', ['Hamlet.txt', 'RomeoJuliet.txt'])
# (8124, 'calculated', ['Hamlet.txt', 'RomeoJuliet.txt'])
# (8125, 'identification', ['Hamlet.txt', 'RomeoJuliet.txt'])
# (8126, 'early', ['RomeoJuliet.txt'])
# (8127, 'chor', ['RomeoJuliet.txt'])
# (8128, 'heartless', ['RomeoJuliet.txt'])
# (8129, 'quench', ['RomeoJuliet.txt'])
# (8130, 'brawls', ['RomeoJuliet.txt'])
# (8131, 'drave', ['RomeoJuliet.txt'])
# (8132, 'misshapen', ['RomeoJuliet.txt'])
# (8133, 'discreet', ['RomeoJuliet.txt'])
# (8134, 'choking', ['RomeoJuliet.txt'])
# (8135, 'supposd', ['RomeoJuliet.txt'])
# (8136, 'bide', ['RomeoJuliet.txt'])
# (8137, 'examine', ['RomeoJuliet.txt'])
# (8138, 'pencil', ['RomeoJuliet.txt'])
# (8139, 'learned', ['RomeoJuliet.txt'])
# (8140, 'sisters', ['RomeoJuliet.txt'])
# (8141, 'unattainted', ['RomeoJuliet.txt'])
# (8142, 'wheres', ['RomeoJuliet.txt'])
# (8143, 'maidenhead', ['RomeoJuliet.txt'])
# (8144, 'earthquake', ['RomeoJuliet.txt'])
# (8145, 'clasps', ['RomeoJuliet.txt'])
# (8146, 'servd', ['RomeoJuliet.txt'])
# (8147, 'game', ['RomeoJuliet.txt'])
# (8148, 'atomies', ['RomeoJuliet.txt'])
# (8149, 'bakes', ['RomeoJuliet.txt'])
# (8150, 'wooes', ['RomeoJuliet.txt'])
# (8151, 'climbs', ['RomeoJuliet.txt'])
# (8152, 'belonging', ['RomeoJuliet.txt'])
# (8153, 'swearst', ['RomeoJuliet.txt'])
# (8154, 'advance', ['RomeoJuliet.txt'])
# (8155, 'clears', ['RomeoJuliet.txt'])
# (8156, 'spell', ['RomeoJuliet.txt'])
# (8157, 'jour', ['RomeoJuliet.txt'])
# (8158, 'strain', ['RomeoJuliet.txt'])
# (8159, 'constrains', ['RomeoJuliet.txt'])
# (8160, 'stretches', ['RomeoJuliet.txt'])
# (8161, 'fan', ['RomeoJuliet.txt'])
# (8162, 'cords', ['RomeoJuliet.txt'])
# (8163, 'lieve', ['RomeoJuliet.txt'])
# (8164, 'oddly', ['RomeoJuliet.txt'])
# (8165, 'consume', ['RomeoJuliet.txt'])
# (8166, 'moderately', ['RomeoJuliet.txt'])
# (8167, 'operation', ['RomeoJuliet.txt'])
# (8168, 'minstrels', ['RomeoJuliet.txt'])
# (8169, 'follower', ['RomeoJuliet.txt'])
# (8170, 'stoccata', ['RomeoJuliet.txt'])
# (8171, 'tybalts', ['RomeoJuliet.txt'])
# (8172, 'tot', ['RomeoJuliet.txt'])
# (8173, 'robes', ['RomeoJuliet.txt'])
# (8174, 'unthankfulness', ['RomeoJuliet.txt'])
# (8175, 'heartsick', ['RomeoJuliet.txt'])
# (8176, 'conceald', ['RomeoJuliet.txt'])
# (8177, 'hunting', ['RomeoJuliet.txt'])
# (8178, 'absolvd', ['RomeoJuliet.txt'])
# (8179, 'abusd', ['RomeoJuliet.txt'])
# (8180, 'slandred', ['RomeoJuliet.txt'])
# (8181, 'twoandforty', ['RomeoJuliet.txt'])
# (8182, 'crowd', ['RomeoJuliet.txt'])
# (8183, 'logs', ['RomeoJuliet.txt'])
# (8184, 'hated', ['RomeoJuliet.txt'])
# (8185, 'advancd', ['RomeoJuliet.txt'])
# (8186, 'dirges', ['RomeoJuliet.txt'])
# (8187, 'griping', ['RomeoJuliet.txt'])
# (8188, 'suspecting', ['RomeoJuliet.txt'])
# (8189, 'distilld', ['RomeoJuliet.txt'])
# (8190, 'tigers', ['RomeoJuliet.txt'])
# (8191, 'unsavoury', ['RomeoJuliet.txt'])
# (8192, 'ambiguities', ['RomeoJuliet.txt'])
# (8193, 'miscarried', ['RomeoJuliet.txt'])
# (8194, 'writes', ['RomeoJuliet.txt'])
# (8195, 'httppglaforgfundraising', ['RomeoJuliet.txt'])
# (8196, 'httppglaforg', ['RomeoJuliet.txt'])

# %% [markdown]
# # Exercice 4

# %%
W_RJ_mm = W_RJ.map(lambda x: ((x,'RomeoJuliet.txt'),1) )
W_R_mm = W_R.map(lambda x: ((x,'RichardII.txt'),1) )
W_H_mm = W_H.map(lambda x: ((x,'Hamlet.txt'),1) )

W_RJ_mr  = W_RJ_mm .reduceByKey(lambda x,y : x+y)
W_R_mr  = W_R_mm .reduceByKey(lambda x,y : x+y)
W_H_mr  = W_H_mm .reduceByKey(lambda x,y : x+y)


union4 = W_RJ_mr.union(W_R_mr).union(W_H_mr)

preResult4 = union4.map(lambda x : (x[0][0],[(x[0][1],x[1])]))\
.reduceByKey(lambda x,y: x+y)
                 
Result4 = preResult4.zipWithIndex().map(lambda x: (x[1],x[0][0],x[0][1]))
                                                                                                 
for i in Result4.collect(): print(i)
#finalResult4 = spark.createDataFrame(Result4,["id","Word","Document #Frequency"])
#finalResult4.show(100,False)
# Out:
# Streaming output truncated to the last 5000 lines.
# (3197, 'posthaste', [('Hamlet.txt', 1)])
# (3198, 'tenantless', [('Hamlet.txt', 1)])
# (3199, 'sheeted', [('Hamlet.txt', 1)])
# (3200, 'squeak', [('Hamlet.txt', 1)])
# (3201, 'roman', [('Hamlet.txt', 2)])
# (3202, 'trains', [('Hamlet.txt', 2)])
# (3203, 'moist', [('Hamlet.txt', 1)])
# (3204, 'influence', [('Hamlet.txt', 1)])
# (3205, 'precurse', [('Hamlet.txt', 1)])
# (3206, 'harbingers', [('Hamlet.txt', 1)])
# (3207, 'preceding', [('Hamlet.txt', 1)])
# (3208, 'omen', [('Hamlet.txt', 1)])
# (3209, 'demonstrated', [('Hamlet.txt', 1)])
# (3210, 'blast', [('Hamlet.txt', 2)])
# (3211, 'illusion', [('Hamlet.txt', 1)])
# (3212, 'partisan', [('Hamlet.txt', 1)])
# (3213, 'majestical', [('Hamlet.txt', 2)])
# (3214, 'invulnerable', [('Hamlet.txt', 1)])
# (3215, 'started', [('Hamlet.txt', 1)])
# (3216, 'shrillsounding', [('Hamlet.txt', 1)])
# (3217, 'erring', [('Hamlet.txt', 1)])
# (3218, 'hies', [('Hamlet.txt', 1)])
# (3219, 'probation', [('Hamlet.txt', 1)])
# (3220, 'crowing', [('Hamlet.txt', 1)])
# (3221, 'celebrated', [('Hamlet.txt', 1)])
# (3222, 'dawning', [('Hamlet.txt', 1)])
# (3223, 'planets', [('Hamlet.txt', 1)])
# (3224, 'fairy', [('Hamlet.txt', 1)])
# (3225, 'eastward', [('Hamlet.txt', 1)])
# (3226, 'impart', [('Hamlet.txt', 4)])
# (3227, 'fitting', [('Hamlet.txt', 1)])
# (3228, 'befitted', [('Hamlet.txt', 1)])
# (3229, 'wisest', [('Hamlet.txt', 3)])
# (3230, 'defeated', [('Hamlet.txt', 1)])
# (3231, 'dropping', [('Hamlet.txt', 1)])
# (3232, 'wisdoms', [('Hamlet.txt', 1)])
# (3233, 'supposal', [('Hamlet.txt', 1)])
# (3234, 'disjoint', [('Hamlet.txt', 1)])
# (3235, 'frame', [('Hamlet.txt', 4)])
# (3236, 'colleagued', [('Hamlet.txt', 1)])
# (3237, 'impotent', [('Hamlet.txt', 1)])
# (3238, 'bedrid', [('Hamlet.txt', 1)])
# (3239, 'hears', [('Hamlet.txt', 3)])
# (3240, 'suppress', [('Hamlet.txt', 2)])
# (3241, 'proportions', [('Hamlet.txt', 1)])
# (3242, 'instrumental', [('Hamlet.txt', 1)])
# (3243, 'wishes', [('Hamlet.txt', 1)])
# (3244, 'laboursome', [('Hamlet.txt', 1)])
# (3245, 'nighted', [('Hamlet.txt', 1)])
# (3246, 'colour', [('Hamlet.txt', 5)])
# (3247, 'suits', [('Hamlet.txt', 3)])
# (3248, 'windy', [('Hamlet.txt', 1)])
# (3249, 'suspiration', [('Hamlet.txt', 1)])
# (3250, 'dejected', [('Hamlet.txt', 1)])
# (3251, 'moods', [('Hamlet.txt', 1)])
# (3252, 'passeth', [('Hamlet.txt', 1)])
# (3253, 'commendable', [('Hamlet.txt', 1)])
# (3254, 'duties', [('Hamlet.txt', 1)])
# (3255, 'survivor', [('Hamlet.txt', 1)])
# (3256, 'persevere', [('Hamlet.txt', 1)])
# (3257, 'incorrect', [('Hamlet.txt', 1)])
# (3258, 'unprevailing', [('Hamlet.txt', 1)])
# (3259, 'intent', [('Hamlet.txt', 2)])
# (3260, 'wittenberg', [('Hamlet.txt', 4)])
# (3261, 'accord', [('Hamlet.txt', 1)])
# (3262, 'smiling', [('Hamlet.txt', 3)])
# (3263, 'bruit', [('Hamlet.txt', 1)])
# (3264, 'respeaking', [('Hamlet.txt', 1)])
# (3265, 'thaw', [('Hamlet.txt', 1)])
# (3266, 'flat', [('Hamlet.txt', 3)])
# (3267, 'uses', [('Hamlet.txt', 3)])
# (3268, 'oh', [('Hamlet.txt', 3)])
# (3269, 'unweeded', [('Hamlet.txt', 1)])
# (3270, 'seed', [('Hamlet.txt', 1)])
# (3271, 'hyperion', [('Hamlet.txt', 1)])
# (3272, 'increase', [('Hamlet.txt', 1)])
# (3273, 'niobe', [('Hamlet.txt', 1)])
# (3274, 'unrighteous', [('Hamlet.txt', 1)])
# (3275, 'prithee', [('Hamlet.txt', 1)])
# (3276, 'fellowstudent', [('Hamlet.txt', 1)])
# (3277, 'admiration', [('Hamlet.txt', 3)])
# (3278, 'marvel', [('Hamlet.txt', 1)])
# (3279, 'middle', [('Hamlet.txt', 2)])
# (3280, 'fearsurprised', [('Hamlet.txt', 1)])
# (3281, 'jelly', [('Hamlet.txt', 1)])
# (3282, 'lifted', [('Hamlet.txt', 1)])
# (3283, 'troubles', [('Hamlet.txt', 2)])
# (3284, 'beaver', [('Hamlet.txt', 1)])
# (3285, 'constantly', [('Hamlet.txt', 1)])
# (3286, 'moderate', [('Hamlet.txt', 1)])
# (3287, 'gape', [('Hamlet.txt', 1)])
# (3288, 'tenable', [('Hamlet.txt', 1)])
# (3289, 'suppliance', [('Hamlet.txt', 1)])
# (3290, 'carve', [('Hamlet.txt', 1)])
# (3291, 'credent', [('Hamlet.txt', 1)])
# (3292, 'importunity', [('Hamlet.txt', 1)])
# (3293, 'chariest', [('Hamlet.txt', 1)])
# (3294, 'unmask', [('Hamlet.txt', 1)])
# (3295, 'scopes', [('Hamlet.txt', 1)])
# (3296, 'strokes', [('Hamlet.txt', 1)])
# (3297, 'contagious', [('Hamlet.txt', 1)])
# (3298, 'pastors', [('Hamlet.txt', 1)])
# (3299, 'thorny', [('Hamlet.txt', 1)])
# (3300, 'reckless', [('Hamlet.txt', 1)])
# (3301, 'libertine', [('Hamlet.txt', 1)])
# (3302, 'primrose', [('Hamlet.txt', 1)])
# (3303, 'recks', [('Hamlet.txt', 1)])
# (3304, 'adoption', [('Hamlet.txt', 1)])
# (3305, 'grapple', [('Hamlet.txt', 2)])
# (3306, 'hoops', [('Hamlet.txt', 1)])
# (3307, 'comrade', [('Hamlet.txt', 1)])
# (3308, 'censure', [('Hamlet.txt', 4)])
# (3309, 'reserve', [('Hamlet.txt', 1)])
# (3310, 'costly', [('Hamlet.txt', 1)])
# (3311, 'habit', [('Hamlet.txt', 4)])
# (3312, 'purse', [('Hamlet.txt', 3)])
# (3313, 'fancy', [('Hamlet.txt', 3)])
# (3314, 'proclaims', [('Hamlet.txt', 2)])
# (3315, 'station', [('Hamlet.txt', 2)])
# (3316, 'select', [('Hamlet.txt', 1)])
# (3317, 'loses', [('Hamlet.txt', 1)])
# (3318, 'husbandry', [('Hamlet.txt', 1)])
# (3319, 'bounteous', [('Hamlet.txt', 1)])
# (3320, 'behoves', [('Hamlet.txt', 1)])
# (3321, 'tenders', [('Hamlet.txt', 3)])
# (3322, 'pooh', [('Hamlet.txt', 1)])
# (3323, 'crack', [('Hamlet.txt', 1)])
# (3324, 'roaming', [('Hamlet.txt', 1)])
# (3325, 'woodcocks', [('Hamlet.txt', 1)])
# (3326, 'scanter', [('Hamlet.txt', 1)])
# (3327, 'entreatments', [('Hamlet.txt', 1)])
# (3328, 'higher', [('Hamlet.txt', 1)])
# (3329, 'larger', [('Hamlet.txt', 1)])
# (3330, 'tether', [('Hamlet.txt', 1)])
# (3331, 'brokers', [('Hamlet.txt', 1)])
# (3332, 'investments', [('Hamlet.txt', 1)])
# (3333, 'unholy', [('Hamlet.txt', 1)])
# (3334, 'pious', [('Hamlet.txt', 3)])
# (3335, 'wassail', [('Hamlet.txt', 1)])
# (3336, 'swaggering', [('Hamlet.txt', 1)])
# (3337, 'upspring', [('Hamlet.txt', 1)])
# (3338, 'drains', [('Hamlet.txt', 1)])
# (3339, 'draughts', [('Hamlet.txt', 1)])
# (3340, 'kettledrum', [('Hamlet.txt', 1)])
# (3341, 'observance', [('Hamlet.txt', 2)])
# (3342, 'heavyheaded', [('Hamlet.txt', 1)])
# (3343, 'nations', [('Hamlet.txt', 1)])
# (3344, 'clepe', [('Hamlet.txt', 1)])
# (3345, 'drunkards', [('Hamlet.txt', 1)])
# (3346, 'achievements', [('Hamlet.txt', 1)])
# (3347, 'marrow', [('Hamlet.txt', 1)])
# (3348, 'vicious', [('Hamlet.txt', 1)])
# (3349, 'mole', [('Hamlet.txt', 2)])
# (3350, 'origin', [('Hamlet.txt', 2)])
# (3351, 'pales', [('Hamlet.txt', 1)])
# (3352, 'plausive', [('Hamlet.txt', 1)])
# (3353, 'undergo', [('Hamlet.txt', 1)])
# (3354, 'evil', [('Hamlet.txt', 4)])
# (3355, 'ministers', [('Hamlet.txt', 1)])
# (3356, 'blasts', [('Hamlet.txt', 1)])
# (3357, 'questionable', [('Hamlet.txt', 1)])
# (3358, 'burst', [('Hamlet.txt', 3)])
# (3359, 'cerements', [('Hamlet.txt', 1)])
# (3360, 'quietly', [('Hamlet.txt', 1)])
# (3361, 'ponderous', [('Hamlet.txt', 1)])
# (3362, 'marble', [('Hamlet.txt', 1)])
# (3363, 'glimpses', [('Hamlet.txt', 1)])
# (3364, 'horridly', [('Hamlet.txt', 2)])
# (3365, 'beyond', [('Hamlet.txt', 2)])
# (3366, 'beckons', [('Hamlet.txt', 3)])
# (3367, 'waves', [('Hamlet.txt', 3)])
# (3368, 'summit', [('Hamlet.txt', 2)])
# (3369, 'cliff', [('Hamlet.txt', 1)])
# (3370, 'beetles', [('Hamlet.txt', 1)])
# (3371, 'deprive', [('Hamlet.txt', 1)])
# (3372, 'desperation', [('Hamlet.txt', 2)])
# (3373, 'beneath', [('Hamlet.txt', 4)])
# (3374, 'artery', [('Hamlet.txt', 1)])
# (3375, 'hardy', [('Hamlet.txt', 1)])
# (3376, 'nemean', [('Hamlet.txt', 1)])
# (3377, 'nerve', [('Hamlet.txt', 1)])
# (3378, 'unhand', [('Hamlet.txt', 1)])
# (3379, 'flames', [('Hamlet.txt', 2)])
# (3380, 'secrets', [('Hamlet.txt', 1)])
# (3381, 'prisonhouse', [('Hamlet.txt', 1)])
# (3382, 'freeze', [('Hamlet.txt', 1)])
# (3383, 'knotted', [('Hamlet.txt', 1)])
# (3384, 'fretful', [('Hamlet.txt', 1)])
# (3385, 'porcupine', [('Hamlet.txt', 1)])
# (3386, 'meditation', [('Hamlet.txt', 1)])
# (3387, 'sweep', [('Hamlet.txt', 2)])
# (3388, 'fat', [('Hamlet.txt', 6)])
# (3389, 'rots', [('Hamlet.txt', 1)])
# (3390, 'wharf', [('Hamlet.txt', 1)])
# (3391, 'stung', [('Hamlet.txt', 1)])
# (3392, 'rankly', [('Hamlet.txt', 1)])
# (3393, 'traitorous', [('Hamlet.txt', 1)])
# (3394, 'gifts', [('Hamlet.txt', 4)])
# (3395, 'lust', [('Hamlet.txt', 2)])
# (3396, 'falling', [('Hamlet.txt', 2)])
# (3397, 'decline', [('Hamlet.txt', 1)])
# (3398, 'prey', [('Hamlet.txt', 1)])
# (3399, 'garbage', [('Hamlet.txt', 1)])
# (3400, 'hebenon', [('Hamlet.txt', 1)])
# (3401, 'pour', [('Hamlet.txt', 1)])
# (3402, 'leperous', [('Hamlet.txt', 1)])
# (3403, 'distilment', [('Hamlet.txt', 1)])
# (3404, 'quicksilver', [('Hamlet.txt', 1)])
# (3405, 'gates', [('Hamlet.txt', 1)])
# (3406, 'posset', [('Hamlet.txt', 1)])
# (3407, 'curd', [('Hamlet.txt', 1)])
# (3408, 'lazarlike', [('Hamlet.txt', 1)])
# (3409, 'imperfections', [('Hamlet.txt', 1)])
# (3410, 'howsoever', [('Hamlet.txt', 1)])
# (3411, 'taint', [('Hamlet.txt', 1)])
# (3412, 'glowworm', [('Hamlet.txt', 1)])
# (3413, 'host', [('Hamlet.txt', 1)])
# (3414, 'distracted', [('Hamlet.txt', 3)])
# (3415, 'saws', [('Hamlet.txt', 1)])
# (3416, 'pressures', [('Hamlet.txt', 1)])
# (3417, 'observation', [('Hamlet.txt', 1)])
# (3418, 'baser', [('Hamlet.txt', 2)])
# (3419, 'illo', [('Hamlet.txt', 1)])
# (3420, 'hillo', [('Hamlet.txt', 1)])
# (3421, 'wonderful', [('Hamlet.txt', 2)])
# (3422, 'reveal', [('Hamlet.txt', 1)])
# (3423, 'dwelling', [('Hamlet.txt', 1)])
# (3424, 'arrant', [('Hamlet.txt', 2)])
# (3425, 'offend', [('Hamlet.txt', 1)])
# (3426, 'patrick', [('Hamlet.txt', 1)])
# (3427, 'vision', [('Hamlet.txt', 1)])
# (3428, 'scholars', [('Hamlet.txt', 1)])
# (3429, 'headshake', [('Hamlet.txt', 1)])
# (3430, 'doubtful', [('Hamlet.txt', 2)])
# (3431, 'ambiguous', [('Hamlet.txt', 1)])
# (3432, 'friending', [('Hamlet.txt', 1)])
# (3433, 'lack', [('Hamlet.txt', 6)])
# (3434, 'inquiry', [('Hamlet.txt', 1)])
# (3435, 'danskers', [('Hamlet.txt', 1)])
# (3436, 'nearer', [('Hamlet.txt', 2)])
# (3437, 'distant', [('Hamlet.txt', 1)])
# (3438, 'usual', [('Hamlet.txt', 1)])
# (3439, 'slips', [('Hamlet.txt', 1)])
# (3440, 'gaming', [('Hamlet.txt', 3)])
# (3441, 'swearing', [('Hamlet.txt', 2)])
# (3442, 'drabbing', [('Hamlet.txt', 1)])
# (3443, 'incontinency', [('Hamlet.txt', 1)])
# (3444, 'quaintly', [('Hamlet.txt', 1)])
# (3445, 'flash', [('Hamlet.txt', 1)])
# (3446, 'outbreak', [('Hamlet.txt', 1)])
# (3447, 'savageness', [('Hamlet.txt', 1)])
# (3448, 'sullies', [('Hamlet.txt', 1)])
# (3449, 'working', [('Hamlet.txt', 2)])
# (3450, 'videlicet', [('Hamlet.txt', 1)])
# (3451, 'windlasses', [('Hamlet.txt', 1)])
# (3452, 'assays', [('Hamlet.txt', 1)])
# (3453, 'indirections', [('Hamlet.txt', 1)])
# (3454, 'affrighted', [('Hamlet.txt', 1)])
# (3455, 'hat', [('Hamlet.txt', 2)])
# (3456, 'downgyved', [('Hamlet.txt', 1)])
# (3457, 'purport', [('Hamlet.txt', 1)])
# (3458, 'horrors', [('Hamlet.txt', 1)])
# (3459, 'wrist', [('Hamlet.txt', 1)])
# (3460, 'shaking', [('Hamlet.txt', 1)])
# (3461, 'shatter', [('Hamlet.txt', 1)])
# (3462, 'fordoes', [('Hamlet.txt', 1)])
# (3463, 'undertakings', [('Hamlet.txt', 1)])
# (3464, 'repel', [('Hamlet.txt', 1)])
# (3465, 'quoted', [('Hamlet.txt', 1)])
# (3466, 'trifle', [('Hamlet.txt', 1)])
# (3467, 'jealousy', [('Hamlet.txt', 2)])
# (3468, 'proper', [('Hamlet.txt', 2)])
# (3469, 'resembles', [('Hamlet.txt', 1)])
# (3470, 'vouchsafe', [('Hamlet.txt', 3)])
# (3471, 'companies', [('Hamlet.txt', 1)])
# (3472, 'pleasures', [('Hamlet.txt', 2)])
# (3473, 'gather', [('Hamlet.txt', 3)])
# (3474, 'glean', [('Hamlet.txt', 1)])
# (3475, 'afflicts', [('Hamlet.txt', 1)])
# (3476, 'majesties', [('Hamlet.txt', 2)])
# (3477, 'commanded', [('Hamlet.txt', 1)])
# (3478, 'changed', [('Hamlet.txt', 1)])
# (3479, 'practices', [('Hamlet.txt', 1)])
# (3480, 'joyfully', [('Hamlet.txt', 1)])
# (3481, 'hunts', [('Hamlet.txt', 1)])
# (3482, 'preparation', [('Hamlet.txt', 1)])
# (3483, 'polack', [('Hamlet.txt', 4)])
# (3484, 'impotence', [('Hamlet.txt', 1)])
# (3485, 'employ', [('Hamlet.txt', 1)])
# (3486, 'likes', [('Hamlet.txt', 3)])
# (3487, 'beautified', [('Hamlet.txt', 1)])
# (3488, 'solicitings', [('Hamlet.txt', 1)])
# (3489, 'desk', [('Hamlet.txt', 1)])
# (3490, 'mute', [('Hamlet.txt', 1)])
# (3491, 'lock', [('Hamlet.txt', 2)])
# (3492, 'admit', [('Hamlet.txt', 2)])
# (3493, 'tokens', [('Hamlet.txt', 1)])
# (3494, 'declension', [('Hamlet.txt', 1)])
# (3495, 'positively', [('Hamlet.txt', 1)])
# (3496, 'circumstances', [('Hamlet.txt', 1)])
# (3497, 'arras', [('Hamlet.txt', 5)])
# (3498, 'thereon', [('Hamlet.txt', 1)])
# (3499, 'board', [('Hamlet.txt', 1)])
# (3500, 'godamercy', [('Hamlet.txt', 1)])
# (3501, 'fishmonger', [('Hamlet.txt', 2)])
# (3502, 'picked', [('Hamlet.txt', 2)])
# (3503, 'conception', [('Hamlet.txt', 1)])
# (3504, 'harping', [('Hamlet.txt', 1)])
# (3505, 'satirical', [('Hamlet.txt', 1)])
# (3506, 'beards', [('Hamlet.txt', 1)])
# (3507, 'wrinkled', [('Hamlet.txt', 1)])
# (3508, 'purging', [('Hamlet.txt', 2)])
# (3509, 'thick', [('Hamlet.txt', 3)])
# (3510, 'amber', [('Hamlet.txt', 1)])
# (3511, 'gum', [('Hamlet.txt', 1)])
# (3512, 'plentiful', [('Hamlet.txt', 1)])
# (3513, 'potently', [('Hamlet.txt', 1)])
# (3514, 'crab', [('Hamlet.txt', 1)])
# (3515, 'replies', [('Hamlet.txt', 1)])
# (3516, 'prosperously', [('Hamlet.txt', 1)])
# (3517, 'honoured', [('Hamlet.txt', 1)])
# (3518, 'overhappy', [('Hamlet.txt', 1)])
# (3519, 'waist', [('Hamlet.txt', 1)])
# (3520, 'privates', [('Hamlet.txt', 1)])
# (3521, 'space', [('Hamlet.txt', 1)])
# (3522, 'quality', [('Hamlet.txt', 4)])
# (3523, 'halfpenny', [('Hamlet.txt', 1)])
# (3524, 'inclining', [('Hamlet.txt', 1)])
# (3525, 'modesties', [('Hamlet.txt', 1)])
# (3526, 'consonancy', [('Hamlet.txt', 1)])
# (3527, 'everpreserved', [('Hamlet.txt', 1)])
# (3528, 'proposer', [('Hamlet.txt', 1)])
# (3529, 'moult', [('Hamlet.txt', 1)])
# (3530, 'exercises', [('Hamlet.txt', 1)])
# (3531, 'heavily', [('Hamlet.txt', 1)])
# (3532, 'congregation', [('Hamlet.txt', 1)])
# (3533, 'vapours', [('Hamlet.txt', 1)])
# (3534, 'faculties', [('Hamlet.txt', 2)])
# (3535, 'admirable', [('Hamlet.txt', 1)])
# (3536, 'paragon', [('Hamlet.txt', 1)])
# (3537, 'lungs', [('Hamlet.txt', 2)])
# (3538, 'sere', [('Hamlet.txt', 1)])
# (3539, 'verse', [('Hamlet.txt', 1)])
# (3540, 'tragedians', [('Hamlet.txt', 1)])
# (3541, 'wonted', [('Hamlet.txt', 2)])
# (3542, 'tyrannically', [('Hamlet.txt', 1)])
# (3543, 'pursue', [('Hamlet.txt', 2)])
# (3544, 'tarre', [('Hamlet.txt', 1)])
# (3545, 'poet', [('Hamlet.txt', 1)])
# (3546, 'possible', [('Hamlet.txt', 4)])
# (3547, 'lived', [('Hamlet.txt', 1)])
# (3548, 'appurtenance', [('Hamlet.txt', 1)])
# (3549, 'ceremony', [('Hamlet.txt', 3)])
# (3550, 'garb', [('Hamlet.txt', 1)])
# (3551, 'unclefather', [('Hamlet.txt', 1)])
# (3552, 'auntmother', [('Hamlet.txt', 1)])
# (3553, 'deceived', [('Hamlet.txt', 2)])
# (3554, 'southerly', [('Hamlet.txt', 1)])
# (3555, 'hawk', [('Hamlet.txt', 1)])
# (3556, 'handsaw', [('Hamlet.txt', 1)])
# (3557, 'hearer', [('Hamlet.txt', 1)])
# (3558, 'buzz', [('Hamlet.txt', 2)])
# (3559, 'comedy', [('Hamlet.txt', 2)])
# (3560, 'pastoral', [('Hamlet.txt', 1)])
# (3561, 'pastoralcomical', [('Hamlet.txt', 1)])
# (3562, 'historicalpastoral', [('Hamlet.txt', 1)])
# (3563, 'tragicalhistorical', [('Hamlet.txt', 1)])
# (3564, 'individable', [('Hamlet.txt', 1)])
# (3565, 'unlimited', [('Hamlet.txt', 1)])
# (3566, 'jephthah', [('Hamlet.txt', 3)])
# (3567, 'loved', [('Hamlet.txt', 3)])
# (3568, 'chanson', [('Hamlet.txt', 1)])
# (3569, 'abridgement', [('Hamlet.txt', 1)])
# (3570, 'altitude', [('Hamlet.txt', 1)])
# (3571, 'uncurrent', [('Hamlet.txt', 1)])
# (3572, 'passionate', [('Hamlet.txt', 2)])
# (3573, 'pleased', [('Hamlet.txt', 1)])
# (3574, 'matters', [('Hamlet.txt', 2)])
# (3575, 'digested', [('Hamlet.txt', 1)])
# (3576, 'savoury', [('Hamlet.txt', 1)])
# (3577, 'indite', [('Hamlet.txt', 1)])
# (3578, 'affectation', [('Hamlet.txt', 1)])
# (3579, 'line', [('Hamlet.txt', 2)])
# (3580, 'rugged', [('Hamlet.txt', 2)])
# (3581, 'hyrcanian', [('Hamlet.txt', 1)])
# (3582, 'ominous', [('Hamlet.txt', 1)])
# (3583, 'gules', [('Hamlet.txt', 1)])
# (3584, 'impasted', [('Hamlet.txt', 1)])
# (3585, 'parching', [('Hamlet.txt', 1)])
# (3586, 'hellish', [('Hamlet.txt', 1)])
# (3587, 'priam', [('Hamlet.txt', 4)])
# (3588, 'drives', [('Hamlet.txt', 1)])
# (3589, 'flaming', [('Hamlet.txt', 2)])
# (3590, 'hush', [('Hamlet.txt', 1)])
# (3591, 'aroused', [('Hamlet.txt', 1)])
# (3592, 'eterne', [('Hamlet.txt', 1)])
# (3593, 'fellies', [('Hamlet.txt', 1)])
# (3594, 'fiends', [('Hamlet.txt', 1)])
# (3595, 'bawdry', [('Hamlet.txt', 1)])
# (3596, 'hecuba', [('Hamlet.txt', 4)])
# (3597, 'bisson', [('Hamlet.txt', 1)])
# (3598, 'robe', [('Hamlet.txt', 1)])
# (3599, 'caught', [('Hamlet.txt', 2)])
# (3600, 'mincing', [('Hamlet.txt', 1)])
# (3601, 'milch', [('Hamlet.txt', 1)])
# (3602, 'abstracts', [('Hamlet.txt', 1)])
# (3603, 'sixteen', [('Hamlet.txt', 1)])
# (3604, 'distraction', [('Hamlet.txt', 2)])
# (3605, 'horrid', [('Hamlet.txt', 2)])
# (3606, 'amaze', [('Hamlet.txt', 1)])
# (3607, 'peak', [('Hamlet.txt', 1)])
# (3608, 'johnadreams', [('Hamlet.txt', 1)])
# (3609, 'defeat', [('Hamlet.txt', 2)])
# (3610, 'tweaks', [('Hamlet.txt', 1)])
# (3611, 'fatted', [('Hamlet.txt', 1)])
# (3612, 'remorseless', [('Hamlet.txt', 1)])
# (3613, 'prompted', [('Hamlet.txt', 1)])
# (3614, 'unpack', [('Hamlet.txt', 1)])
# (3615, 'drab', [('Hamlet.txt', 1)])
# (3616, 'creatures', [('Hamlet.txt', 3)])
# (3617, 'malefactions', [('Hamlet.txt', 1)])
# (3618, 'miraculous', [('Hamlet.txt', 1)])
# (3619, 'pleasing', [('Hamlet.txt', 1)])
# (3620, 'potent', [('Hamlet.txt', 2)])
# (3621, 'damn', [('Hamlet.txt', 1)])
# (3622, 'confusion', [('Hamlet.txt', 1)])
# (3623, 'turbulent', [('Hamlet.txt', 1)])
# (3624, 'feels', [('Hamlet.txt', 1)])
# (3625, 'crafty', [('Hamlet.txt', 1)])
# (3626, 'niggard', [('Hamlet.txt', 1)])
# (3627, 'exercise', [('Hamlet.txt', 2)])
# (3628, 'smart', [('Hamlet.txt', 1)])
# (3629, 'beautied', [('Hamlet.txt', 1)])
# (3630, 'plastering', [('Hamlet.txt', 1)])
# (3631, 'nobler', [('Hamlet.txt', 1)])
# (3632, 'arrows', [('Hamlet.txt', 2)])
# (3633, 'heartache', [('Hamlet.txt', 1)])
# (3634, 'devoutly', [('Hamlet.txt', 1)])
# (3635, 'whips', [('Hamlet.txt', 2)])
# (3636, 'contumely', [('Hamlet.txt', 1)])
# (3637, 'spurns', [('Hamlet.txt', 2)])
# (3638, 'bodkin', [('Hamlet.txt', 1)])
# (3639, 'fardels', [('Hamlet.txt', 1)])
# (3640, 'grunt', [('Hamlet.txt', 1)])
# (3641, 'bourn', [('Hamlet.txt', 1)])
# (3642, 'traveller', [('Hamlet.txt', 1)])
# (3643, 'puzzles', [('Hamlet.txt', 1)])
# (3644, 'hue', [('Hamlet.txt', 1)])
# (3645, 'sicklied', [('Hamlet.txt', 1)])
# (3646, 'remembrances', [('Hamlet.txt', 1)])
# (3647, 'givers', [('Hamlet.txt', 1)])
# (3648, 'commerce', [('Hamlet.txt', 1)])
# (3649, 'translate', [('Hamlet.txt', 2)])
# (3650, 'paradox', [('Hamlet.txt', 1)])
# (3651, 'believed', [('Hamlet.txt', 1)])
# (3652, 'relish', [('Hamlet.txt', 2)])
# (3653, 'beck', [('Hamlet.txt', 1)])
# (3654, 'dowry', [('Hamlet.txt', 1)])
# (3655, 'escape', [('Hamlet.txt', 2)])
# (3656, 'calumny', [('Hamlet.txt', 1)])
# (3657, 'monsters', [('Hamlet.txt', 1)])
# (3658, 'lisp', [('Hamlet.txt', 1)])
# (3659, 'marriages', [('Hamlet.txt', 1)])
# (3660, 'jangled', [('Hamlet.txt', 1)])
# (3661, 'feature', [('Hamlet.txt', 2)])
# (3662, 'brood', [('Hamlet.txt', 1)])
# (3663, 'hatch', [('Hamlet.txt', 1)])
# (3664, 'disclose', [('Hamlet.txt', 1)])
# (3665, 'determination', [('Hamlet.txt', 1)])
# (3666, 'pronounced', [('Hamlet.txt', 1)])
# (3667, 'acquire', [('Hamlet.txt', 1)])
# (3668, 'temperance', [('Hamlet.txt', 1)])
# (3669, 'smoothness', [('Hamlet.txt', 1)])
# (3670, 'offends', [('Hamlet.txt', 1)])
# (3671, 'rags', [('Hamlet.txt', 1)])
# (3672, 'groundlings', [('Hamlet.txt', 1)])
# (3673, 'capable', [('Hamlet.txt', 1)])
# (3674, 'termagant', [('Hamlet.txt', 1)])
# (3675, 'outherods', [('Hamlet.txt', 1)])
# (3676, 'herod', [('Hamlet.txt', 1)])
# (3677, 'pressure', [('Hamlet.txt', 1)])
# (3678, 'unskilful', [('Hamlet.txt', 1)])
# (3679, 'judicious', [('Hamlet.txt', 1)])
# (3680, 'praise', [('Hamlet.txt', 2)])
# (3681, 'strutted', [('Hamlet.txt', 1)])
# (3682, 'journeymen', [('Hamlet.txt', 1)])
# (3683, 'reform', [('Hamlet.txt', 1)])
# (3684, 'considered', [('Hamlet.txt', 1)])
# (3685, 'conversation', [('Hamlet.txt', 1)])
# (3686, 'advancement', [('Hamlet.txt', 2)])
# (3687, 'clothe', [('Hamlet.txt', 1)])
# (3688, 'candied', [('Hamlet.txt', 1)])
# (3689, 'hinges', [('Hamlet.txt', 1)])
# (3690, 'fawning', [('Hamlet.txt', 1)])
# (3691, 'buffets', [('Hamlet.txt', 1)])
# (3692, 'rewards', [('Hamlet.txt', 2)])
# (3693, 'comingled', [('Hamlet.txt', 1)])
# (3694, 'prythee', [('Hamlet.txt', 2)])
# (3695, 'imaginations', [('Hamlet.txt', 1)])
# (3696, 'stithy', [('Hamlet.txt', 1)])
# (3697, 'heedful', [('Hamlet.txt', 1)])
# (3698, 'rivet', [('Hamlet.txt', 1)])
# (3699, 'detecting', [('Hamlet.txt', 1)])
# (3700, 'capons', [('Hamlet.txt', 1)])
# (3701, 'accounted', [('Hamlet.txt', 1)])
# (3702, 'caesar', [('Hamlet.txt', 2)])
# (3703, 'killed', [('Hamlet.txt', 1)])
# (3704, 'calf', [('Hamlet.txt', 1)])
# (3705, 'metal', [('Hamlet.txt', 1)])
# (3706, 'sables', [('Hamlet.txt', 2)])
# (3707, 'lovingly', [('Hamlet.txt', 1)])
# (3708, 'protestation', [('Hamlet.txt', 1)])
# (3709, 'declines', [('Hamlet.txt', 1)])
# (3710, 'exits', [('Hamlet.txt', 1)])
# (3711, 'carried', [('Hamlet.txt', 1)])
# (3712, 'woos', [('Hamlet.txt', 1)])
# (3713, 'loth', [('Hamlet.txt', 1)])
# (3714, 'miching', [('Hamlet.txt', 1)])
# (3715, 'mallicho', [('Hamlet.txt', 1)])
# (3716, 'cart', [('Hamlet.txt', 1)])
# (3717, 'orbed', [('Hamlet.txt', 1)])
# (3718, 'sheen', [('Hamlet.txt', 1)])
# (3719, 'hymen', [('Hamlet.txt', 1)])
# (3720, 'unite', [('Hamlet.txt', 1)])
# (3721, 'commutual', [('Hamlet.txt', 1)])
# (3722, 'journeys', [('Hamlet.txt', 1)])
# (3723, 'littlest', [('Hamlet.txt', 1)])
# (3724, 'operant', [('Hamlet.txt', 1)])
# (3725, 'functions', [('Hamlet.txt', 1)])
# (3726, 'accurst', [('Hamlet.txt', 1)])
# (3727, 'instances', [('Hamlet.txt', 1)])
# (3728, 'sticks', [('Hamlet.txt', 1)])
# (3729, 'mellow', [('Hamlet.txt', 1)])
# (3730, 'enactures', [('Hamlet.txt', 1)])
# (3731, 'slender', [('Hamlet.txt', 1)])
# (3732, 'mousetrap', [('Hamlet.txt', 1)])
# (3733, 'baptista', [('Hamlet.txt', 1)])
# (3734, 'touches', [('Hamlet.txt', 1)])
# (3735, 'dallying', [('Hamlet.txt', 1)])
# (3736, 'keen', [('Hamlet.txt', 2)])
# (3737, 'croaking', [('Hamlet.txt', 1)])
# (3738, 'ban', [('Hamlet.txt', 1)])
# (3739, 'infected', [('Hamlet.txt', 1)])
# (3740, 'poisons', [('Hamlet.txt', 1)])
# (3741, 'extant', [('Hamlet.txt', 1)])
# (3742, 'turk', [('Hamlet.txt', 1)])
# (3743, 'damon', [('Hamlet.txt', 1)])
# (3744, 'dismantled', [('Hamlet.txt', 1)])
# (3745, 'reigns', [('Hamlet.txt', 1)])
# (3746, 'rhymed', [('Hamlet.txt', 1)])
# (3747, 'poisoning', [('Hamlet.txt', 1)])
# (3748, 'retirement', [('Hamlet.txt', 1)])
# (3749, 'doctor', [('Hamlet.txt', 1)])
# (3750, 'plunge', [('Hamlet.txt', 1)])
# (3751, 'stonish', [('Hamlet.txt', 1)])
# (3752, 'pickers', [('Hamlet.txt', 1)])
# (3753, 'bar', [('Hamlet.txt', 1)])
# (3754, 'unmannerly', [('Hamlet.txt', 1)])
# (3755, 'stops', [('Hamlet.txt', 2)])
# (3756, 'mystery', [('Hamlet.txt', 1)])
# (3757, 'played', [('Hamlet.txt', 1)])
# (3758, 'cloud', [('Hamlet.txt', 1)])
# (3759, 'weasel', [('Hamlet.txt', 2)])
# (3760, 'backed', [('Hamlet.txt', 1)])
# (3761, 'nero', [('Hamlet.txt', 1)])
# (3762, 'hypocrites', [('Hamlet.txt', 1)])
# (3763, 'massy', [('Hamlet.txt', 1)])
# (3764, 'fetters', [('Hamlet.txt', 1)])
# (3765, 'eldest', [('Hamlet.txt', 1)])
# (3766, 'stronger', [('Hamlet.txt', 4)])
# (3767, 'defeats', [('Hamlet.txt', 1)])
# (3768, 'neglect', [('Hamlet.txt', 1)])
# (3769, 'thicker', [('Hamlet.txt', 1)])
# (3770, 'prize', [('Hamlet.txt', 1)])
# (3771, 'buys', [('Hamlet.txt', 1)])
# (3772, 'shuffling', [('Hamlet.txt', 2)])
# (3773, 'evidence', [('Hamlet.txt', 1)])
# (3774, 'repentance', [('Hamlet.txt', 1)])
# (3775, 'newborn', [('Hamlet.txt', 1)])
# (3776, 'praying', [('Hamlet.txt', 1)])
# (3777, 'hent', [('Hamlet.txt', 1)])
# (3778, 'salvation', [('Hamlet.txt', 2)])
# (3779, 'trip', [('Hamlet.txt', 1)])
# (3780, 'kick', [('Hamlet.txt', 1)])
# (3781, 'prolongs', [('Hamlet.txt', 1)])
# (3782, 'sickly', [('Hamlet.txt', 2)])
# (3783, 'pranks', [('Hamlet.txt', 1)])
# (3784, 'intruding', [('Hamlet.txt', 1)])
# (3785, 'bulwark', [('Hamlet.txt', 1)])
# (3786, 'blurs', [('Hamlet.txt', 1)])
# (3787, 'blister', [('Hamlet.txt', 1)])
# (3788, 'contraction', [('Hamlet.txt', 1)])
# (3789, 'rhapsody', [('Hamlet.txt', 1)])
# (3790, 'solidity', [('Hamlet.txt', 1)])
# (3791, 'compound', [('Hamlet.txt', 1)])
# (3792, 'tristful', [('Hamlet.txt', 1)])
# (3793, 'thoughtsick', [('Hamlet.txt', 1)])
# (3794, 'seated', [('Hamlet.txt', 1)])
# (3795, 'curls', [('Hamlet.txt', 1)])
# (3796, 'heavenkissing', [('Hamlet.txt', 1)])
# (3797, 'combination', [('Hamlet.txt', 1)])
# (3798, 'assurance', [('Hamlet.txt', 2)])
# (3799, 'moor', [('Hamlet.txt', 1)])
# (3800, 'ecstacy', [('Hamlet.txt', 1)])
# (3801, 'hoodmanblind', [('Hamlet.txt', 1)])
# (3802, 'sans', [('Hamlet.txt', 1)])
# (3803, 'mope', [('Hamlet.txt', 1)])
# (3804, 'compulsive', [('Hamlet.txt', 1)])
# (3805, 'ardour', [('Hamlet.txt', 1)])
# (3806, 'actively', [('Hamlet.txt', 1)])
# (3807, 'enseamed', [('Hamlet.txt', 1)])
# (3808, 'honeying', [('Hamlet.txt', 1)])
# (3809, 'nasty', [('Hamlet.txt', 1)])
# (3810, 'sty', [('Hamlet.txt', 1)])
# (3811, 'twentieth', [('Hamlet.txt', 1)])
# (3812, 'tithe', [('Hamlet.txt', 1)])
# (3813, 'cutpurse', [('Hamlet.txt', 1)])
# (3814, 'rule', [('Hamlet.txt', 1)])
# (3815, 'shreds', [('Hamlet.txt', 1)])
# (3816, 'blunted', [('Hamlet.txt', 1)])
# (3817, 'vacancy', [('Hamlet.txt', 1)])
# (3818, 'incorporal', [('Hamlet.txt', 1)])
# (3819, 'peep', [('Hamlet.txt', 2)])
# (3820, 'flame', [('Hamlet.txt', 2)])
# (3821, 'preaching', [('Hamlet.txt', 1)])
# (3822, 'temperately', [('Hamlet.txt', 1)])
# (3823, 'test', [('Hamlet.txt', 1)])
# (3824, 'reword', [('Hamlet.txt', 1)])
# (3825, 'ulcerous', [('Hamlet.txt', 1)])
# (3826, 'mining', [('Hamlet.txt', 1)])
# (3827, 'ranker', [('Hamlet.txt', 2)])
# (3828, 'fatness', [('Hamlet.txt', 1)])
# (3829, 'curb', [('Hamlet.txt', 2)])
# (3830, 'habits', [('Hamlet.txt', 1)])
# (3831, 'frock', [('Hamlet.txt', 1)])
# (3832, 'aptly', [('Hamlet.txt', 1)])
# (3833, 'refrain', [('Hamlet.txt', 1)])
# (3834, 'abstinence', [('Hamlet.txt', 1)])
# (3835, 'potency', [('Hamlet.txt', 1)])
# (3836, 'desirous', [('Hamlet.txt', 1)])
# (3837, 'punish', [('Hamlet.txt', 1)])
# (3838, 'bloat', [('Hamlet.txt', 1)])
# (3839, 'pinch', [('Hamlet.txt', 1)])
# (3840, 'reechy', [('Hamlet.txt', 1)])
# (3841, 'paddling', [('Hamlet.txt', 1)])
# (3842, 'essentially', [('Hamlet.txt', 1)])
# (3843, 'bat', [('Hamlet.txt', 2)])
# (3844, 'gib', [('Hamlet.txt', 1)])
# (3845, 'unpeg', [('Hamlet.txt', 1)])
# (3846, 'creep', [('Hamlet.txt', 1)])
# (3847, 'schoolfellows', [('Hamlet.txt', 1)])
# (3848, 'adders', [('Hamlet.txt', 1)])
# (3849, 'mandate', [('Hamlet.txt', 1)])
# (3850, 'enginer', [('Hamlet.txt', 1)])
# (3851, 'delve', [('Hamlet.txt', 1)])
# (3852, 'crafts', [('Hamlet.txt', 1)])
# (3853, 'lug', [('Hamlet.txt', 1)])
# (3854, 'guts', [('Hamlet.txt', 2)])
# (3855, 'dragging', [('Hamlet.txt', 1)])
# (3856, 'heaves', [('Hamlet.txt', 1)])
# (3857, 'contend', [('Hamlet.txt', 1)])
# (3858, 'mightier', [('Hamlet.txt', 1)])
# (3859, 'ore', [('Hamlet.txt', 1)])
# (3860, 'mineral', [('Hamlet.txt', 1)])
# (3861, 'metals', [('Hamlet.txt', 1)])
# (3862, 'mountains', [('Hamlet.txt', 2)])
# (3863, 'transports', [('Hamlet.txt', 1)])
# (3864, 'discord', [('Hamlet.txt', 1)])
# (3865, 'compounded', [('Hamlet.txt', 1)])
# (3866, 'sponge', [('Hamlet.txt', 2)])
# (3867, 'authorities', [('Hamlet.txt', 1)])
# (3868, 'jaw', [('Hamlet.txt', 1)])
# (3869, 'mouthed', [('Hamlet.txt', 1)])
# (3870, 'gleaned', [('Hamlet.txt', 1)])
# (3871, 'squeezing', [('Hamlet.txt', 1)])
# (3872, 'multitude', [('Hamlet.txt', 1)])
# (3873, 'diseases', [('Hamlet.txt', 1)])
# (3874, 'appliance', [('Hamlet.txt', 1)])
# (3875, 'convocation', [('Hamlet.txt', 1)])
# (3876, 'politic', [('Hamlet.txt', 1)])
# (3877, 'dishes', [('Hamlet.txt', 1)])
# (3878, 'quickness', [('Hamlet.txt', 1)])
# (3879, 'purposes', [('Hamlet.txt', 3)])
# (3880, 'cherub', [('Hamlet.txt', 1)])
# (3881, 'hectic', [('Hamlet.txt', 1)])
# (3882, 'haps', [('Hamlet.txt', 1)])
# (3883, 'marching', [('Hamlet.txt', 1)])
# (3884, 'conveyance', [('Hamlet.txt', 1)])
# (3885, 'rendezvous', [('Hamlet.txt', 1)])
# (3886, 'poland', [('Hamlet.txt', 3)])
# (3887, 'frontier', [('Hamlet.txt', 1)])
# (3888, 'straw', [('Hamlet.txt', 2)])
# (3889, 'occasions', [('Hamlet.txt', 2)])
# (3890, 'godlike', [('Hamlet.txt', 1)])
# (3891, 'fust', [('Hamlet.txt', 1)])
# (3892, 'bestial', [('Hamlet.txt', 1)])
# (3893, 'oblivion', [('Hamlet.txt', 1)])
# (3894, 'craven', [('Hamlet.txt', 1)])
# (3895, 'precisely', [('Hamlet.txt', 1)])
# (3896, 'sith', [('Hamlet.txt', 2)])
# (3897, 'examples', [('Hamlet.txt', 1)])
# (3898, 'invisible', [('Hamlet.txt', 1)])
# (3899, 'event', [('Hamlet.txt', 1)])
# (3900, 'exposing', [('Hamlet.txt', 1)])
# (3901, 'unsure', [('Hamlet.txt', 1)])
# (3902, 'continent', [('Hamlet.txt', 2)])
# (3903, 'distract', [('Hamlet.txt', 1)])
# (3904, 'tricks', [('Hamlet.txt', 3)])
# (3905, 'hems', [('Hamlet.txt', 1)])
# (3906, 'enviously', [('Hamlet.txt', 1)])
# (3907, 'straws', [('Hamlet.txt', 2)])
# (3908, 'unshaped', [('Hamlet.txt', 1)])
# (3909, 'nods', [('Hamlet.txt', 1)])
# (3910, 'unhappily', [('Hamlet.txt', 1)])
# (3911, 'conjectures', [('Hamlet.txt', 1)])
# (3912, 'spills', [('Hamlet.txt', 1)])
# (3913, 'turf', [('Hamlet.txt', 1)])
# (3914, 'bewept', [('Hamlet.txt', 1)])
# (3915, 'owl', [('Hamlet.txt', 1)])
# (3916, 'spies', [('Hamlet.txt', 1)])
# (3917, 'battalions', [('Hamlet.txt', 1)])
# (3918, 'muddied', [('Hamlet.txt', 1)])
# (3919, 'unwholesome', [('Hamlet.txt', 1)])
# (3920, 'whispers', [('Hamlet.txt', 1)])
# (3921, 'inter', [('Hamlet.txt', 1)])
# (3922, 'pictures', [('Hamlet.txt', 1)])
# (3923, 'buzzers', [('Hamlet.txt', 1)])
# (3924, 'infect', [('Hamlet.txt', 1)])
# (3925, 'arraign', [('Hamlet.txt', 1)])
# (3926, 'murdering', [('Hamlet.txt', 1)])
# (3927, 'ocean', [('Hamlet.txt', 1)])
# (3928, 'flats', [('Hamlet.txt', 1)])
# (3929, 'rabble', [('Hamlet.txt', 1)])
# (3930, 'ratifiers', [('Hamlet.txt', 1)])
# (3931, 'props', [('Hamlet.txt', 1)])
# (3932, 'danes', [('Hamlet.txt', 4)])
# (3933, 'harlot', [('Hamlet.txt', 1)])
# (3934, 'divinity', [('Hamlet.txt', 2)])
# (3935, 'hedge', [('Hamlet.txt', 1)])
# (3936, 'juggled', [('Hamlet.txt', 1)])
# (3937, 'profoundest', [('Hamlet.txt', 1)])
# (3938, 'throughly', [('Hamlet.txt', 1)])
# (3939, 'sweepstake', [('Hamlet.txt', 1)])
# (3940, 'winner', [('Hamlet.txt', 1)])
# (3941, 'repast', [('Hamlet.txt', 1)])
# (3942, 'dressed', [('Hamlet.txt', 1)])
# (3943, 'adown', [('Hamlet.txt', 1)])
# (3944, 'fitted', [('Hamlet.txt', 1)])
# (3945, 'columbines', [('Hamlet.txt', 1)])
# (3946, 'sundays', [('Hamlet.txt', 1)])
# (3947, 'robin', [('Hamlet.txt', 1)])
# (3948, 'prettiness', [('Hamlet.txt', 1)])
# (3949, 'flaxen', [('Hamlet.txt', 1)])
# (3950, 'poll', [('Hamlet.txt', 1)])
# (3951, 'collateral', [('Hamlet.txt', 1)])
# (3952, 'jointly', [('Hamlet.txt', 1)])
# (3953, 'trophy', [('Hamlet.txt', 1)])
# (3954, 'formal', [('Hamlet.txt', 1)])
# (3955, 'greeted', [('Hamlet.txt', 1)])
# (3956, 'overlooked', [('Hamlet.txt', 1)])
# (3957, 'appointment', [('Hamlet.txt', 1)])
# (3958, 'speedier', [('Hamlet.txt', 1)])
# (3959, 'proceeded', [('Hamlet.txt', 1)])
# (3960, 'feats', [('Hamlet.txt', 1)])
# (3961, 'crimeful', [('Hamlet.txt', 1)])
# (3962, 'sphere', [('Hamlet.txt', 1)])
# (3963, 'gender', [('Hamlet.txt', 1)])
# (3964, 'dipping', [('Hamlet.txt', 1)])
# (3965, 'turneth', [('Hamlet.txt', 1)])
# (3966, 'recount', [('Hamlet.txt', 1)])
# (3967, 'postscript', [('Hamlet.txt', 1)])
# (3968, 'lamond', [('Hamlet.txt', 1)])
# (3969, 'masterly', [('Hamlet.txt', 1)])
# (3970, 'swore', [('Hamlet.txt', 1)])
# (3971, 'envenom', [('Hamlet.txt', 1)])
# (3972, 'painting', [('Hamlet.txt', 1)])
# (3973, 'wick', [('Hamlet.txt', 1)])
# (3974, 'pleurisy', [('Hamlet.txt', 1)])
# (3975, 'delays', [('Hamlet.txt', 1)])
# (3976, 'hurts', [('Hamlet.txt', 1)])
# (3977, 'excellence', [('Hamlet.txt', 3)])
# (3978, 'varnish', [('Hamlet.txt', 1)])
# (3979, 'unbated', [('Hamlet.txt', 2)])
# (3980, 'mountebank', [('Hamlet.txt', 1)])
# (3981, 'rare', [('Hamlet.txt', 1)])
# (3982, 'convenience', [('Hamlet.txt', 1)])
# (3983, 'performance', [('Hamlet.txt', 1)])
# (3984, 'stuck', [('Hamlet.txt', 1)])
# (3985, 'willow', [('Hamlet.txt', 1)])
# (3986, 'hoary', [('Hamlet.txt', 1)])
# (3987, 'garlands', [('Hamlet.txt', 1)])
# (3988, 'purples', [('Hamlet.txt', 1)])
# (3989, 'pendant', [('Hamlet.txt', 1)])
# (3990, 'sliver', [('Hamlet.txt', 1)])
# (3991, 'weedy', [('Hamlet.txt', 1)])
# (3992, 'tunes', [('Hamlet.txt', 1)])
# (3993, 'incapable', [('Hamlet.txt', 1)])
# (3994, 'distress', [('Hamlet.txt', 1)])
# (3995, 'indued', [('Hamlet.txt', 1)])
# (3996, 'garments', [('Hamlet.txt', 1)])
# (3997, 'melodious', [('Hamlet.txt', 1)])
# (3998, 'spades', [('Hamlet.txt', 1)])
# (3999, 'wilfully', [('Hamlet.txt', 1)])
# (4000, 'crowner', [('Hamlet.txt', 1)])
# (4001, 'sat', [('Hamlet.txt', 2)])
# (4002, 'nill', [('Hamlet.txt', 1)])
# (4003, 'ditchers', [('Hamlet.txt', 1)])
# (4004, 'profession', [('Hamlet.txt', 1)])
# (4005, 'scripture', [('Hamlet.txt', 2)])
# (4006, 'dig', [('Hamlet.txt', 2)])
# (4007, 'mason', [('Hamlet.txt', 2)])
# (4008, 'carpenter', [('Hamlet.txt', 2)])
# (4009, 'gallowsmaker', [('Hamlet.txt', 1)])
# (4010, 'tenants', [('Hamlet.txt', 1)])
# (4011, 'gallows', [('Hamlet.txt', 3)])
# (4012, 'cudgel', [('Hamlet.txt', 1)])
# (4013, 'stoup', [('Hamlet.txt', 1)])
# (4014, 'digs', [('Hamlet.txt', 1)])
# (4015, 'behove', [('Hamlet.txt', 1)])
# (4016, 'gravemaking', [('Hamlet.txt', 1)])
# (4017, 'daintier', [('Hamlet.txt', 1)])
# (4018, 'politician', [('Hamlet.txt', 1)])
# (4019, 'suchaone', [('Hamlet.txt', 1)])
# (4020, 'praised', [('Hamlet.txt', 1)])
# (4021, 'knocked', [('Hamlet.txt', 1)])
# (4022, 'mazard', [('Hamlet.txt', 1)])
# (4023, 'revolution', [('Hamlet.txt', 1)])
# (4024, 'pickaxe', [('Hamlet.txt', 1)])
# (4025, 'cases', [('Hamlet.txt', 1)])
# (4026, 'tenures', [('Hamlet.txt', 1)])
# (4027, 'shovel', [('Hamlet.txt', 1)])
# (4028, 'battery', [('Hamlet.txt', 1)])
# (4029, 'recognizances', [('Hamlet.txt', 1)])
# (4030, 'vouchers', [('Hamlet.txt', 2)])
# (4031, 'purchases', [('Hamlet.txt', 1)])
# (4032, 'breadth', [('Hamlet.txt', 1)])
# (4033, 'indentures', [('Hamlet.txt', 1)])
# (4034, 'jot', [('Hamlet.txt', 2)])
# (4035, 'sheep', [('Hamlet.txt', 1)])
# (4036, 'calves', [('Hamlet.txt', 1)])
# (4037, 'absolute', [('Hamlet.txt', 2)])
# (4038, 'equivocation', [('Hamlet.txt', 1)])
# (4039, 'losing', [('Hamlet.txt', 1)])
# (4040, 'sexton', [('Hamlet.txt', 1)])
# (4041, 'pocky', [('Hamlet.txt', 1)])
# (4042, 'decayer', [('Hamlet.txt', 1)])
# (4043, 'threeandtwenty', [('Hamlet.txt', 1)])
# (4044, 'jester', [('Hamlet.txt', 1)])
# (4045, 'gorge', [('Hamlet.txt', 1)])
# (4046, 'gambols', [('Hamlet.txt', 1)])
# (4047, 'flashes', [('Hamlet.txt', 1)])
# (4048, 'looked', [('Hamlet.txt', 1)])
# (4049, 'pah', [('Hamlet.txt', 1)])
# (4050, 'trace', [('Hamlet.txt', 2)])
# (4051, 'stopping', [('Hamlet.txt', 1)])
# (4052, 'bunghole', [('Hamlet.txt', 1)])
# (4053, 'consider', [('Hamlet.txt', 2)])
# (4054, 'curiously', [('Hamlet.txt', 1)])
# (4055, 'procession', [('Hamlet.txt', 1)])
# (4056, 'corpse', [('Hamlet.txt', 1)])
# (4057, 'fordo', [('Hamlet.txt', 1)])
# (4058, 'shards', [('Hamlet.txt', 1)])
# (4059, 'flints', [('Hamlet.txt', 1)])
# (4060, 'pebbles', [('Hamlet.txt', 1)])
# (4061, 'virgin', [('Hamlet.txt', 1)])
# (4062, 'strewments', [('Hamlet.txt', 1)])
# (4063, 'sage', [('Hamlet.txt', 1)])
# (4064, 'requiem', [('Hamlet.txt', 1)])
# (4065, 'peaceparted', [('Hamlet.txt', 1)])
# (4066, 'unpolluted', [('Hamlet.txt', 1)])
# (4067, 'treble', [('Hamlet.txt', 2)])
# (4068, 'pile', [('Hamlet.txt', 1)])
# (4069, 'olympus', [('Hamlet.txt', 1)])
# (4070, 'advancing', [('Hamlet.txt', 1)])
# (4071, 'conjures', [('Hamlet.txt', 1)])
# (4072, 'grappling', [('Hamlet.txt', 1)])
# (4073, 'splenative', [('Hamlet.txt', 1)])
# (4074, 'wiseness', [('Hamlet.txt', 1)])
# (4075, 'whine', [('Hamlet.txt', 1)])
# (4076, 'outface', [('Hamlet.txt', 1)])
# (4077, 'millions', [('Hamlet.txt', 1)])
# (4078, 'acres', [('Hamlet.txt', 1)])
# (4079, 'zone', [('Hamlet.txt', 1)])
# (4080, 'ossa', [('Hamlet.txt', 1)])
# (4081, 'strengthen', [('Hamlet.txt', 1)])
# (4082, 'mutinies', [('Hamlet.txt', 1)])
# (4083, 'bilboes', [('Hamlet.txt', 1)])
# (4084, 'rashness', [('Hamlet.txt', 1)])
# (4085, 'indiscretion', [('Hamlet.txt', 1)])
# (4086, 'plots', [('Hamlet.txt', 2)])
# (4087, 'roughhew', [('Hamlet.txt', 1)])
# (4088, 'cabin', [('Hamlet.txt', 1)])
# (4089, 'seagown', [('Hamlet.txt', 1)])
# (4090, 'packet', [('Hamlet.txt', 1)])
# (4091, 'sorts', [('Hamlet.txt', 1)])
# (4092, 'supervise', [('Hamlet.txt', 1)])
# (4093, 'baseness', [('Hamlet.txt', 1)])
# (4094, 'comma', [('Hamlet.txt', 1)])
# (4095, 'amities', [('Hamlet.txt', 1)])
# (4096, 'suchlike', [('Hamlet.txt', 1)])
# (4097, 'shrivingtime', [('Hamlet.txt', 1)])
# (4098, 'ordinant', [('Hamlet.txt', 1)])
# (4099, 'changeling', [('Hamlet.txt', 1)])
# (4100, 'insinuation', [('Hamlet.txt', 1)])
# (4101, 'incensed', [('Hamlet.txt', 1)])
# (4102, 'opposites', [('Hamlet.txt', 1)])
# (4103, 'perfect', [('Hamlet.txt', 1)])
# (4104, 'interim', [('Hamlet.txt', 1)])
# (4105, 'waterfly', [('Hamlet.txt', 1)])
# (4106, 'crib', [('Hamlet.txt', 1)])
# (4107, 'chough', [('Hamlet.txt', 1)])
# (4108, 'spacious', [('Hamlet.txt', 1)])
# (4109, 'northerly', [('Hamlet.txt', 1)])
# (4110, 'calendar', [('Hamlet.txt', 1)])
# (4111, 'definement', [('Hamlet.txt', 1)])
# (4112, 'perdition', [('Hamlet.txt', 1)])
# (4113, 'verity', [('Hamlet.txt', 1)])
# (4114, 'extolment', [('Hamlet.txt', 1)])
# (4115, 'infusion', [('Hamlet.txt', 1)])
# (4116, 'rareness', [('Hamlet.txt', 1)])
# (4117, 'diction', [('Hamlet.txt', 1)])
# (4118, 'semblable', [('Hamlet.txt', 1)])
# (4119, 'umbrage', [('Hamlet.txt', 1)])
# (4120, 'really', [('Hamlet.txt', 1)])
# (4121, 'meed', [('Hamlet.txt', 1)])
# (4122, 'unfellowed', [('Hamlet.txt', 1)])
# (4123, 'assigns', [('Hamlet.txt', 2)])
# (4124, 'hangers', [('Hamlet.txt', 3)])
# (4125, 'german', [('Hamlet.txt', 1)])
# (4126, 'conceited', [('Hamlet.txt', 1)])
# (4127, 'exceed', [('Hamlet.txt', 1)])
# (4128, 'lapwing', [('Hamlet.txt', 1)])
# (4129, 'drossy', [('Hamlet.txt', 1)])
# (4130, 'yeasty', [('Hamlet.txt', 1)])
# (4131, 'winnowed', [('Hamlet.txt', 1)])
# (4132, 'instructs', [('Hamlet.txt', 1)])
# (4133, 'gaingiving', [('Hamlet.txt', 1)])
# (4134, 'forestall', [('Hamlet.txt', 1)])
# (4135, 'augury', [('Hamlet.txt', 1)])
# (4136, 'sparrow', [('Hamlet.txt', 1)])
# (4137, 'readiness', [('Hamlet.txt', 1)])
# (4138, 'exception', [('Hamlet.txt', 1)])
# (4139, 'reconcilement', [('Hamlet.txt', 1)])
# (4140, 'darkest', [('Hamlet.txt', 1)])
# (4141, 'stoups', [('Hamlet.txt', 1)])
# (4142, 'cups', [('Hamlet.txt', 1)])
# (4143, 'kettle', [('Hamlet.txt', 1)])
# (4144, 'judges', [('Hamlet.txt', 1)])
# (4145, 'palpable', [('Hamlet.txt', 1)])
# (4146, 'pearl', [('Hamlet.txt', 1)])
# (4147, 'dally', [('Hamlet.txt', 1)])
# (4148, 'villany', [('Hamlet.txt', 1)])
# (4149, 'murderous', [('Hamlet.txt', 1)])
# (4150, 'sergeant', [('Hamlet.txt', 1)])
# (4151, 'felicity', [('Hamlet.txt', 1)])
# (4152, 'afar', [('Hamlet.txt', 1)])
# (4153, 'volley', [('Hamlet.txt', 1)])
# (4154, 'flights', [('Hamlet.txt', 1)])
# (4155, 'quarry', [('Hamlet.txt', 1)])
# (4156, 'unknowing', [('Hamlet.txt', 1)])
# (4157, 'accidental', [('Hamlet.txt', 1)])
# (4158, 'casual', [('Hamlet.txt', 1)])
# (4159, 'noblest', [('Hamlet.txt', 1)])
# (4160, 'loudly', [('Hamlet.txt', 1)])
# (4161, 'website', [('Hamlet.txt', 4)])
# (4162, 'manager', [('Hamlet.txt', 1)])
# (4163, 'nonprofit', [('Hamlet.txt', 1)])
# (4164, 'wwwgutenbergorgcontact', [('Hamlet.txt', 1)])
# (4165, 'widespread', [('Hamlet.txt', 1)])
# (4166, 'machinereadable', [('Hamlet.txt', 1)])
# (4167, 'wwwgutenbergorgdonate', [('Hamlet.txt', 2)])
# (4168, 'etext', [('RichardII.txt', 29), ('RomeoJuliet.txt', 2)])
# (4169, 'file', [('RichardII.txt', 3), ('Hamlet.txt', 1), ('RomeoJuliet.txt', 2)])
# (4170, 'future', [('RichardII.txt', 5), ('Hamlet.txt', 3), ('RomeoJuliet.txt', 6)])
# (4171, 'often', [('RichardII.txt', 3), ('Hamlet.txt', 4), ('RomeoJuliet.txt', 3)])
# (4172, 'releases', [('RichardII.txt', 1)])
# (4173, 'etexts', [('RichardII.txt', 7)])
# (4174, 'electronic', [('RichardII.txt', 19), ('Hamlet.txt', 27), ('RomeoJuliet.txt', 29)])
# (4175, 'complete', [('RichardII.txt', 16), ('Hamlet.txt', 1), ('RomeoJuliet.txt', 4)])
# (4176, 'works', [('RichardII.txt', 15), ('Hamlet.txt', 33), ('RomeoJuliet.txt', 36)])
# (4177, 'william', [('RichardII.txt', 14), ('Hamlet.txt', 3), ('RomeoJuliet.txt', 8)])
# (4178, 'provided', [('RichardII.txt', 11), ('Hamlet.txt', 5), ('RomeoJuliet.txt', 6)])
# (4179, 'permission', [('RichardII.txt', 9), ('Hamlet.txt', 6), ('RomeoJuliet.txt', 8)])
# (4180, 'readable', [('RichardII.txt', 12), ('Hamlet.txt', 1), ('RomeoJuliet.txt', 3)])
# (4181, 'copies', [('RichardII.txt', 20), ('Hamlet.txt', 7), ('RomeoJuliet.txt', 9)])
# (4182, 'distributed', [('RichardII.txt', 18), ('Hamlet.txt', 4), ('RomeoJuliet.txt', 6)])
# (4183, 'personal', [('RichardII.txt', 9), ('Hamlet.txt', 1), ('RomeoJuliet.txt', 1)])
# (4184, 'commercially', [('RichardII.txt', 9), ('RomeoJuliet.txt', 1)])
# (4185, 'includes', [('RichardII.txt', 9), ('Hamlet.txt', 1), ('RomeoJuliet.txt', 2)])
# (4186, 'download', [('RichardII.txt', 9), ('RomeoJuliet.txt', 1)])
# (4187, 'time', [('RichardII.txt', 48), ('Hamlet.txt', 43), ('RomeoJuliet.txt', 34)])
# (4188, 'membership', [('RichardII.txt', 9), ('RomeoJuliet.txt', 1)])
# (4189, 'proud', [('RichardII.txt', 15), ('Hamlet.txt', 3), ('RomeoJuliet.txt', 7)])
# (4190, 'cooperate', [('RichardII.txt', 1), ('RomeoJuliet.txt', 1)])
# (4191, 'reading', [('RichardII.txt', 1), ('Hamlet.txt', 3), ('RomeoJuliet.txt', 2)])
# (4192, 'education', [('RichardII.txt', 1), ('RomeoJuliet.txt', 1)])
# (4193, 'entertainment', [('RichardII.txt', 1), ('Hamlet.txt', 4), ('RomeoJuliet.txt', 1)])
# (4194, 'made', [('RichardII.txt', 26), ('Hamlet.txt', 29), ('RomeoJuliet.txt', 21)])
# (4195, 'access', [('RichardII.txt', 1), ('Hamlet.txt', 11), ('RomeoJuliet.txt', 12)])
# (4196, 'allowed', [('RichardII.txt', 1), ('Hamlet.txt', 1), ('RomeoJuliet.txt', 1)])
# (4197, 'welcome', [('RichardII.txt', 14), ('Hamlet.txt', 16), ('RomeoJuliet.txt', 8)])
# (4198, 'plain', [('RichardII.txt', 5), ('Hamlet.txt', 5), ('RomeoJuliet.txt', 3)])
# (4199, 'humans', [('RichardII.txt', 1)])
# (4200, 'since', [('RichardII.txt', 21), ('Hamlet.txt', 18), ('RomeoJuliet.txt', 11)])
# (4201, 'hundreds', [('RichardII.txt', 1), ('Hamlet.txt', 1), ('RomeoJuliet.txt', 1)])
# (4202, 'donations', [('RichardII.txt', 4), ('Hamlet.txt', 15), ('RomeoJuliet.txt', 15)])
# (4203, 'information', [('RichardII.txt', 5), ('Hamlet.txt', 8), ('RomeoJuliet.txt', 8)])
# (4204, 'contacting', [('RichardII.txt', 1)])
# (4205, 'get', [('RichardII.txt', 6), ('Hamlet.txt', 9), ('RomeoJuliet.txt', 14)])
# (4206, 'included', [('RichardII.txt', 1), ('Hamlet.txt', 3), ('RomeoJuliet.txt', 3)])
# (4207, 'need', [('RichardII.txt', 7), ('Hamlet.txt', 5), ('RomeoJuliet.txt', 11)])
# (4208, 'richard', [('RichardII.txt', 139)])
# (4209, 'second', [('RichardII.txt', 7), ('Hamlet.txt', 25), ('RomeoJuliet.txt', 7)])
# (4210, 'trademark', [('RichardII.txt', 1), ('Hamlet.txt', 13), ('RomeoJuliet.txt', 11)])
# (4211, 'release', [('RichardII.txt', 2), ('Hamlet.txt', 1), ('RomeoJuliet.txt', 1)])
# (4212, 'date', [('RichardII.txt', 3), ('Hamlet.txt', 3), ('RomeoJuliet.txt', 7)])
# (4213, 'day', [('RichardII.txt', 24), ('Hamlet.txt', 21), ('RomeoJuliet.txt', 45)])
# (4214, 'posted', [('RichardII.txt', 1), ('Hamlet.txt', 4), ('RomeoJuliet.txt', 5)])
# (4215, 'comment', [('RichardII.txt', 1), ('Hamlet.txt', 1)])
# (4216, 'editing', [('RichardII.txt', 1)])
# (4217, 'wish', [('RichardII.txt', 5), ('Hamlet.txt', 4), ('RomeoJuliet.txt', 7)])
# (4218, 'first', [('RichardII.txt', 18), ('Hamlet.txt', 63), ('RomeoJuliet.txt', 9)])
# (4219, 'please', [('RichardII.txt', 11), ('Hamlet.txt', 15), ('RomeoJuliet.txt', 6)])
# (4220, 'next', [('RichardII.txt', 8), ('Hamlet.txt', 5), ('RomeoJuliet.txt', 7)])
# (4221, 'one', [('RichardII.txt', 47), ('Hamlet.txt', 45), ('RomeoJuliet.txt', 63)])
# (4222, 'million', [('RichardII.txt', 5), ('Hamlet.txt', 1)])
# (4223, 'dollars', [('RichardII.txt', 2)])
# (4224, 'hour', [('RichardII.txt', 7), ('Hamlet.txt', 8), ('RomeoJuliet.txt', 16)])
# (4225, 'fifty', [('RichardII.txt', 1), ('Hamlet.txt', 1)])
# (4226, 'analyzed', [('RichardII.txt', 1)])
# (4227, 'written', [('RichardII.txt', 1), ('Hamlet.txt', 4), ('RomeoJuliet.txt', 8)])
# (4228, 'etc', [('RichardII.txt', 2)])
# (4229, 'audience', [('RichardII.txt', 1), ('Hamlet.txt', 5)])
# (4230, 'hundred', [('RichardII.txt', 5), ('Hamlet.txt', 2), ('RomeoJuliet.txt', 3)])
# (4231, 'per', [('RichardII.txt', 3)])
# (4232, 'text', [('RichardII.txt', 2), ('RomeoJuliet.txt', 1)])
# (4233, 'dollar', [('RichardII.txt', 1)])
# (4234, 'productivity', [('RichardII.txt', 1)])
# (4235, 'december', [('RichardII.txt', 2)])
# (4236, 'x', [('RichardII.txt', 1)])
# (4237, 'expected', [('RichardII.txt', 1)])
# (4238, 'number', [('RichardII.txt', 5), ('Hamlet.txt', 3), ('RomeoJuliet.txt', 5)])
# (4239, 'computer', [('RichardII.txt', 2), ('Hamlet.txt', 2), ('RomeoJuliet.txt', 2)])
# (4240, 'users', [('RichardII.txt', 1)])
# (4241, 'deductible', [('RichardII.txt', 1), ('Hamlet.txt', 1), ('RomeoJuliet.txt', 1)])
# (4242, 'allowable', [('RichardII.txt', 1)])
# (4243, 'mail', [('RichardII.txt', 2)])
# (4244, 'box', [('RichardII.txt', 2), ('Hamlet.txt', 1)])
# (4245, 'champaign', [('RichardII.txt', 2)])
# (4246, 'il', [('RichardII.txt', 2)])
# (4247, 'web', [('RichardII.txt', 1), ('Hamlet.txt', 1), ('RomeoJuliet.txt', 7)])
# (4248, 'promonet', [('RichardII.txt', 1)])
# (4249, 'else', [('RichardII.txt', 12), ('Hamlet.txt', 17), ('RomeoJuliet.txt', 13)])
# (4250, 'director', [('RichardII.txt', 1), ('RomeoJuliet.txt', 1)])
# (4251, 'hartpoboxcom', [('RichardII.txt', 2)])
# (4252, 'advisor', [('RichardII.txt', 1)])
# (4253, 'small', [('RichardII.txt', 14), ('Hamlet.txt', 3), ('RomeoJuliet.txt', 5)])
# (4254, 'unlike', [('RichardII.txt', 1)])
# (4255, 'many', [('RichardII.txt', 18), ('Hamlet.txt', 20), ('RomeoJuliet.txt', 16)])
# (4256, 'materials', [('RichardII.txt', 1)])
# (4257, 'methods', [('RichardII.txt', 1), ('Hamlet.txt', 1), ('RomeoJuliet.txt', 2)])
# (4258, 'reputation', [('RichardII.txt', 4), ('Hamlet.txt', 1), ('RomeoJuliet.txt', 1)])
# (4259, 'copy', [('RichardII.txt', 3), ('Hamlet.txt', 12), ('RomeoJuliet.txt', 12)])
# (4260, 'distribute', [('RichardII.txt', 3), ('Hamlet.txt', 6), ('RomeoJuliet.txt', 6)])
# (4261, 'laws', [('RichardII.txt', 2), ('Hamlet.txt', 10), ('RomeoJuliet.txt', 8)])
# (4262, 'license', [('RichardII.txt', 2), ('Hamlet.txt', 18), ('RomeoJuliet.txt', 15)])
# (4263, 'replacement', [('RichardII.txt', 3), ('Hamlet.txt', 5), ('RomeoJuliet.txt', 5)])
# (4264, 'provisions', [('RichardII.txt', 1), ('Hamlet.txt', 1), ('RomeoJuliet.txt', 1)])
# (4265, 'exact', [('RichardII.txt', 1), ('Hamlet.txt', 1)])
# (4266, 'including', [('RichardII.txt', 6), ('Hamlet.txt', 9), ('RomeoJuliet.txt', 8)])
# (4267, 'word', [('RichardII.txt', 21), ('Hamlet.txt', 12), ('RomeoJuliet.txt', 28)])
# (4268, 'processing', [('RichardII.txt', 1), ('Hamlet.txt', 1), ('RomeoJuliet.txt', 1)])
# (4269, 'hypertext', [('RichardII.txt', 2), ('Hamlet.txt', 1), ('RomeoJuliet.txt', 1)])
# (4270, 'software', [('RichardII.txt', 2)])
# (4271, 'either', [('RichardII.txt', 3), ('Hamlet.txt', 7), ('RomeoJuliet.txt', 10)])
# (4272, 'clearly', [('RichardII.txt', 1), ('Hamlet.txt', 2), ('RomeoJuliet.txt', 1)])
# (4273, 'contain', [('RichardII.txt', 3), ('Hamlet.txt', 2), ('RomeoJuliet.txt', 2)])
# (4274, 'intended', [('RichardII.txt', 3), ('RomeoJuliet.txt', 1)])
# (4275, 'author', [('RichardII.txt', 3), ('Hamlet.txt', 3), ('RomeoJuliet.txt', 1)])
# (4276, 'tilde', [('RichardII.txt', 1)])
# (4277, 'readily', [('RichardII.txt', 1)])
# (4278, 'reader', [('RichardII.txt', 1)])
# (4279, 'equivalent', [('RichardII.txt', 1)])
# (4280, 'program', [('RichardII.txt', 1)])
# (4281, 'displays', [('RichardII.txt', 1)])
# (4282, 'case', [('RichardII.txt', 2), ('Hamlet.txt', 1), ('RomeoJuliet.txt', 9)])
# (4283, 'instance', [('RichardII.txt', 1), ('Hamlet.txt', 1)])
# (4284, 'processors', [('RichardII.txt', 1)])
# (4285, 'agree', [('RichardII.txt', 1), ('Hamlet.txt', 9), ('RomeoJuliet.txt', 10)])
# (4286, 'request', [('RichardII.txt', 1), ('Hamlet.txt', 2), ('RomeoJuliet.txt', 2)])
# (4287, 'cost', [('RichardII.txt', 2), ('Hamlet.txt', 5), ('RomeoJuliet.txt', 4)])
# (4288, 'warranty', [('RichardII.txt', 2), ('Hamlet.txt', 2), ('RomeoJuliet.txt', 2)])
# (4289, 'disclaimer', [('RichardII.txt', 1), ('Hamlet.txt', 3), ('RomeoJuliet.txt', 3)])
# (4290, 'damages', [('RichardII.txt', 5), ('Hamlet.txt', 4), ('RomeoJuliet.txt', 4)])
# (4291, 'defect', [('RichardII.txt', 3), ('Hamlet.txt', 5), ('RomeoJuliet.txt', 3)])
# (4292, 'data', [('RichardII.txt', 1), ('Hamlet.txt', 1), ('RomeoJuliet.txt', 1)])
# (4293, 'infringement', [('RichardII.txt', 1), ('Hamlet.txt', 1), ('RomeoJuliet.txt', 1)])
# (4294, 'defective', [('RichardII.txt', 1), ('Hamlet.txt', 4), ('RomeoJuliet.txt', 3)])
# (4295, 'damaged', [('RichardII.txt', 1), ('Hamlet.txt', 1), ('RomeoJuliet.txt', 1)])
# (4296, 'virus', [('RichardII.txt', 1), ('Hamlet.txt', 1), ('RomeoJuliet.txt', 1)])
# (4297, 'codes', [('RichardII.txt', 1), ('Hamlet.txt', 1), ('RomeoJuliet.txt', 1)])
# (4298, 'described', [('RichardII.txt', 1), ('Hamlet.txt', 1), ('RomeoJuliet.txt', 1)])
# (4299, 'party', [('RichardII.txt', 3), ('Hamlet.txt', 2), ('RomeoJuliet.txt', 1)])
# (4300, 'receive', [('RichardII.txt', 4), ('Hamlet.txt', 9), ('RomeoJuliet.txt', 4)])
# (4301, 'disclaims', [('RichardII.txt', 1)])
# (4302, 'costs', [('RichardII.txt', 1), ('Hamlet.txt', 2), ('RomeoJuliet.txt', 2)])
# (4303, 'strict', [('RichardII.txt', 3), ('Hamlet.txt', 3), ('RomeoJuliet.txt', 1)])
# ...
# (7837, 'driving', [('RomeoJuliet.txt', 1)])
# (7838, 'lowring', [('RomeoJuliet.txt', 1)])
# (7839, 'nimblepiniond', [('RomeoJuliet.txt', 1)])
# (7840, 'warm', [('RomeoJuliet.txt', 4)])
# (7841, 'bandy', [('RomeoJuliet.txt', 1)])
# (7842, 'jaunce', [('RomeoJuliet.txt', 1)])
# (7843, 'oddly', [('RomeoJuliet.txt', 1)])
# (7844, 'henceforward', [('RomeoJuliet.txt', 2)])
# (7845, 'theyll', [('RomeoJuliet.txt', 1)])
# (7846, 'drudge', [('RomeoJuliet.txt', 1)])
# (7847, 'afterhours', [('RomeoJuliet.txt', 1)])
# (7848, 'powder', [('RomeoJuliet.txt', 3)])
# (7849, 'consume', [('RomeoJuliet.txt', 1)])
# (7850, 'confounds', [('RomeoJuliet.txt', 1)])
# (7851, 'moderately', [('RomeoJuliet.txt', 1)])
# (7852, 'arrives', [('RomeoJuliet.txt', 1)])
# (7853, 'gossamer', [('RomeoJuliet.txt', 1)])
# (7854, 'idles', [('RomeoJuliet.txt', 1)])
# (7855, 'heapd', [('RomeoJuliet.txt', 1)])
# (7856, 'imagind', [('RomeoJuliet.txt', 1)])
# (7857, 'excess', [('RomeoJuliet.txt', 1)])
# (7858, 'operation', [('RomeoJuliet.txt', 1)])
# (7859, 'drawer', [('RomeoJuliet.txt', 1)])
# (7860, 'nuts', [('RomeoJuliet.txt', 1)])
# (7861, 'egg', [('RomeoJuliet.txt', 2)])
# (7862, 'quarrelld', [('RomeoJuliet.txt', 1)])
# (7863, 'wakened', [('RomeoJuliet.txt', 1)])
# (7864, 'den', [('RomeoJuliet.txt', 1)])
# (7865, 'minstrels', [('RomeoJuliet.txt', 2)])
# (7866, 'discords', [('RomeoJuliet.txt', 3)])
# (7867, 'grievances', [('RomeoJuliet.txt', 1)])
# (7868, 'follower', [('RomeoJuliet.txt', 1)])
# (7869, 'appertaining', [('RomeoJuliet.txt', 1)])
# (7870, 'injurd', [('RomeoJuliet.txt', 1)])
# (7871, 'stoccata', [('RomeoJuliet.txt', 1)])
# (7872, 'ratcatcher', [('RomeoJuliet.txt', 1)])
# (7873, 'drybeat', [('RomeoJuliet.txt', 2)])
# (7874, 'bandying', [('RomeoJuliet.txt', 1)])
# (7875, 'surgeon', [('RomeoJuliet.txt', 1)])
# (7876, 'courage', [('RomeoJuliet.txt', 1)])
# (7877, 'soundly', [('RomeoJuliet.txt', 2)])
# (7878, 'supported', [('RomeoJuliet.txt', 1)])
# (7879, 'ally', [('RomeoJuliet.txt', 1)])
# (7880, 'tybalts', [('RomeoJuliet.txt', 11)])
# (7881, 'softned', [('RomeoJuliet.txt', 1)])
# (7882, 'fireeyd', [('RomeoJuliet.txt', 1)])
# (7883, 'staying', [('RomeoJuliet.txt', 1)])
# (7884, 'murtherer', [('RomeoJuliet.txt', 2)])
# (7885, 'beginners', [('RomeoJuliet.txt', 1)])
# (7886, 'displeasure', [('RomeoJuliet.txt', 1)])
# (7887, 'bowd', [('RomeoJuliet.txt', 1)])
# (7888, 'truce', [('RomeoJuliet.txt', 1)])
# (7889, 'spleen', [('RomeoJuliet.txt', 1)])
# (7890, 'tilts', [('RomeoJuliet.txt', 1)])
# (7891, 'piercing', [('RomeoJuliet.txt', 1)])
# (7892, 'stout', [('RomeoJuliet.txt', 2)])
# (7893, 'tot', [('RomeoJuliet.txt', 3)])
# (7894, 'hates', [('RomeoJuliet.txt', 1)])
# (7895, 'ableeding', [('RomeoJuliet.txt', 1)])
# (7896, 'amerce', [('RomeoJuliet.txt', 1)])
# (7897, 'pleading', [('RomeoJuliet.txt', 1)])
# (7898, 'excuses', [('RomeoJuliet.txt', 1)])
# (7899, 'gallop', [('RomeoJuliet.txt', 1)])
# (7900, 'fieryfooted', [('RomeoJuliet.txt', 1)])
# (7901, 'phaeton', [('RomeoJuliet.txt', 1)])
# (7902, 'loveperforming', [('RomeoJuliet.txt', 1)])
# (7903, 'agrees', [('RomeoJuliet.txt', 1)])
# (7904, 'sobersuited', [('RomeoJuliet.txt', 1)])
# (7905, 'matron', [('RomeoJuliet.txt', 1)])
# (7906, 'winning', [('RomeoJuliet.txt', 1)])
# (7907, 'playd', [('RomeoJuliet.txt', 1)])
# (7908, 'hood', [('RomeoJuliet.txt', 3)])
# (7909, 'ravens', [('RomeoJuliet.txt', 1)])
# (7910, 'garish', [('RomeoJuliet.txt', 1)])
# (7911, 'mansion', [('RomeoJuliet.txt', 2)])
# (7912, 'festival', [('RomeoJuliet.txt', 2)])
# (7913, 'robes', [('RomeoJuliet.txt', 2)])
# (7914, 'weraday', [('RomeoJuliet.txt', 2)])
# (7915, 'undone', [('RomeoJuliet.txt', 2)])
# (7916, 'torment', [('RomeoJuliet.txt', 1)])
# (7917, 'vowel', [('RomeoJuliet.txt', 1)])
# (7918, 'bedaubd', [('RomeoJuliet.txt', 1)])
# (7919, 'goreblood', [('RomeoJuliet.txt', 1)])
# (7920, 'bankrout', [('RomeoJuliet.txt', 1)])
# (7921, 'press', [('RomeoJuliet.txt', 2)])
# (7922, 'beautiful', [('RomeoJuliet.txt', 1)])
# (7923, 'dovefeatherd', [('RomeoJuliet.txt', 1)])
# (7924, 'divinest', [('RomeoJuliet.txt', 1)])
# (7925, 'dissemblers', [('RomeoJuliet.txt', 1)])
# (7926, 'blisterd', [('RomeoJuliet.txt', 1)])
# (7927, 'crownd', [('RomeoJuliet.txt', 1)])
# (7928, 'mangled', [('RomeoJuliet.txt', 2)])
# (7929, 'needly', [('RomeoJuliet.txt', 1)])
# (7930, 'rankd', [('RomeoJuliet.txt', 1)])
# (7931, 'highway', [('RomeoJuliet.txt', 1)])
# (7932, 'maidenwidowed', [('RomeoJuliet.txt', 1)])
# (7933, 'acquaintance', [('RomeoJuliet.txt', 1)])
# (7934, 'vanishd', [('RomeoJuliet.txt', 1)])
# (7935, 'merciful', [('RomeoJuliet.txt', 2)])
# (7936, 'purgatory', [('RomeoJuliet.txt', 1)])
# (7937, 'calling', [('RomeoJuliet.txt', 1)])
# (7938, 'smilest', [('RomeoJuliet.txt', 1)])
# (7939, 'unthankfulness', [('RomeoJuliet.txt', 1)])
# (7940, 'sinabsolver', [('RomeoJuliet.txt', 1)])
# (7941, 'professd', [('RomeoJuliet.txt', 1)])
# (7942, 'mangle', [('RomeoJuliet.txt', 1)])
# (7943, 'displant', [('RomeoJuliet.txt', 1)])
# (7944, 'prevails', [('RomeoJuliet.txt', 1)])
# (7945, 'dispute', [('RomeoJuliet.txt', 1)])
# (7946, 'unmade', [('RomeoJuliet.txt', 1)])
# (7947, 'heartsick', [('RomeoJuliet.txt', 1)])
# (7948, 'mistlike', [('RomeoJuliet.txt', 1)])
# (7949, 'whos', [('RomeoJuliet.txt', 2)])
# (7950, 'predicament', [('RomeoJuliet.txt', 1)])
# (7951, 'blubbering', [('RomeoJuliet.txt', 1)])
# (7952, 'conceald', [('RomeoJuliet.txt', 1)])
# (7953, 'cancelld', [('RomeoJuliet.txt', 1)])
# (7954, 'sack', [('RomeoJuliet.txt', 1)])
# (7955, 'unseemly', [('RomeoJuliet.txt', 1)])
# (7956, 'usurer', [('RomeoJuliet.txt', 1)])
# (7957, 'perjury', [('RomeoJuliet.txt', 1)])
# (7958, 'vowd', [('RomeoJuliet.txt', 1)])
# (7959, 'flask', [('RomeoJuliet.txt', 1)])
# (7960, 'afire', [('RomeoJuliet.txt', 1)])
# (7961, 'dismembred', [('RomeoJuliet.txt', 1)])
# (7962, 'courts', [('RomeoJuliet.txt', 1)])
# (7963, 'miserable', [('RomeoJuliet.txt', 2)])
# (7964, 'decreed', [('RomeoJuliet.txt', 1)])
# (7965, 'sojourn', [('RomeoJuliet.txt', 1)])
# (7966, 'nightingale', [('RomeoJuliet.txt', 3)])
# (7967, 'lark', [('RomeoJuliet.txt', 6)])
# (7968, 'pomegranate', [('RomeoJuliet.txt', 1)])
# (7969, 'lace', [('RomeoJuliet.txt', 1)])
# (7970, 'candles', [('RomeoJuliet.txt', 1)])
# (7971, 'tiptoe', [('RomeoJuliet.txt', 1)])
# (7972, 'meteor', [('RomeoJuliet.txt', 1)])
# (7973, 'torchbearer', [('RomeoJuliet.txt', 1)])
# (7974, 'needst', [('RomeoJuliet.txt', 1)])
# (7975, 'reflex', [('RomeoJuliet.txt', 1)])
# (7976, 'vaulty', [('RomeoJuliet.txt', 1)])
# (7977, 'sharps', [('RomeoJuliet.txt', 1)])
# (7978, 'divideth', [('RomeoJuliet.txt', 1)])
# (7979, 'affray', [('RomeoJuliet.txt', 1)])
# (7980, 'hunting', [('RomeoJuliet.txt', 1)])
# (7981, 'thinkst', [('RomeoJuliet.txt', 1)])
# (7982, 'bottom', [('RomeoJuliet.txt', 2)])
# (7983, 'unaccustomd', [('RomeoJuliet.txt', 3)])
# (7984, 'procures', [('RomeoJuliet.txt', 1)])
# (7985, 'namd', [('RomeoJuliet.txt', 1)])
# (7986, 'wreak', [('RomeoJuliet.txt', 1)])
# (7987, 'sorted', [('RomeoJuliet.txt', 1)])
# (7988, 'expects', [('RomeoJuliet.txt', 1)])
# (7989, 'peters', [('RomeoJuliet.txt', 3)])
# (7990, 'drizzle', [('RomeoJuliet.txt', 1)])
# (7991, 'rains', [('RomeoJuliet.txt', 1)])
# (7992, 'showring', [('RomeoJuliet.txt', 1)])
# (7993, 'counterfeitst', [('RomeoJuliet.txt', 1)])
# (7994, 'ebb', [('RomeoJuliet.txt', 1)])
# (7995, 'flow', [('RomeoJuliet.txt', 1)])
# (7996, 'raging', [('RomeoJuliet.txt', 1)])
# (7997, 'tempesttossed', [('RomeoJuliet.txt', 1)])
# (7998, 'thankful', [('RomeoJuliet.txt', 2)])
# (7999, 'minion', [('RomeoJuliet.txt', 1)])
# (8000, 'drag', [('RomeoJuliet.txt', 1)])
# (8001, 'baggage', [('RomeoJuliet.txt', 2)])
# (8002, 'disobedient', [('RomeoJuliet.txt', 2)])
# (8003, 'smatter', [('RomeoJuliet.txt', 1)])
# (8004, 'godigoden', [('RomeoJuliet.txt', 1)])
# (8005, 'waking', [('RomeoJuliet.txt', 4)])
# (8006, 'parentage', [('RomeoJuliet.txt', 1)])
# (8007, 'traind', [('RomeoJuliet.txt', 1)])
# (8008, 'proportiond', [('RomeoJuliet.txt', 1)])
# (8009, 'whining', [('RomeoJuliet.txt', 1)])
# (8010, 'mammet', [('RomeoJuliet.txt', 1)])
# (8011, 'ont', [('RomeoJuliet.txt', 2)])
# (8012, 'practise', [('RomeoJuliet.txt', 1)])
# (8013, 'stratagems', [('RomeoJuliet.txt', 1)])
# (8014, 'stealth', [('RomeoJuliet.txt', 1)])
# (8015, 'displeasd', [('RomeoJuliet.txt', 1)])
# (8016, 'absolvd', [('RomeoJuliet.txt', 1)])
# (8017, 'dispraise', [('RomeoJuliet.txt', 1)])
# (8018, 'immoderately', [('RomeoJuliet.txt', 1)])
# (8019, 'hastes', [('RomeoJuliet.txt', 1)])
# (8020, 'minded', [('RomeoJuliet.txt', 1)])
# (8021, 'slowd', [('RomeoJuliet.txt', 1)])
# (8022, 'abusd', [('RomeoJuliet.txt', 1)])
# (8023, 'wrongst', [('RomeoJuliet.txt', 1)])
# (8024, 'slandred', [('RomeoJuliet.txt', 1)])
# (8025, 'evening', [('RomeoJuliet.txt', 1)])
# (8026, 'pensive', [('RomeoJuliet.txt', 1)])
# (8027, 'strains', [('RomeoJuliet.txt', 1)])
# (8028, 'prorogue', [('RomeoJuliet.txt', 1)])
# (8029, 'hearst', [('RomeoJuliet.txt', 2)])
# (8030, 'seald', [('RomeoJuliet.txt', 2)])
# (8031, 'label', [('RomeoJuliet.txt', 1)])
# (8032, 'longexperiencd', [('RomeoJuliet.txt', 1)])
# (8033, 'thievish', [('RomeoJuliet.txt', 1)])
# (8034, 'lurk', [('RomeoJuliet.txt', 1)])
# (8035, 'serpents', [('RomeoJuliet.txt', 1)])
# (8036, 'roaring', [('RomeoJuliet.txt', 2)])
# (8037, 'oercoverd', [('RomeoJuliet.txt', 1)])
# (8038, 'reeky', [('RomeoJuliet.txt', 1)])
# (8039, 'distilled', [('RomeoJuliet.txt', 1)])
# (8040, 'warmth', [('RomeoJuliet.txt', 1)])
# (8041, 'testify', [('RomeoJuliet.txt', 1)])
# (8042, 'fade', [('RomeoJuliet.txt', 1)])
# (8043, 'paly', [('RomeoJuliet.txt', 1)])
# (8044, 'deprivd', [('RomeoJuliet.txt', 1)])
# (8045, 'borrowed', [('RomeoJuliet.txt', 2)])
# (8046, 'continue', [('RomeoJuliet.txt', 1)])
# (8047, 'twoandforty', [('RomeoJuliet.txt', 1)])
# (8048, 'cooks', [('RomeoJuliet.txt', 1)])
# (8049, 'cook', [('RomeoJuliet.txt', 2)])
# (8050, 'forsooth', [('RomeoJuliet.txt', 1)])
# (8051, 'harlotry', [('RomeoJuliet.txt', 1)])
# (8052, 'gadding', [('RomeoJuliet.txt', 1)])
# (8053, 'enjoind', [('RomeoJuliet.txt', 1)])
# (8054, 'prostrate', [('RomeoJuliet.txt', 1)])
# (8055, 'knit', [('RomeoJuliet.txt', 1)])
# (8056, 'ast', [('RomeoJuliet.txt', 1)])
# (8057, 'behooffull', [('RomeoJuliet.txt', 1)])
# (8058, 'freezes', [('RomeoJuliet.txt', 1)])
# (8059, 'subtilly', [('RomeoJuliet.txt', 1)])
# (8060, 'dishonourd', [('RomeoJuliet.txt', 1)])
# (8061, 'healthsome', [('RomeoJuliet.txt', 1)])
# (8062, 'receptacle', [('RomeoJuliet.txt', 1)])
# (8063, 'mandrakes', [('RomeoJuliet.txt', 1)])
# (8064, 'environed', [('RomeoJuliet.txt', 1)])
# (8065, 'forefathers', [('RomeoJuliet.txt', 1)])
# (8066, 'club', [('RomeoJuliet.txt', 1)])
# (8067, 'dash', [('RomeoJuliet.txt', 1)])
# (8068, 'seeking', [('RomeoJuliet.txt', 1)])
# (8069, 'keys', [('RomeoJuliet.txt', 1)])
# (8070, 'pastry', [('RomeoJuliet.txt', 1)])
# (8071, 'crowd', [('RomeoJuliet.txt', 1)])
# (8072, 'curfew', [('RomeoJuliet.txt', 1)])
# (8073, 'bakd', [('RomeoJuliet.txt', 1)])
# (8074, 'mousehunt', [('RomeoJuliet.txt', 1)])
# (8075, 'logs', [('RomeoJuliet.txt', 3)])
# (8076, 'drier', [('RomeoJuliet.txt', 1)])
# (8077, 'loggerhead', [('RomeoJuliet.txt', 1)])
# (8078, 'slugabed', [('RomeoJuliet.txt', 1)])
# (8079, 'pennyworths', [('RomeoJuliet.txt', 1)])
# (8080, 'aquavitae', [('RomeoJuliet.txt', 1)])
# (8081, 'revive', [('RomeoJuliet.txt', 1)])
# (8082, 'deceasd', [('RomeoJuliet.txt', 1)])
# (8083, 'woful', [('RomeoJuliet.txt', 7)])
# (8084, 'ties', [('RomeoJuliet.txt', 1)])
# (8085, 'deflowered', [('RomeoJuliet.txt', 1)])
# (8086, 'catchd', [('RomeoJuliet.txt', 1)])
# (8087, 'divorced', [('RomeoJuliet.txt', 1)])
# (8088, 'detestable', [('RomeoJuliet.txt', 2)])
# (8089, 'distressed', [('RomeoJuliet.txt', 1)])
# (8090, 'hated', [('RomeoJuliet.txt', 1)])
# (8091, 'advancd', [('RomeoJuliet.txt', 2)])
# (8092, 'ordained', [('RomeoJuliet.txt', 1)])
# (8093, 'instruments', [('RomeoJuliet.txt', 2)])
# (8094, 'dirges', [('RomeoJuliet.txt', 1)])
# (8095, 'lowr', [('RomeoJuliet.txt', 1)])
# (8096, 'manent', [('RomeoJuliet.txt', 1)])
# (8097, 'pet', [('RomeoJuliet.txt', 10)])
# (8098, 'servingcreature', [('RomeoJuliet.txt', 1)])
# (8099, 'crotchets', [('RomeoJuliet.txt', 1)])
# (8100, 'fa', [('RomeoJuliet.txt', 2)])
# (8101, 'griping', [('RomeoJuliet.txt', 1)])
# (8102, 'catling', [('RomeoJuliet.txt', 1)])
# (8103, 'hugh', [('RomeoJuliet.txt', 1)])
# (8104, 'tarry', [('RomeoJuliet.txt', 1)])
# (8105, 'lifts', [('RomeoJuliet.txt', 1)])
# (8106, 'capels', [('RomeoJuliet.txt', 2)])
# (8107, 'misadventure', [('RomeoJuliet.txt', 2)])
# (8108, 'overwhelming', [('RomeoJuliet.txt', 1)])
# (8109, 'meagre', [('RomeoJuliet.txt', 1)])
# (8110, 'tortoise', [('RomeoJuliet.txt', 1)])
# (8111, 'beggarly', [('RomeoJuliet.txt', 1)])
# (8112, 'boxes', [('RomeoJuliet.txt', 1)])
# (8113, 'earthen', [('RomeoJuliet.txt', 1)])
# (8114, 'seeds', [('RomeoJuliet.txt', 1)])
# (8115, 'packthread', [('RomeoJuliet.txt', 1)])
# (8116, 'noting', [('RomeoJuliet.txt', 1)])
# (8117, 'sell', [('RomeoJuliet.txt', 4)])
# (8118, 'apoth', [('RomeoJuliet.txt', 4)])
# (8119, 'mall', [('RomeoJuliet.txt', 1)])
# (8120, 'affords', [('RomeoJuliet.txt', 1)])
# (8121, 'poverty', [('RomeoJuliet.txt', 2)])
# (8122, 'consents', [('RomeoJuliet.txt', 1)])
# (8123, 'compounds', [('RomeoJuliet.txt', 1)])
# (8124, 'associate', [('RomeoJuliet.txt', 1)])
# (8125, 'visiting', [('RomeoJuliet.txt', 1)])
# (8126, 'suspecting', [('RomeoJuliet.txt', 1)])
# (8127, 'whistle', [('RomeoJuliet.txt', 2)])
# (8128, 'distilld', [('RomeoJuliet.txt', 1)])
# (8129, 'muffle', [('RomeoJuliet.txt', 1)])
# (8130, 'mattock', [('RomeoJuliet.txt', 3)])
# (8131, 'interrupt', [('RomeoJuliet.txt', 1)])
# (8132, 'savagewild', [('RomeoJuliet.txt', 1)])
# (8133, 'inexorable', [('RomeoJuliet.txt', 1)])
# (8134, 'tigers', [('RomeoJuliet.txt', 1)])
# (8135, 'opens', [('RomeoJuliet.txt', 1)])
# (8136, 'haughty', [('RomeoJuliet.txt', 1)])
# (8137, 'supposed', [('RomeoJuliet.txt', 1)])
# (8138, 'lanthorn', [('RomeoJuliet.txt', 2)])
# (8139, 'flag', [('RomeoJuliet.txt', 1)])
# (8140, 'advanced', [('RomeoJuliet.txt', 1)])
# (8141, 'sunder', [('RomeoJuliet.txt', 1)])
# (8142, 'paramour', [('RomeoJuliet.txt', 1)])
# (8143, 'inauspicious', [('RomeoJuliet.txt', 1)])
# (8144, 'worldwearied', [('RomeoJuliet.txt', 1)])
# (8145, 'bargain', [('RomeoJuliet.txt', 1)])
# (8146, 'unsavoury', [('RomeoJuliet.txt', 1)])
# (8147, 'seasick', [('RomeoJuliet.txt', 1)])
# (8148, 'grubs', [('RomeoJuliet.txt', 1)])
# (8149, 'eyeless', [('RomeoJuliet.txt', 1)])
# (8150, 'discern', [('RomeoJuliet.txt', 1)])
# (8151, 'burneth', [('RomeoJuliet.txt', 1)])
# (8152, 'menace', [('RomeoJuliet.txt', 1)])
# (8153, 'masterless', [('RomeoJuliet.txt', 1)])
# (8154, 'discolourd', [('RomeoJuliet.txt', 1)])
# (8155, 'contradict', [('RomeoJuliet.txt', 1)])
# (8156, 'sisterhood', [('RomeoJuliet.txt', 1)])
# (8157, 'nuns', [('RomeoJuliet.txt', 1)])
# (8158, 'pariss', [('RomeoJuliet.txt', 1)])
# (8159, 'tombs', [('RomeoJuliet.txt', 1)])
# (8160, 'bleeds', [('RomeoJuliet.txt', 1)])
# (8161, 'mistaen', [('RomeoJuliet.txt', 1)])
# (8162, 'warns', [('RomeoJuliet.txt', 1)])
# (8163, 'untaught', [('RomeoJuliet.txt', 1)])
# (8164, 'ambiguities', [('RomeoJuliet.txt', 1)])
# (8165, 'parties', [('RomeoJuliet.txt', 1)])
# (8166, 'direful', [('RomeoJuliet.txt', 1)])
# (8167, 'excusd', [('RomeoJuliet.txt', 1)])
# (8168, 'pind', [('RomeoJuliet.txt', 1)])
# (8169, 'betrothd', [('RomeoJuliet.txt', 1)])
# (8170, 'potions', [('RomeoJuliet.txt', 1)])
# (8171, 'prefixed', [('RomeoJuliet.txt', 1)])
# (8172, 'awaking', [('RomeoJuliet.txt', 1)])
# (8173, 'scare', [('RomeoJuliet.txt', 1)])
# (8174, 'miscarried', [('RomeoJuliet.txt', 1)])
# (8175, 'sacrificd', [('RomeoJuliet.txt', 1)])
# (8176, 'rigour', [('RomeoJuliet.txt', 1)])
# (8177, 'countys', [('RomeoJuliet.txt', 1)])
# (8178, 'friars', [('RomeoJuliet.txt', 1)])
# (8179, 'writes', [('RomeoJuliet.txt', 1)])
# (8180, 'pothecary', [('RomeoJuliet.txt', 1)])
# (8181, 'therewithal', [('RomeoJuliet.txt', 1)])
# (8182, 'punishd', [('RomeoJuliet.txt', 1)])
# (8183, 'jointure', [('RomeoJuliet.txt', 1)])
# (8184, 'whiles', [('RomeoJuliet.txt', 1)])
# (8185, 'various', [('RomeoJuliet.txt', 1)])
# (8186, 'httpwwwpglaforg', [('RomeoJuliet.txt', 1)])
# (8187, 'httppglaforgfundraising', [('RomeoJuliet.txt', 1)])
# (8188, 'principal', [('RomeoJuliet.txt', 1)])
# (8189, 'melan', [('RomeoJuliet.txt', 1)])
# (8190, 'dr', [('RomeoJuliet.txt', 2)])
# (8191, 'ak', [('RomeoJuliet.txt', 1)])
# (8192, 'numerous', [('RomeoJuliet.txt', 1)])
# (8193, 'httppglaforg', [('RomeoJuliet.txt', 2)])
# (8194, 'gbnewbypglaforg', [('RomeoJuliet.txt', 1)])
# (8195, 'httppglaforgdonate', [('RomeoJuliet.txt', 1)])
# (8196, 'httpwwwgutenbergorg', [('RomeoJuliet.txt', 1)])
